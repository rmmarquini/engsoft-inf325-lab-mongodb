# %% [markdown]
# # Exercício 1

# %% [markdown]
# ## Objetivo
#
# Esta atividade tem o objetivo de exercitar de maneira prática o que foi aprendido pelo aluno no contexto do MongoDB.

# %% [markdown]
# ## Sobre a base de dados
#
# Neste laboratório você utilizará um dataset contendo informações sobre restaurantes. A coleção de restaurantes contém 3772 documentos. Cada documento contém informações sobre um único restaurante.
#
# Veja um exemplo de documento de um dos restaurantes e entenda a estrutura/schema:
#
# ```json
# {
#   "address": {
#      "building": "1007",
#      "coord": [ -73.856077, 40.848447 ],
#      "street": "Morris Park Ave",
#      "zipcode": "10462"
#   },
#   "borough": "Bronx",
#   "cuisine": "Bakery",
#   "grades": [
#      { "date": { "$date": 1393804800000 }, "grade": "A", "score": 2 },
#      { "date": { "$date": 1378857600000 }, "grade": "A", "score": 6 },
#      { "date": { "$date": 1358985600000 }, "grade": "A", "score": 10 },
#      { "date": { "$date": 1322006400000 }, "grade": "A", "score": 9 },
#      { "date": { "$date": 1299715200000 }, "grade": "B", "score": 14 }
#   ],
#   "name": "Morris Park Bake Shop",
#   "restaurant_id": "30075445"
# }
#
# ```

# %% [markdown]
# # Baixando a coleção

# %%
# !wget https://www.w3resource.com/mongodb-exercises/restaurants.zip
# !unzip -o restaurants.zip
# !rm restaurants.zip
# Out:
# --2020-08-15 00:27:30--  https://www.w3resource.com/mongodb-exercises/restaurants.zip
# Resolving www.w3resource.com (www.w3resource.com)... 172.67.69.127, 104.26.14.93, 104.26.15.93, ...
# Connecting to www.w3resource.com (www.w3resource.com)|172.67.69.127|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 262722 (257K) [application/zip]
# Saving to: ‘restaurants.zip’
#
# restaurants.zip     100%[===================>] 256.56K  1.25MB/s    in 0.2s
#
# 2020-08-15 00:27:33 (1.25 MB/s) - ‘restaurants.zip’ saved [262722/262722]
#
# Archive:  restaurants.zip
#   inflating: restaurants.json

# %% [markdown]
# # Importando a coleção para o MongoDB
# Utilizaremos o ``` mongoimport ``` para importar a coleção ``` restaunts.json ```. Mais informações sobre esta ferramenta podem ser encontradas em https://docs.mongodb.com/manual/reference/program/mongoimport/#bin.mongoimport .
#
# Modifique o comando abaixo, alterando o nome do banco de dados e da coleção para nomes de sua preferência.

# %%
# !mongoimport --db exercicio1 --collection restaurants --drop --file $(pwd)/restaurants.json
# Out:
# 2020-08-15T00:27:35.531+0000	connected to: mongodb://localhost/
# 2020-08-15T00:27:35.531+0000	dropping: exercicio1.restaurants
# 2020-08-15T00:27:37.552+0000	3772 document(s) imported successfully. 0 document(s) failed to import.

# %% [markdown]
# # Opções para fazer consultas no dataset

# %% [markdown]
# ## Usando Python

# %%
from pymongo import MongoClient
from pprintpp import pprint
import warnings
warnings.filterwarnings('ignore')
mongoclient = MongoClient('localhost', 27017)
db = mongoclient.exercicio1
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'exercicio1')

# %%
db.restaurants.find({}).count()
# Out:
# 3772

# %% [markdown]
# ## Mongo Shell

# %%
! mongo --quiet --eval 'db.restaurants.find().count();' exercicio1
# Out:
# 3772

# %% [markdown]
# ## Mongo Shell e Python

# %%
documento_busca = {
    
}

! mongo --quiet --eval "db.restaurants.find().count();" exercicio1
# Out:
# 3772

# %% [markdown]
# ## Questões Exemplo

# %% [markdown]
# ### [Questão Exemplo A]  Mostre um documento qualquer da coleção restaurants

# %%
result = db.restaurants.find({}).limit(1)

pprint( list(result) )
# Out:
# [
#     {
#         '_id': ObjectId('5f372bf75956cf602023fe99'),
#         'address': {
#             'building': '2780',
#             'coord': [-73.98241999999999, 40.579505],
#             'street': 'Stillwell Avenue',
#             'zipcode': '11224',
#         },
#         'borough': 'Brooklyn',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 6, 10, 0, 0),
#                 'grade': 'A',
#                 'score': 5,
#             },
#             {
#                 'date': datetime.datetime(2013, 6, 5, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#             {
#                 'date': datetime.datetime(2012, 4, 13, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2011, 10, 12, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#         ],
#         'name': 'Riviera Caterer',
#         'restaurant_id': '40356018',
#     },
# ]

# %% [markdown]
# ### [Questão Exemplo B]  Encontre o documento referente ao restaurante de nome "Kosher Island"

# %%
result = db.restaurants.find({"name": "Kosher Island"})

pprint( list(result) )
# Out:
# [
#     {
#         '_id': ObjectId('5f372bf75956cf602023fea5'),
#         'address': {
#             'building': '2206',
#             'coord': [-74.1377286, 40.6119572],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Jewish/Kosher',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 10, 6, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2014, 5, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2013, 4, 4, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2012, 1, 24, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#         ],
#         'name': 'Kosher Island',
#         'restaurant_id': '40356442',
#     },
# ]

# %% [markdown]
# ## Questões a serem resolvidas

# %% [markdown]
# ### [Questão 1] Mostre o nome de todos os restaurantes sem repetir. Separadamente, mostre também todos os tipos distintos de cozinhas.

# %%
result = db.restaurants.distinct("name")

pprint( list(result) )
# Out:
# [
#     '(Lewis Drug Store) Locanda Vini E Olii',
#     '1 East 66Th Street Kitchen',
#     '101 Deli',
#     '101 Restaurant And Bar',
#     '1020 Bar',
#     '104-01 Foster Avenue Coffee Shop(Ups)',
#     '10Th Avenue Pizza & Cafe',
#     '111 Restaurant',
#     '15 East Restaurant',
#     '200 Fifth Avenue Restaurant & Sports Bar',
#     '21 Club',
#     '2A',
#     '3 Deli & Grill',
#     '3 Guys',
#     '3 Guys Resturant',
#     '42Nd Street Pizza Diner',
#     "44 & X Hell'S Kitchen",
#     '44 Sw Ristorante & Bar',
#     '5 Burro Cafe',
#     '525 Lex Restaurant & Bar',
#     '7 Stars',
#     '71 Irving Place',
#     '7B Bar',
#     '7Th Avenue Donut Shop',
#     '810 Deli & Cafe',
#     '9024/Catering By Michael Schick Inc.',
#     '9Th Ave Saloon',
#     'A & B Deli & Catering',
#     'A & S Pizzeria',
#     'A Salt & Battery',
#     'A-1 Pizza Shop',
#     'A.J. Pizzeria',
#     "Abigael'S On Broadway",
#     'Abir Halal Restaurant',
#     "Abitino'S Pizza",
#     'Absolute Bagels',
#     'Academy Restauraunt',
#     'Acappella Restaurant',
#     'Acapulco Deli & Restaurant',
#     'Ace Bar',
#     'Acme Bar & Grill',
#     'Acqua',
#     'Acqua Santa',
#     'Acquista Trattoria',
#     'Adria Hotel',
#     "Adrian & Rocky'S Caterers",
#     'Afghan Kebab House',
#     'Afghan Kebab House #1',
#     'African Market (Baboon Cafe)',
#     'African Terrace',
#     'Africana Restaurant',
#     "Afternoone'S Restaurant",
#     'Agave',
#     'Agra Restaurant',
#     'Ah! Chihuahua',
#     'Air France Lounge',
#     'Air India Lounge',
#     'Airport Deli',
#     'Ajanta India',
#     'Ajisen Ramen',
#     'Akiyama Japanese Restaurant',
#     'Al Cholo Bakery',
#     'Al Di La',
#     'Al Forno',
#     'Al-Dente',
#     'Al-Mehran Restaurant',
#     'Aladdin',
#     'Alba Pizza',
#     "Alba'S Pizza",
#     'Albany Manor',
#     'Albella Ristorante & Bar',
#     "Aldo'S Ii Pizza And Restaurant",
#     "Alex'S Kitchen",
#     "Alfonso'S Bar",
#     "Alfonso'S Pastry Shoppe",
#     "Ali'S Roti Shop",
#     'Alibaba',
#     'Alibi Club',
#     "Alice'S Tea Cup",
#     'Alices',
#     'Aliotta Bake Shop',
#     'All American Coffee Shop',
#     'All American Deli',
#     "Allan'S Bakery",
#     'Alma',
#     'Almar',
#     'Alpha Donuts',
#     'Alta',
#     'Alyshia Aleem Coffee Shop',
#     'Am',
#     'Amaranth',
#     'Amazon Cafe',
#     'Ambassador Diner',
#     'Ambassador Dining Room  At Saratoga Family Inn',
#     'Ambassador Theatre',
#     'Ambrosinos Pizzeria',
#     "Amelia'S Restaurant",
#     'Amerada Hess Express Cafe',
#     'American Airlines Employee Cafeteria',
#     'American Coffee Shop',
#     'American Express',
#     "American Hero & Sub'S",
#     'American Museum Of Natural History Food Court',
#     'Americas Burger And Wraps',
#     'Americas Restorante',
#     'Amf 34 Avenue Lanes',
#     'Amma',
#     'Amnon Kosher Pizza',
#     'Amore Pizzeria & Restaurant',
#     'Amsterdam Billiards',
#     'Amsterdam Restaurant & Tapas Lounge',
#     "Amy'S Bread",
#     'An Beal Bocht Cafe',
#     "Andre'S Hungarian",
#     "Andrew'S Coffee Shop",
#     "Andrew'S Diner",
#     'Andrews Coffee Shop',
#     "Andy'S Cafeteria",
#     'Anesis Cafe',
#     'Angel Flakes Patties',
#     'Angelica Kitchen',
#     "Angelica'S Bakery",
#     'Angelika Film Center',
#     'Angelo Of Mulberry St.',
#     "Angelo'S Pizzeria/Mimmo'S Restaurant",
#     'Anglers Club Of New York',
#     'Angry Wades',
#     'Anna Maria Pizza Pasta',
#     "Anna'S Cafe",
#     'Annam Braham Restaurant',
#     'Annelies Pastries',
#     "Annie Moore'S Restaurant",
#     "Annie'S Kitchen",
#     'Anopoli Family Restaurant',
#     'Anotheroom',
#     "Anthony'S Place",
#     'Antica Trattoria',
#     'Antojitos Mexicanos',
#     "Antonio'S Pizza",
#     "Antun'S",
#     'Anyway Cafe',
#     'Anyway Cafe Bar',
#     'Apollo Bakery',
#     'Appetito Restaurant',
#     "Applebaum'S",
#     "Applebee'S Neighborhood Grill & Bar",
#     'Aqua Grill',
#     'Aquamarina',
#     'Aqueduct North',
#     'Arabelle',
#     'Archer Sports Bar',
#     'Archives',
#     'Areo Restaurant',
#     "Aretsky'S Patroon",
#     'Arharn Thai Cuisine',
#     'Ariana Kebab House',
#     'Arirang Hibachi Steak House',
#     'Arirang Hibachi Steakhouse',
#     'Ariyoshi Japanese Restaurant',
#     'Arka Lounge',
#     "Arlene'S Grocery",
#     "Armando'S Pizza",
#     'Arno Ristorante',
#     'Arriba Arriba',
#     'Arte Cafe',
#     'Arte Restaurant',
#     "Arthur'S Tavern",
#     "Artie'S",
#     'Artisanal',
#     "Arturo'S",
#     "Arturo'S Pizza",
#     'Artuso Pastry Shop',
#     'Arzu Restaurant',
#     "Ashby'S Specialty",
#     'Astoria Bagel Shop',
#     'Astra',
#     'Astral Fitness & Wellness',
#     'Astro Restaurant',
#     'Astromundo Restaurant',
#     'Atlantic Grill',
#     'Atlantis Diner',
#     'Au Bon Pain',
#     'Auction House',
#     "Aunt Bella'S Rest Of Little Neck",
#     "Auntie Anne'S Pretzels",
#     'Austin House',
#     "Austin'S Steak & Ale House",
#     'Automatic Slims',
#     'Avellino Restaurant',
#     'Avra Estiatorio',
#     'Ayurveda Cafe',
#     'Azalea',
#     'Azuri Cafe',
#     'Azusa Of Japan',
#     'B & M Hot Bagel & Grocery',
#     'B. Smith Restaurant',
#     'B.B. Kings',
#     'B.Q.E. Cafe Billiards',
#     'B66 Club',
#     'Babbo Ristorante E Enoteca',
#     "Baby Bo'S Burritos",
#     'Back To Nature',
#     'Bad Boys Pizza',
#     'Bagel Bazaar',
#     "Bagel Bob'S",
#     'Bagel Cafe',
#     'Bagel Club',
#     'Bagel Corner',
#     'Bagel Deli / Village Green Deli',
#     'Bagel Depot',
#     'Bagel House',
#     'Bagel Land',
#     'Bagel Shoppe',
#     'Bagel Works',
#     'Bagelman Of Woodside',
#     'Bagels & Cream Deli',
#     'Bagels Deli',
#     'Bagels Etc',
#     'Bagels N Buns',
#     'Bahari Estiatorio',
#     'Bahia Restaurant & Cafe',
#     'Bais Rochel',
#     'Bake And Things Restaurant',
#     'Baker Street Pub',
#     "Baker'S Dozen Bagel",
#     'Bali Nusa Indonesian Restaurant',
#     "Ballato'S Restaurant",
#     'Ballfields Cafe',
#     'Bally Total Fitness',
#     'Balthazar Bakery',
#     'Balthazar Restaurant',
#     'Bamboo Garden',
#     'Bamboo Garden Restaurant',
#     "Bamonte'S Restaurant",
#     'Bangal Curry',
#     'Bangkok Grand Palace',
#     'Bangkok Thai House',
#     'Bank Of New York',
#     'Bank Of New York Cafe',
#     'Banshee Pub',
#     'Bar 515',
#     'Bar Association Of The City Of Ny Kitchen',
#     'Bar Coastal',
#     'Bar None',
#     'Bar Six',
#     'Bar Tabac',
#     'Bar Toto',
#     'Bar Veloce',
#     'Bar Vetro',
#     'Baraonda',
#     'Barbaresco',
#     'Barbes',
#     'Barbetta Restaurant',
#     "Barclay'S Capital",
#     'Barfly',
#     'Bari Sandwich Shop',
#     'Barios Pizza & Restaurant',
#     'Barnes & Noble Booksellers',
#     'Barnes & Noble Cafe',
#     'Barney Greengrass',
#     'Barone Pizza',
#     'Barracuda Bar',
#     'Barrage',
#     'Barranquilla Bakery & Restaurant',
#     'Barre Cafe At Steps',
#     'Barries Restaurant',
#     "Barrow'S Pub",
#     'Bartow Pizza',
#     'Baskin Robbins',
#     'Bassett Caterers',
#     'Basta Pasta Restaurant',
#     'Bateaux New York',
#     'Bay Pizzeria Restaurant',
#     'Bay Ridge Manor Catering',
#     'Baybridge Szechuan Restaurant',
#     'Bayridge Pizza',
#     'Beauty Bar',
#     'Beaver Pond',
#     'Becco',
#     'Bedford Cafe & Restaurant',
#     "Behan'S Pub",
#     'Bel Paese Italian Deli',
#     'Bel-Aire Diner',
#     'Belaire Cafe',
#     'Belasco Theatre',
#     'Bella Blu',
#     'Bella Luna',
#     'Bella Napoli',
#     'Bello Giardino',
#     'Bello Restaurant',
#     'Bellrose Deli',
#     'Belmora Pizza & Restaurant',
#     'Belvedere Cafe',
#     'Ben Ash Delicatessen',
#     "Ben'S Deli",
#     "Ben'S Kosher Deli & Restaurant",
#     "Ben'S Pizza",
#     'Ben-Best Deli & Restaurant',
#     'Benjamin',
#     "Bennie'S Thai Cafe",
#     "Benny'S Burritos",
#     "Benny'S Famous Pizza",
#     'Bennys Burritos',
#     'Bergen Bagels',
#     'Bergen Beach Cafe',
#     'Berkely',
#     'Bermay Luncheonette',
#     'Bernard B Jacobs Theater',
#     'Best Deli Cafe',
#     'Beth Torah Kosher Caterers',
#     'Beyoglu',
#     'Biarritz Bakery',
#     'Bicheiros Bar',
#     "Big Al'S Chicago Pizza",
#     'Big Als Chicago Pizza',
#     'Big Bar',
#     "Big Daddy'S Diner",
#     'Big Jons Pizza & Restaurant',
#     'Big New York Fried Chicken',
#     "Bijan'S",
#     "Bill'S Restaurant",
#     'Billiard Company',
#     "Billy'S Sport Bar Restaurant & Lounge",
#     'Billymarks West',
#     'Birdland',
#     'Bistro Citron',
#     'Bistro Les Amis',
#     'Bistro Ten-18',
#     'Bits Bite & Baguettes',
#     'Black And White',
#     'Black Fat Pussy Cat',
#     'Black Rock Cafe',
#     'Black Whale',
#     'Blake & Todd',
#     'Blanches @ Dkny',
#     'Blarney Bar',
#     'Blarney Castle',
#     'Blarney Rock',
#     'Blarney Stone',
#     'Bleecker Street Bar',
#     'Blimpie',
#     'Bliss Bakery & Cafe',
#     'Bliss Street Station Restaurant',
#     "Blockhead'S Burritos",
#     "Blockhead'S Mexican Diner",
#     'Blockheads',
#     'Blockheads Burritos',
#     'Blondies',
#     'Blue & Gold Bar',
#     'Blue & Gray Inn',
#     'Blue Bay Diner',
#     'Blue Bay Restaurant',
#     'Blue Diner',
#     'Blue Fin',
#     'Blue Hill Restaurant',
#     'Blue Mountain Restaurant & Jerk Center',
#     'Blue Note Jazz',
#     'Blue Ribbon',
#     'Blue Ribbon Brasserie',
#     'Blue Ribbon Sushi',
#     'Blue Smoke',
#     'Blue Water Grill',
#     'Bluestockings Womens Bookstore Cafe',
#     "Bobby Van'S",
#     "Bobby'S Coffee Shop",
#     'Bocca',
#     'Bocca Di Bacco',
#     'Bocelli',
#     'Bombay Masala',
#     'Bond St',
#     'Bonelle Pastry Shop',
#     "Bonnie'S Grill",
#     "Bono'S Cafe",
#     'Book Chang Dong Sodndubu',
#     'Booth Theater',
#     'Boots & Saddle Bar',
#     'Boston Jerk-City Restaurant',
#     'Boston Market',
#     'Boston Pizza',
#     'Botanica Bar',
#     'Bottino',
#     'Boulevard Tavern',
#     'Bourbon Street',
#     'Bowery Eletric',
#     'Bowler Land',
#     'Bowlmor Chelsea Piers',
#     'Box Car Lounge',
#     "Brady'S Bar",
#     "Brandy'S Piano Bar",
#     'Brasserie Athenee',
#     'Brasserie Les Halles',
#     "Braulio'S & Family Restaurant",
#     'Bravo Cafe Concert',
#     'Bravo Pizza',
#     'Brazil Grill',
#     'Bread',
#     'Bread Market Cafe',
#     "Brendan'S",
#     'Brennan & Carr',
#     'Bricco Restaurant',
#     'Bridgeview Diner',
#     'Brioso Ristorante',
#     'Broadhurst Theater',
#     'Broadway Bagel',
#     'Broadway Dive',
#     'Broadway Lounge',
#     'Broadway Pizza & Pasta',
#     'Broadway Restaurant',
#     'Broadway Station',
#     'Broadway Theatre',
#     'Bronx Grill',
#     'Brooklyn Botanic Catering Hall',
#     'Brooklyn Diner',
#     'Brooklyn Ice Cream Factory',
#     'Brooklyn Moon Cafe',
#     'Brooklyn Pizza',
#     'Brooklyn Pizza Ii',
#     'Brooks Atkinson Theater',
#     'Broome Street Bar',
#     "Brother Jimmy'S Bbq",
#     'Brunos On The Boulevard',
#     "Bubby'S",
#     'Buccaneer Diner',
#     "Buddy'S Burrito & Taco Bar",
#     "Buddy'S Wonder Bar",
#     'Bull Head Tavern',
#     'Bull Mccabes',
#     'Bull Shots',
#     "Bully'S Deli",
#     'Bum Bum Bar',
#     'Bungalow Bar & Restaurant',
#     'Buona Notte Ristorante',
#     'Buono Bakery',
#     "Burek'S Pizza",
#     'Burger Barn Restaurant',
#     'Burger Heaven',
#     'Burger King',
#     'Burger King/Metro Mall',
#     'Burgers & Cupcakes',
#     "Burke'S Pub",
#     'Burrito Box',
#     'Burrito Loco',
#     'Bus Stop Cafe',
#     'Buzz',
#     'C & B Luncheonette',
#     'C & C Catering',
#     'C & C Catering Service',
#     'C.U.N.Y Cafe',
#     'Cabana',
#     "Caesar'S Palace",
#     'Cafe 101',
#     'Cafe 101 16Th Floor Cafeteria',
#     'Cafe 212/Columbia Catering Kitchen - Alfred Lerner Hall',
#     'Cafe 31',
#     'Cafe 75 Bar',
#     'Cafe Al Mercato',
#     "Cafe Amore'S Restaurant",
#     'Cafe Angelique',
#     'Cafe Angus',
#     'Cafe Asean',
#     'Cafe Atelier (Art Students League)',
#     'Cafe Bar',
#     'Cafe Bella Vita',
#     'Cafe Beyond',
#     'Cafe Bonjour',
#     'Cafe Borgia Ii',
#     'Cafe Bravo',
#     'Cafe Buon Gusto',
#     'Cafe Capri',
#     'Cafe Cardini',
#     'Cafe Cello Deli',
#     'Cafe Champignon',
#     'Cafe Duke',
#     'Cafe Edison',
#     'Cafe Eighty Two',
#     'Cafe Espanol',
#     'Cafe Express',
#     'Cafe Frida',
#     'Cafe Gitane',
#     'Cafe Joul',
#     'Cafe K',
#     'Cafe Lalo',
#     "Cafe Lou'S",
#     'Cafe Loup',
#     'Cafe Luka',
#     'Cafe Luluc',
#     'Cafe Luna',
#     'Cafe Luxembourg',
#     'Cafe Madison',
#     'Cafe Mae Mae',
#     'Cafe Metro',
#     'Cafe Mogador',
#     'Cafe Ole Usa',
#     'Cafe Orlin',
#     'Cafe Paris',
#     'Cafe Rakka',
#     'Cafe Renaissance',
#     'Cafe Riazor',
#     'Cafe Ronda',
#     'Cafe Rustico Ii',
#     'Cafe Sabarsky',
#     'Cafe Spice',
#     'Cafe Steinhof',
#     'Cafe Un Deux Trois',
#     'Cafe Volna',
#     'Cafe Zaiya',
#     'Cafeteria',
#     'Cafeteria- Lirr Employees',
#     'Caffe Buon Gusto',
#     'Caffe Dante',
#     'Caffe Egidio',
#     'Caffe Grazie',
#     'Caffe Linda',
#     'Caffe Napoli',
#     'Caffe Palermo',
#     'Caffe Reggio',
#     'Caffe Roma',
#     'Caffe Venezia',
#     'Caffe Vivaldi',
#     "Caffe' Romeo",
#     'Caffee Express',
#     'Caliente Cab Co',
#     'Cambridge Caterers',
#     'Camilles',
#     'Campagnola Restaurant',
#     'Campanile',
#     'Campeon',
#     'Campus Center Cafeteria',
#     'Campus Eatery',
#     'Canaletto Ristorante',
#     'Canard Inc',
#     'Candies Bar',
#     'Candle Bar',
#     'Candle Cafe',
#     "Canlon'S Restaurant",
#     'Canyon Road Grill',
#     'Capitol Restaurant',
#     'Cappuccino Cafe',
#     'Capri Bakery',
#     'Capri Ii Pizza',
#     'Capri Pizza Restaurant',
#     'Caprice',
#     "Captain'S Pizzeria And Restaurant",
#     'Cara Mia',
#     'Caravan Chicken',
#     'Caravan Of Dreams',
#     'Caribbean Sports',
#     'Caridad',
#     'Caridad Restaurant',
#     'Carleton Lounge - Mudd Building',
#     'Carlos Pizza',
#     'Carlow East',
#     "Carmine'S",
#     "Carmine'S Restaurant",
#     'Carnegie Delicatessen & Restaurant',
#     "Carol'S Cafe",
#     "Caroline'S On Broadway",
#     'Carom Cafe Billiards',
#     'Carry On Tea & Sympathy',
#     'Caruso Pizza #2',
#     'Caruso Pizzeria & Restaurant',
#     'Carvel',
#     'Carvel Ice Cream',
#     'Casa',
#     'Casa Bella',
#     'Casa Java',
#     'Casa Pepe',
#     'Casa Promesa',
#     'Casabianca Pizzeria',
#     'Casanova Restaurant',
#     "Cascarino'S",
#     "Cascarino'S Pizza",
#     "Cassidy'S Ale House",
#     'Cassis Bistro/Brasserie',
#     'Castlehill Diner',
#     "Catania'S Pizza Cafe",
#     "Caterina'S Pizza",
#     "Caterina'S Pizzeria",
#     "Cavallo'S Pizzeria",
#     'Cavatappo Grill',
#     'Cavo',
#     'Cbs Employee Cafeteria',
#     'Cea Lo Cafe',
#     'Cebu',
#     "Celeste'S Snack Bar",
#     'Central Cafe',
#     'Central Park Boathouse',
#     "Cha Cha'S Backyard Garden Bar & Cafe",
#     'Chadash Falafel & Pizza',
#     "Chadwick'S",
#     'Champ Gourmet',
#     "Champ'S Deli",
#     'Champion Bakery',
#     "Chan'S Kitchen",
#     'Chap A Nosh/Yun Kee',
#     "Charle'S Corner Restaurant & Deli",
#     'Charles Pizzeria',
#     "Charlie'S Mom Chinese Restaurant",
#     'Charlies Sports Bar',
#     'Charo Restaurant',
#     'Chase Edr',
#     'Che Bella Pizza',
#     'Checkers',
#     "Chef Ho'S",
#     'Cheito Duran Deli Grocery',
#     'Chelsea Square Restaurant',
#     'Chelsea Trattoria',
#     "Chen'S Chinese",
#     'Cherokee Deli',
#     'Cherry Tavern',
#     'Chez Jaqueline',
#     'Chez Josephine',
#     'Chez Napolean',
#     "Chic-Fil-A, Quiznos Subs, Jw'S, Tossed",
#     'Chick-N-Ribs',
#     'Chicken Delicious',
#     'Chicken Festival',
#     'Chicken Holiday Express',
#     'Chickpea',
#     'China Chalet',
#     'China Fun',
#     'China Glatt',
#     'China Grill',
#     'China New Star',
#     'China Wok Ii',
#     'Chinantla',
#     'Chirping Chicken',
#     'Chiu Hong Bakery',
#     'Cho Dang Gol',
#     'Cho-Sen Garden',
#     "Chock Full O' Nuts",
#     "Chop'T",
#     'Chopstix Restaurant',
#     'Choy Le Chinese Restaurant',
#     "Christie'S",
#     "Christina'S Restaurant",
#     "Chuck E Cheese'S",
#     'Churrascaria Plataforma',
#     'Ciao Bella',
#     "Cibar - Lady Mendl'S Tea Salon",
#     'Cibo',
#     'Cilantro',
#     'Cindy Restaurant Luncheonette',
#     'Cinema Cafe & Bar',
#     'Cinema The Brasserie',
#     'Cinnabon World Famous Cinnamon Rolls',
#     'Cipriani Dolci',
#     'Cipriani Downtown Restaurant',
#     'Circa Tabac',
#     'Circle In The Square Theatre',
#     'Circle Pizzeria',
#     "Circle'S Grill",
#     'Circo Pastry Shop',
#     'Circo Restaurant',
#     'Ciro Pizza',
#     "Ciro'S Pizza Restaurant",
#     'Ciros Pastry Shop',
#     'Citibank Employee Cafeteria',
#     'Citibank Executive Conference Center',
#     'Citrus Bar & Grill',
#     'City Chow Cafe',
#     'City Chow Cafe V (Equinox)',
#     'City College Cafeteria',
#     'City Crab',
#     'City Hall Restaurant',
#     'City Island Deli',
#     'City Island Diner /Snug Bar',
#     'City Lobster & Steak',
#     'City Market Cafe',
#     'City Pie',
#     "Cj Sullivan'S",
#     'Claddagh Inn',
#     "Clark'S Restaurant",
#     'Classic Coffee Shop',
#     'Cleary Gottlieb',
#     "Cleopatra'S Needle",
#     'Clinton Restaurant',
#     'Clinton Street Baking Company',
#     'Cloister Cafe',
#     'Club 101',
#     'Club Macanudo (Cigar Bar)',
#     'Club Metropolitan',
#     'Cobblestone Pub',
#     'Cocktail Room (Nyac)',
#     "Cody'S Ale House Grill",
#     'Coffee Express',
#     'Coffee Shop',
#     'Coliseum Bar Restaurant',
#     'Collado Restaurant',
#     'Colonnade Diner',
#     'Colony Club',
#     'Columbo Yogurt/ Taco Bell/ Nathans/ Tim Horton/Pizza Hut',
#     'Columbus Citizens Foundation',
#     'Columbus Gourmet Food',
#     'Columbus House',
#     'Comic Strip',
#     'Community Food And Juice',
#     'Como Pizza',
#     'Concession # 110',
#     'Concession # 120/ The Bullpen',
#     'Concession Stand  330',
#     'Concourse Jamaican Bakery',
#     'Connecticut Muffin',
#     "Connie O'S",
#     "Connolly'S",
#     "Connolly'S Corner",
#     "Connolly'S Pub",
#     'Constantines Deli',
#     "Conti'S",
#     'Continental Luncheonette & Deli',
#     'Convivium Osteria',
#     "Coogan'S",
#     "Cookie'S Lounge",
#     'Cool Zone',
#     'Cooper Town Diner',
#     'Coopers Tavern',
#     'Copper Kettle',
#     "Coppola'S",
#     'Coral Diner',
#     'Corato I Pizza & Restaurant',
#     'Corato Pizza Ii',
#     'Cornelia Street Cafe',
#     'Corner Bistro',
#     'Corner Cafe And Bakery',
#     'Corner Gourmet Ii',
#     'Cort Theatre',
#     'Cositas Ricas',
#     'Cosmos Restaurant',
#     'Costco Wholesale',
#     'Country Donuts',
#     'Court Order',
#     'Court Square Diner',
#     'Courtyard By Marriott',
#     "Cousin John'S Cafe And Bakery",
#     'Cowgirl Hall Of Fame',
#     'Coyote Ugly',
#     'Cozy Soup & Burger',
#     'Crab Shanty',
#     'Craft',
#     "Cranberry'S",
#     'Cravath Cafe',
#     'Create & Go',
#     'Creative Cakes',
#     'Creative Edge Caterers',
#     'Credit Agricole',
#     'Credit Agricole-Cbi Executive Room',
#     'Crescent Corner',
#     "Crif Dogs / Please Don'T Tell",
#     'Criminal Court Bldg Cafeteria',
#     'Cronin & Phelan Pub & Restaurant',
#     'Crossbay Diner',
#     'Crossroads (Marriott Marquis)',
#     'Crosstown Diner',
#     'Crown Diner',
#     'Crown Fried Chicken',
#     'Crown Gourmet Deli',
#     'Crystal Curry House',
#     'Crystal Manor',
#     'Crystal Palace',
#     'Crystal Room',
#     'Cuccios Bakery',
#     'Cuchifrito',
#     'Cuchifritos',
#     'Cucina Di Pesce',
#     'Cucina Gourmet',
#     'Cucina Vivolo',
#     'Culinart Cafe',
#     "Cullen'S Tavern",
#     'Cup & Saucer',
#     'Curry In A Hurry',
#     "Curves Gentleman'S Club",
#     'D & P Restaurant & Cocktail',
#     "D'Angelo'S Pizzeria And Restaurant",
#     "D'Aquila Bakery",
#     'D.B.A.',
#     'Da Marino Restaurant',
#     'Da Mikelle Ii',
#     'Da Nico Restaurant',
#     'Da Rosina Restaurant',
#     'Da Silvano Restaurant',
#     'Da Tommasso',
#     'Da Umberto Restaurant',
#     'Da Vinci Pizza',
#     "Daddy'S",
#     'Dagan Pizza',
#     'Dagan Pizza & Dairy Restaurant',
#     'Dairy Luncheonette',
#     'Dairy Palace',
#     'Dakota Diner',
#     'Dallas Bbq',
#     'Dan Tempura',
#     'Dancing Crane Cafe (Bx Zoo)',
#     "Dangerfield'S Night Club",
#     'Dani Pizza And Restaurant',
#     'Daniel',
#     "Daniel'S Bagel",
#     "Daniello'S Pizzeria",
#     'Danny Blaine',
#     "Danny'S Deli",
#     "Danny'S Pizzeria & Cafe",
#     "Danny'S Pizzeria Ii",
#     "Dante'S Gourmet Food",
#     "Dave'S Tavern",
#     'Davis Polk Dining Room',
#     'Dazies Restaurant',
#     'Db Bistro Moderne',
#     'De Robertis Pastry Shop',
#     "Deacon Brodie'S",
#     'Death & Co',
#     "Deb'S",
#     'Debevoise & Plimpton',
#     "Defonte'S Sandwich Shop",
#     'Del Corso Pizzeria',
#     "Del Frisco'S",
#     'Deli Plus ( Inside Port Authority Station)',
#     'Delias Lounge Cafe',
#     'Delight Donut',
#     'Delmonico Gourmet',
#     "Delmonico'S Kitchen",
#     'Delmonicos',
#     'Delta Grill',
#     'Deluxe',
#     'Demarchelier Restaurant',
#     "Dempsey'S Pub",
#     "Denino'S Pizzeria Tavern",
#     "Dennis' Place",
#     "Denny'S Pub",
#     "Desmond'S Tavern",
#     'Desseo Night Club',
#     'Deux Amis',
#     'Devasthanam Canteen',
#     'Devon & Blakely',
#     "Di Luvio'S Deli",
#     'Diamante Poblano Restaurant',
#     "Digby'S",
#     'Dim Sum Go Go',
#     'Dinastia China',
#     'Diner',
#     'Dining Room',
#     "Dino'S Pizza & Pasta",
#     'Distilled',
#     'Dive 75',
#     'Dive Bar',
#     'Divers Cove',
#     'Diwan-E- Khaas',
#     'Diwan-E-Khaas',
#     "Dizzy'S Restaurant",
#     'Dj Reynolds Pub And Restaurant',
#     'Do Hwa',
#     'Doc Holidays',
#     'Doc Watsons',
#     'Doc Wine Bar',
#     'Dock Street Bar & Grill',
#     'Dojo Restaurant',
#     'Dolcino Trattoria Toscana',
#     "Dominick'S Bar & Restaurant",
#     "Domino'S Pizza",
#     'Don Alex Restaurant',
#     'Don Coqui',
#     'Don Filippo Restaurant',
#     'Don Giovanni Restaurant',
#     'Don Paco  Lopez Panderia',
#     'Don Pedro Restaurant',
#     'Don Pepi Pizza',
#     'Don Pepis Delicatessen',
#     'Don Peppe',
#     "Donato'S Pizzeria Restaurant",
#     "Donohue'S Steak House",
#     'Donut Pub',
#     'Donut Stop',
#     'Doral Donuts',
#     "Dorrian'S Red Hand Restaurant",
#     'Dosa Hutt',
#     'Double Dragon',
#     'Douglaston Club',
#     'Douglaston Golf Snacks',
#     'Down The Hatch',
#     'Down Town Association',
#     'Downtown Bakery Ii Mexican Food',
#     'Downtown Deli',
#     "Doyle'S Corner",
#     'Dragon City',
#     'Dragon Land Bakery',
#     'Dream Pizza',
#     'Dublin 6',
#     'Due',
#     "Duffy'S",
#     "Duke'S",
#     'Dunkin Donuts',
#     "Dunkin' Donuts",
#     "Dunkin' Donuts  Baskin Robbins",
#     "Dunkin' Donuts Baskin Robbins",
#     "Dunkin' Donuts, Baskin Robbins",
#     "Dunkin' Donuts/Baskin Robbins",
#     "Dunkin' Donuts/Baskin Robins",
#     "Dunkin' Donuts/Baskin' Robbins",
#     "Dunkin' Donuts/Subway",
#     'Dyckman Bar',
#     'Dyckman Express Restaurant',
#     'Dyker Beach Golf (Grill Room)',
#     'Dyker Park Bagels',
#     "Dylan'S Candybar",
#     'Dynasty',
#     'E & L Bakery & Coffee Shop',
#     'E-Dah Korean Bbq Lounge',
#     'E.A.T. Cafe',
#     'E.J Luncheonette',
#     'Ear Inn',
#     'East Dynasty',
#     'East Japanese Restaurant/ Bar',
#     'East Of Eighth',
#     'Eastwood Manor',
#     'Eat-A-Bagel (Andrew J. Barbery Ferry Boat)',
#     'Eatery Restaurant',
#     'Ebe Ye Yie African Restaurant',
#     "Edward'S",
#     "Egger'S Ice Cream Parlor",
#     'Egyptian Coffee Shop',
#     'El Aguila Bakery',
#     'El Anzuelo Fino Restaurant',
#     'El Azteca Mexican Restaurant',
#     'El Boqueron Tapas Bar & Restaurant',
#     'El Buen Ambiente',
#     'El Cantinero',
#     'El Caramelo Coffee Shop',
#     'El Caribe',
#     'El Castillo De Jagua Rest',
#     'El Castillo De Madison',
#     'El Centro',
#     'El Charro Bakery',
#     'El Charro Espanol',
#     "El Chivito D'Oro Iii",
#     'El Continental Restaurant',
#     'El Cuencanito',
#     'El Dorado Cafe',
#     'El Dorado Sports Lounge',
#     'El Familar Restaurant',
#     'El Gauchito Restaurant',
#     'El Greco Diner',
#     'El Hornero Bakery',
#     'El Lina Restaurant',
#     'El Loco Burrito',
#     'El Malecon Restaurant',
#     'El Mariachi Restaurant',
#     'El Molino Rojo Restaurant',
#     'El Nuevo Amanecer Restaurant',
#     'El Nuevo Ambiente Restaurant',
#     'El Nuevo Cafe Latino',
#     'El Nuevo Conquistador',
#     'El Olivo',
#     'El Paraiso Bar & Restaurant',
#     'El Pollo Peruano',
#     'El Pote Espanol',
#     'El Pulgarcito De America',
#     'El Ranchito De Daisy',
#     'El Rey De La Caridad',
#     'El Rey Mexican Restaurant',
#     'El Rinconcito Restaurant',
#     'El Rio Grande',
#     'El Rumbero Bar Restaurant',
#     'El Salvador Restaurant',
#     'El Sitio Restaurant',
#     'El Tina Fish Market & Seafood Restaurant',
#     'El Vaquero Barras',
#     'Elegante Pizza',
#     "Eleni'S New York",
#     'Elephant & Castle',
#     'Elia',
#     'Elias Corner For Fish',
#     "Elio'S",
#     "Ellen'S Stardust Diner",
#     'Elmhurst Famous Pizza',
#     'Elmo',
#     'Elora Restaurant',
#     'Emerald Pub',
#     "Emilia'S Restaurant",
#     'Emilio Iii Bar',
#     'Empire Szechuan Noodle House',
#     'Empire Szechuan Village',
#     'Empire Wok Kitchen',
#     'Emporium Brasil Restaurant',
#     "Enid'S",
#     'Ennju',
#     'Enzo Cafe',
#     'Erawan Thai Cuisine',
#     "Erin'S Isle",
#     'Erminia Restaurant',
#     'Ernst & Young Cafe',
#     "Errol'S Bakery",
#     'Esca',
#     'Escuelita Club',
#     'Esperanto',
#     'Ess-A-Bagel',
#     'Essex',
#     'Estancia 460',
#     'Estelle',
#     'Estiatorio Milos',
#     'Estihaya Asian Restaurant',
#     'Ethel Barrymore Theater',
#     'Ethos Greek Cuisine',
#     'Eurest Dining Service (American Express)',
#     'Euro Pizza',
#     'Europa Cafe',
#     'Europa Go-Go Dancing',
#     'Europa Night Club',
#     'Euzkadi',
#     'Everest Diner',
#     'Evergreen Restaurant',
#     "Evodio'S Place",
#     'Evolution',
#     'Excelsior Catering',
#     'Exclusive Catering',
#     "Fabiane'S Cafe & Pastry",
#     'Faces & Names',
#     'Failte',
#     'Fame Diner',
#     'Family Corner',
#     'Family Pizza',
#     'Famous Bagel Buffet',
#     "Famous Ben'S Pizza Of Soho",
#     'Famous Famiglia Pizza',
#     'Famous Fish Market',
#     "Famous Joe'S Pizza",
#     'Famous Pizza',
#     'Faros Restaurant',
#     "Fascati'S Pizzeria",
#     'Fay Da Bakery',
#     'Feeding Tree Style West Indian Restaurant',
#     'Fei Teng Bakery',
#     'Felice 64 Wine Bar',
#     'Felidia Restaurant',
#     'Felix',
#     "Fella'S Bar",
#     "Ferdinando'S Restaurant",
#     "Ferrara'S",
#     'Ferris Booth Commons - Alfred Lerner Hall',
#     'Fifth Ave Cafe /Diner',
#     'Fifth Avenue Bingo',
#     'Fine & Shapiro',
#     'Finestra',
#     "Finnegan'S Wake",
#     'Fiorellos',
#     'Fiorentino Ristorante',
#     'Firehouse',
#     'Firenze',
#     'Fireside',
#     'Firozas Roti Bar',
#     'Fish',
#     'Fish Bar',
#     "Fisherman'S Cove",
#     'Fit Cafeteria (Building A)',
#     "Fitzgerald'S Pub",
#     'Flagship Diner',
#     'Flame Restaurant Coffee House',
#     'Flamingo',
#     "Flannery'S Bar",
#     'Flash Dancers',
#     'Flight 151',
#     'Flik International',
#     "Fluffy'S Cafe & Bakery",
#     'Flushing Meadows Pitch And Putt',
#     'Flute',
#     "Foley'S N.Y. Pub And Restaurant",
#     'Fontana Famous Pizza & Gyro',
#     'Food Fair Deli & Pizza',
#     'Food For Thought Catered Events',
#     'Food For Thought Library Cafe',
#     'Food Mart Deli',
#     'Food Merchants',
#     'Footprints Cafe',
#     'Ford Foundation Cafeteria',
#     'Fordham Fried Chicken & Sea Food',
#     'Fordham Seafood And Chicken',
#     'Fordham University - Mcginley Center',
#     'Fordham University - Millenium Grill',
#     'Fordham University - Ram Cafeteria',
#     'Fordham University - Student Deli',
#     'Fordham University/Mcginley Center/Ramskeller Kitchen',
#     'Forest Hills Coffe Shop',
#     'Forest Hills Spa',
#     'Forest Park Golf Course',
#     'Forlinis Restaurant',
#     'Fortunato Bros Cafe & Bakery',
#     'Fountain Of Youth Health Spa Juice Bar & Dinner',
#     'Four Seasons Hotel',
#     'Fragole',
#     "Francesco'S Pizzeria Restaurant",
#     "Francisco'S Centro Vasco",
#     'Franco Bakery',
#     'Frank',
#     "Frank'S Pizza",
#     "Frank'S Pizza Restaurant",
#     "Frank'S Pizzeria",
#     "Frank'S Place",
#     "Frank'S Soup Bowl",
#     'Frankie & Johnnies Steakhouse',
#     'Fratelli Pizza',
#     "Fred'S",
#     "Fred'S At Barney'S",
#     "Freddie & Pepper'S Pizza",
#     'French Roast',
#     'Fresco',
#     'Fresco Bar Cafe Restaurant',
#     'Fresco On The Go',
#     "Fresh Meadow'S Pizza & Restaurant",
#     'Friars National Assoc.',
#     'Friend Of A Farmer',
#     "Friend'S Tavern",
#     'Friends Deli',
#     'Front Street Pizza',
#     'Frost Restaurant',
#     'Fuji Bakery',
#     'Full Moon Pizza',
#     'Funtopia Usa',
#     'G',
#     'G.P. Diner',
#     "Gabriel'S Bar & Grill",
#     "Gaby'S Pizza",
#     'Galicia Bar',
#     'Galicia Restaurant',
#     "Gallagher'S 2000",
#     'Gandhi',
#     'Gandhi Indian Cuisine',
#     'Garden Cafe Restaurant',
#     'Garden Grill',
#     'Garden Of Eat-In',
#     "Gargiulo'S Restaurant",
#     "Gary And Gino'S",
#     'Gaslight',
#     "Gaudio'S Pizzeria",
#     'Geido Restaurant',
#     'Gemini Diner',
#     "Gemini'S Lounge",
#     "Gene'S Coffee Shop",
#     "Gene'S Resturant",
#     'Genesis # 1 West Indian',
#     "Gennaro'S Catering Hall",
#     "Gennaro'S Rest & Pizzeria",
#     'Gente',
#     'George Keeley',
#     'Georges Restaurant',
#     'Georgia Diner',
#     'Georgios Country Grill',
#     'Gershwin Theatre',
#     'Ghandi Cafe',
#     'Giacomo Fine Foods',
#     'Gian & Pier Bakery',
#     'Giando',
#     'Giardino Ristorante',
#     "Gigi'S Pizzeria",
#     'Gigino At Wagner Park',
#     'Gigino Trattoria',
#     "Gina'S Pizza",
#     'Ginger',
#     "Ginger'S Bar",
#     "Gino'S Pastry Shop",
#     "Gino'S Pizza",
#     "Gino'S Pizzeria",
#     "Gino'S Pizzeria Restaurant",
#     'Gioiosa Caffe Expresso',
#     "Giorgio'S Of Gramercy",
#     'Giovanni 25',
#     "Giovanni'S Restaurant & Cafe",
#     'Giralda Bakery',
#     'Girasol Bakery',
#     "Glaser'S Bakery",
#     'Glatt Kosher Family Chinese Restaurant',
#     "Gleason'S Cafe",
#     "Glen Patrick'S Pub",
#     'Glen Roy Bar And Grill',
#     'Glen Terrace',
#     "Glenda'S Restaurant",
#     'Glendale Bakeshop & Cafe',
#     'Glendale Pizza',
#     'Glenlo Tavern',
#     "Gloria'S In And Out #3",
#     'Glorious Food',
#     'Glory Deli',
#     'Gnocco',
#     'Gold Bar B',
#     "Gold'S Gym",
#     'Golden Crown Bakery',
#     'Golden Dove Diner',
#     'Golden Horse Chinese Rest',
#     'Golden Krust Caribbean Bakery & Grill',
#     'Golden Pavillion',
#     'Golden Pizza',
#     'Golden Theatre',
#     'Good Enough To Eat (A.G. Bistro)',
#     'Good Restaurant',
#     'Good Shepherd Services',
#     "Goody'S Bbq",
#     "Goody'S Spanish Food",
#     'Gotham Bar & Grill',
#     'Gotham Cafe (Inside Holiday Inn)',
#     'Gottscheer Hall',
#     'Gourmet Grill',
#     'Gourmet On J',
#     'Gradisca Restaurant',
#     'Gramercy Cafe',
#     'Grand Avenue Pizza',
#     'Grand Canyon',
#     'Grand Havana Room',
#     'Grand Hyatt New York Hotel',
#     'Grand Morelos Diner & Bakery',
#     'Grand Plaza',
#     'Grand Street Deli & Mini Market',
#     'Grandstand Tavern',
#     'Grano Trattoria',
#     'Grassroot Tavern',
#     "Gray'S Papaya",
#     'Great Jones Cafe',
#     'Great Kills Yacht Club',
#     'Great N.Y. Noodletown',
#     'Great Wall Restaurant',
#     'Green House Cafe',
#     'Green Pavilion Restaurant & Sports Lounge',
#     'Green Trees',
#     'Greenhouse Cafe (557 Broaday) Scholastic Building',
#     'Greenpoint Tavern',
#     'Greenwich Village Bistro',
#     'Greenwood Bakery',
#     'Griffis Faculty Club',
#     "Grini'S Grill & Restaurant",
#     'Grotto Azzura Pizzeria',
#     'Ground Level Beer Pub',
#     "Guastavino'S",
#     'Guayoyo',
#     'Gun Post Lanes Snack Bar',
#     'Gurra Cafe',
#     "Gussy'S Bar",
#     'Gustosa Pizza',
#     'Guy & Gallard',
#     'Gyro King',
#     'H & H Midtown Bagels East',
#     'Haagen-Dazs',
#     'Hairos Night Club',
#     'Hale & Hearty Soups',
#     'Hallmark Deli',
#     'Hallo Berlin',
#     'Hamilton Deli',
#     'Hampton Chutney Company',
#     'Han Bat Restaurant',
#     'Han Gawi',
#     'Hana Sushi',
#     'Hangar Bar',
#     'Hanover Gourmet Deli',
#     'Hanson Gourmet Deli & Cafe',
#     'Hanson Restaurant And Pizzeria',
#     'Hapisgah Restaurant',
#     'Happy Fortune',
#     'Happy Fortune Ii',
#     'Happy Garden',
#     'Happy Restaurant',
#     'Harbor Pizza',
#     'Harlem Bar-B-Q',
#     'Harmonie Club',
#     "Harriet'S Kitchen",
#     "Harry'O",
#     "Harry'S Burrito Junction",
#     'Haru',
#     'Haru Sake Bar',
#     'Harvard Club',
#     'Hasaki Restaurant',
#     'Hatsuhana Restaurant',
#     'Havana Alma De Cuba',
#     'Havana Ny',
#     'Haveli',
#     'Health King',
#     "Healy'S Pub",
#     'Heartland Brewery',
#     "Hector'S Cafe & Diner",
#     'Heidelberg Restaurant',
#     'Heights Cafe',
#     "Hell'S Kitchen",
#     'Hello Deli',
#     "Henny'S Restaurant",
#     'Henrietta Hudson',
#     'Henry St. Ale House',
#     "Henry'S",
#     "Henry'S End",
#     'Hero Champ',
#     'Hi Fi',
#     'Hi Life Bar & Grill',
#     'Hidden Cottage',
#     'Highlands Cafe Restaurant',
#     'Highway Bagels',
#     'Highway Deli And Coffee Shop',
#     'Hill Tap Tavern',
#     'Hillel Bagels',
#     'Hillside Gourmet',
#     'Hillside Swimming Club',
#     'Hillstone Manhattan',
#     "Hillstone'S",
#     'Ho Mei Restaurant',
#     'Hogs & Heifers',
#     'Holland Bar',
#     "Holtermann'S Bakery",
#     'Home Deli & Catering',
#     'Homestretch Bar',
#     'Hong Cheong',
#     'Hong Fung Bakery',
#     'Hong Kong Restaurant',
#     'Hooters',
#     'Hop Kee Restaurant',
#     'Hop Lee Kitchen',
#     'Hop Won Express',
#     'Hornado Ecuatoriano',
#     'Hot & Crusty Bagels Cafe',
#     'Hot & Crusty Bakery',
#     'Hot Bagels',
#     'Hot Bagels & Cafe',
#     'Hotel Carlyle',
#     'House Of Brews',
#     'Housing Works Food',
#     'Hsbc Bank',
#     'Hudson Bar And Books',
#     'Hudson Place',
#     "Hunan ''K'' Chinese Restaurant",
#     'Hunan Balcony',
#     'Hungarian Pastry Shop',
#     "Hunter'S Steak & Ale House",
#     "Hurley'S Saloon",
#     'Hyatt, Ny Central/Room Service',
#     'Hyo Dong Gak',
#     'I Trulli Restaurant',
#     'I.O. Cafe',
#     'Ibm Executive Dining Room',
#     'Ideal Donut',
#     "Ifh El Buffet Restaurant  Alberto'S Mofongo House",
#     "Iggy'S",
#     'Igloo Ice Cream Cafe',
#     'Iguana Restaurant',
#     'Iguanas',
#     'Ihawan',
#     'Ihop',
#     'Il Buco Restaurant',
#     'Il Cantinori Restauraunt',
#     'Il Cortile Restaurant',
#     'Il Fornetto Trattoria Cafe',
#     'Il Mulino',
#     'Il Palazzo',
#     'Il Postino',
#     'Il Posto',
#     'Il Posto Accanto',
#     'Il Riccio Restaurant',
#     'Il Toscano Ristorante',
#     'Il Vagabondo Restaurant',
#     'Il Violino',
#     "Ilda'S Place Ii",
#     'Imperial Biker Bar',
#     'Imperial Coffee House',
#     'Imperial Theatre',
#     'India Passage Restaurant',
#     'Indian Taj',
#     'Indigo Indian Cuisine',
#     'Indo Chine',
#     'Ing Forman Selz',
#     'Intermisson Cafe',
#     'International Restaurant',
#     'Internationalhouse',
#     "Iona'S Bar",
#     'Ipanema Bar',
#     'Ipanema Restaurant',
#     "Irene'S Place",
#     'Irish Brigade',
#     'Irish Cottage',
#     'Irish Eye Bar',
#     'Irish Punt',
#     'Iroha Japanese Restaurant',
#     'Iron Chef House',
#     "Isabela'S Mexican Cuisine",
#     'Ise Japanese Restaurant',
#     'Isla Restauraunt',
#     'Island',
#     'Island Burgers And Shakes',
#     'Island Chateau',
#     'Island Shores',
#     'Island Taste',
#     'Isle Of Capri Resturant',
#     'Istanbul Restaurant',
#     'Italian Village Restaurant Pizzeria',
#     'Italy Pizza & Restaurant',
#     'Izalco Restaurant',
#     'J & C Seafood',
#     'J & J Restaurant & Cuchifritos',
#     'J & M Bakery',
#     'J & R Pizza',
#     'J & S Pizza',
#     "J 'S Pizza",
#     'J And D Pizza',
#     'J And L Deli',
#     'J&V Famous Pizza',
#     'J.E. Bakery',
#     'J.J. Bubbles',
#     "J.R'S Cabaret",
#     "Jack'S Pizza & Pasta",
#     "Jack'S Restaurant & Bar",
#     "Jackie'S West Indian Bakery",
#     'Jacks Ale House',
#     'Jackson Diner Indian Cuisine',
#     'Jackson Hole',
#     'Jackson House Restaurant',
#     "Jacque'S Cafe",
#     'Jade Island Restaurant',
#     'Jade Seneca Oriental Restaurant',
#     "Jahn'S Restaurant",
#     'Jaiya Thai Oriental Restaurant',
#     "Jake'S",
#     "Jake'S Dilemma",
#     "Jake'S Steakhouse",
#     'Jalapeno Deli',
#     'Jamaican Flavours',
#     'Jane',
#     'Japan Airlines Lounge',
#     'Jardin De China Rest',
#     'Java Girl',
#     'Java Restaurant',
#     'Jays Restaurant',
#     'Jean Danet French Pastry',
#     'Jean Georges',
#     "Jennifer'S Restaurant",
#     "Jentana'S Pizza",
#     'Jerk Hut',
#     "Jerry'S 637 Diner",
#     'Jerusalem Pizza',
#     'Jewel Bako',
#     'Jewish Theological Seminary',
#     'Jg Melon Restaurant',
#     'Jian On Chinese Restaurant',
#     "Jim Brady'S Restaurant",
#     "Jimbo'S Hamburger Place",
#     "Jimbo'S Hamburgers",
#     'Jimbos Hamburger Palace',
#     'Jimmy Max Restaurant',
#     "Jimmy Ryan'S",
#     "Jimmy'S Corner",
#     'Jing Fong Restaurant',
#     'Jj Garden Restaurant',
#     "Jj Peabody'S",
#     'Jo Jo',
#     "Jody'S Club",
#     "Joe & Pat'S Pizzeria",
#     'Joe Allen Restaurant',
#     "Joe'S Of Ave U",
#     "Joe'S Pizza",
#     "Joe'S Place",
#     "Joe'S Pub",
#     "Joe'S Shanghai Restaurant",
#     "Joey'S Place",
#     'John & Joe Pizzeria & Restaurant',
#     'John & Tonys Pizza',
#     'John Hughes Knights Of Columbus Club',
#     "John Mulligan'S Fireside Pub",
#     "John'S Donut & Coffee Shop",
#     "John'S Pizza",
#     "John'S Pizzeria",
#     "John'S Restaurant",
#     "Johnny Mack'S Bar",
#     'Johnny Pumps',
#     "Johnny'S Bar",
#     "Johnny'S O'S",
#     "Johnny'S Reef Restaurant",
#     'Johns Cafe & Resturant',
#     "Jojo'S Pizza",
#     'Jolly Tinker',
#     'Jones Reavis & Pague Llp',
#     "Joseph'S Ristorante",
#     'Joshua Tree',
#     "Josie Wood'S Pub",
#     "Josie'S Restaurant",
#     'Joya',
#     "Joyce'S Tavern",
#     "Joyce'S West Indies Restaurant",
#     'Jp Morgan Chase Bank Cafeteria',
#     "Jp'S Bar",
#     "Jp'S Waterside Restaurant",
#     'Judge Roy Bean',
#     'Juice For Life',
#     'Juice Generation',
#     'Juicy Lucy',
#     "Juicy Lucy'S",
#     'Jules Bistro',
#     'Julius',
#     'Julliard & S.A.B. Cafeteria',
#     "Junior'S",
#     "Junior'S Cafe",
#     'Juniors',
#     "K'S Cafeteria",
#     'Kabab Cafe',
#     "Kabooz'S Bar & Grille",
#     'Kabul Kabab House',
#     'Kana Tapas Bar & Restaurant',
#     'Kanes Deli Diner',
#     'Kang Suh Korean Restaurant',
#     'Karavas Pizza N Pita',
#     'Karavas Place',
#     'Karma',
#     'Kasteli Ii',
#     "Katz'S Delicatessen",
#     'Keats Restaurant',
#     'Kebab House',
#     'Keenans',
#     'Keens Steakhouse',
#     'Kelley & Ping',
#     "Kelly'S Pub",
#     "Kelly'S Restaurant & Pizza",
#     "Kelly'S Tavern",
#     'Kennedy Fried Chicken',
#     'Kent Theatre',
#     'Kentucky Fried Chicken, Tim Hortons',
#     'Kentucky Fried Chicken/ Island Cuisine',
#     'Kenyon & Kenyon Cafeteria',
#     'Kerry Hills Pub',
#     'Kew Gardens Cinemas',
#     'Kfc/Taco Bell',
#     'Khyber Pass',
#     'Khyber Restaurant',
#     'Kiddie Cakes',
#     "Kids 'N' Action",
#     'Killarney Rose',
#     "Killarney'S Pub",
#     "Killmeyer'S Old Bavaria Inn.",
#     'Kimchee Korean Restaurant',
#     'King Yum Restaurant',
#     "King'S Arms Restaurant",
#     'Kings Carriage House',
#     'Kings County Cafeteria Bldg T',
#     'Kingston Tropical Bakery',
#     'Kinsale Tavern',
#     'Kismat Indian Cuisine',
#     'Kitchenette Uptown',
#     'Kitty Kiernans',
#     'Knapp St Pizza',
#     'Knapp St Pizza Ii',
#     'Knickerbocker Bar & Grill',
#     'Knickerbocker Club',
#     'Knights Of Baron Dekalb',
#     'Ko-Sushi Japanese Restaurant',
#     'Koliba Restaurant',
#     'Korean Lounge',
#     'Korner Pizzeria',
#     'Kosher Bagel Hole',
#     'Kosher Delight',
#     'Kosher Deluxe',
#     'Kosher Hut Of Brooklyn',
#     'Kosher Island',
#     'Koyzina Kafe',
#     'Krispy Pizzeria',
#     "Kristy'S Restaurant",
#     'Krystal European Bakery',
#     'Krystal Pastry Shop',
#     'Kum Gang San',
#     'Kum Gang San Korean Restaurant',
#     'Kum Kau Kitchen',
#     'Kunjip Restaurant',
#     'Kurumazushi Restaurant',
#     'L & M Italian Deli & Catering',
#     "L'Express",
#     'L. A. Pizzeria',
#     'La Antioquena Bakery Ii',
#     'La Bagel Delight',
#     'La Baraka Restaurant',
#     'La Barca Restaurant',
#     'La Bella Pizza',
#     'La Bella Rosa Bakery',
#     'La Boina Roja Steak House',
#     'La Bonbonniere',
#     'La Bonne Soupe Bistro',
#     'La Bruschetta Restaurant',
#     'La Cabana',
#     'La Cabana Argentina',
#     'La Cabana Jarabacoa Restaurant',
#     'La Cabana Restaurant',
#     'La Cabana Salvadorena Restaurant',
#     'La Candela Espanola',
#     'La Caridad 78',
#     'La Caridad Restaurant',
#     'La Carreta Restaurant',
#     'La Casa Bella',
#     'La Casa Del Pollo Restaurant',
#     'La Cucina',
#     'La Delice Pastry Shop',
#     'La Dinastia',
#     'La Dolce Italia Bakery',
#     'La Familia Restaurant',
#     'La Fe Restaurant',
#     'La Flor Bakery Cafe',
#     'La Fusta Restaurant',
#     'La Giara',
#     'La Gioconda',
#     'La Gourmet',
#     'La Grenouille',
#     'La Grotta Ristorante',
#     'La Isla',
#     'La Isla Cuchifritos',
#     'La Isla Restaurant',
#     'La Lechonera Criolla',
#     'La Lechonera Restaurant',
#     'La Linea Lounge',
#     'La Locanda Restaurant',
#     'La Luncheonette',
#     'La Mangeoire',
#     'La Mediterranee Restaurant',
#     'La Mela Restaurant',
#     'La Mirabelle Restaurant',
#     'La Nortena Express Restaurant',
#     'La Nueva Giralda Bakery',
#     'La Nueva Playitas',
#     'La Nueva Victoria Restaurant',
#     'La Palapa',
#     'La Palina Restaurant',
#     'La Parisienne Diner',
#     'La Perla Mexicana',
#     'La Piazza Pizzeria & Restaurant',
#     'La Piazzetta',
#     'La Picada Azuaya Restaurant',
#     'La Pizza Fresca',
#     'La Ripaille Restaurant',
#     'La Rivista Restaurant',
#     'La Sabrosura',
#     'La Sorrentina Pizzeria Restaurant',
#     'La Sorrentina Ristorante',
#     'La Strada Restaurant',
#     'La Taza De Oro Restaurant',
#     'La Verite Restaurant Bar',
#     'La Vienesa Spanish Bakery',
#     'La Villa De Pizza & Restaurant',
#     'La Villa Pizzeria',
#     'La Villita Restaurant',
#     'Labella Ferrara',
#     "Labetti'S Post # 2159",
#     'Lace',
#     'Laguardia Courtyard Hotel By Marriott',
#     'Lahore Delicatessen',
#     'Lamarca Pasta Restaurant',
#     'Landmark Coffee Shop',
#     'Lane Deli & Catering',
#     'Langans Bar & Restaurant',
#     "Lanza'S",
#     'Las Isla Restaurant',
#     'Last Stop Restaurant',
#     'Laterna Taverna',
#     'Latin American Restaurant',
#     'Latin Bakery',
#     'Latino Restaurant',
#     'Latourette Golf Course',
#     'Lattanzi',
#     "Lavelle'S Admiral'S Club",
#     'Lazard Freres',
#     'Lazzaras Pizza Cafe',
#     'Lb Spumoni Gardens',
#     'Le Bateau Ivre',
#     'Le Bernardin',
#     'Le Bon Cafe',
#     'Le Charlot',
#     'Le Colonial',
#     'Le Gigot',
#     'Le Glacier',
#     'Le Marais',
#     'Le Mirage Cafe',
#     'Le Monde',
#     'Le Pain Quotidien',
#     'Le Paris Bistrot Francais',
#     'Le Perigord',
#     'Le Petit Cafe',
#     'Le Rivage',
#     'Le Singe Vert',
#     'Le Train Bleu & B Cafe',
#     'Le Trapeze',
#     'Le Zie Trattoria',
#     "Lee'S Villa Chinese Restaurant",
#     'Lefkos Pygos Cafe',
#     "Legend'S Pub",
#     'Legends Bar & Grill',
#     'Lena Restaurant',
#     'Lenfest Cafe - Jerome Green Hall',
#     "Lenihan'S Saloon",
#     "Lenny & John'S Pizza",
#     "Lenny'S Bagels",
#     "Lenny'S Clam Bar",
#     "Lenny'S Pizza",
#     'Lenox Hill Grill/Pizza',
#     'Leon Bakery',
#     'Leonidas',
#     'Les Halles',
#     'Levain Bakery',
#     'Lexicon',
#     'Lexington Bar And Books',
#     'Lexington Candy Shop',
#     'Lexler Deli',
#     "Li Greci'S Staaten Restaurant",
#     'Liberato Restaurant',
#     'Lichee Nut',
#     'Liffy Ii Bar',
#     'Lighthouse Cafe Restaurant',
#     "Lil Frankie'S Pizza",
#     "Lily'S Bar @ Roger Smith Hotel",
#     'Lin Home Chinese Restaura',
#     "Lin'S Garden",
#     'Lincoln Plaza Cinemas',
#     'Lindenwood Diner',
#     "Lindy'S",
#     'Ling Kee Beef Jerky',
#     'Lite Bites & Grill',
#     'Lite Delights',
#     'Little Brown Jug',
#     'Little Italy Pizza',
#     'Little Pie Company',
#     'Little Poland Restaurant',
#     "Little Sal'S Italiano",
#     "Little Vincent'S Pizza Restaurant",
#     'Live Bait Bar & Restaurant',
#     "Ljubo'S Pizzeria",
#     "Loduca'S Pizza",
#     "Loeser'S Hebrew National",
#     'Lok Sing Chinese Restaurant',
#     'Loki Bar & Benchmark Restaurant',
#     "Lolita'S Restaurant",
#     "Lombardi'S",
#     'Lomzymianka Restaurant',
#     'London Lennies',
#     'Longacre Theatre',
#     "Lopez'S Pizzeria And Coffee Shop",
#     'Lords Bakery',
#     "Lorenzo & Maria'S",
#     'Lorenzos Bar & Grill (Hilton Garden)',
#     'Los Amigos Mexican Restaurant',
#     'Los Angeles Bakery',
#     'Los Arrieros Restaurant',
#     'Los Girasoles Restaurant',
#     'Los Papis Restaurant',
#     'Los Toldos Restaurant',
#     'Lotos Club Grill Room',
#     'Loui Seafood',
#     "Louie'Sdale Diner",
#     "Lovell'S Guiding Light",
#     "Lucho'S Place",
#     'Lucia Pizza',
#     'Lucien Restauraunt',
#     'Lucky Deli',
#     'Lucky House Chinese Kitchen',
#     'Lucky House Restaurant',
#     'Lucky Pizza',
#     'Lucky Star Cafe',
#     'Lucky Star Restaurant',
#     'Lucky Strike',
#     'Lucys',
#     "Luigi'S Catering",
#     "Luigi'S Pizza",
#     "Luigi'S Pizza & Restaurant",
#     "Luigi'S Pizzeria",
#     "Luigi'S Restaurant",
#     "Luke'S Bar & Grill",
#     "Lulu'S Bakery",
#     "Lulu'S Coffee Shop",
#     'Lunch Box',
#     'Lunella Restaurant',
#     'Lung Moon Bakery',
#     'Lunt Fontanne Theater',
#     'Lupa',
#     "Lupe'S East L.A. Kitchen",
#     "Lusardi'S Restaurant",
#     'Lyceum Theatre',
#     'M & M Bar & Grill',
#     'M. Restaurant',
#     'Macelleria Restaurant',
#     'Mad River Bar & Grille',
#     "Madame Tussaud'S",
#     'Madame X',
#     'Madiba',
#     'Madison Bistro',
#     'Madison Square',
#     "Madison'S",
#     'Madras Mahal',
#     'Maggie Mays',
#     'Maggies Place',
#     "Maguire'S Public House",
#     'Maharaja Quality Sweets',
#     'Majestic Pizza',
#     'Majestic Theater',
#     'Make My Cake',
#     "Malachy'S",
#     'Malaga Restaurant',
#     'Malecon Restaurant',
#     "Maloney'S Bar",
#     "Mama Carmela'S",
#     'Mama Lucia',
#     "Mama'S Fried Chicken",
#     'Mamoun Falafel',
#     'Mana',
#     'Manducatis',
#     "Manetta'S Ristorante",
#     'Mangez Avec Moi',
#     'Manhattan Courtyard',
#     'Manhattan Diner',
#     'Manhattan Espresso',
#     'Manhattan Monster',
#     'Manhem Club',
#     'Manna House',
#     'Manna House Bakery',
#     'Manna One Bakery',
#     'Manna Restaurant Ii',
#     "Manny'S Cafe Family Restaurant",
#     "Manny'S Grill",
#     'Manon Cafe / Leonidas',
#     'Manor House Restaurant',
#     'Mansions Cater',
#     'Marathon Food Shop',
#     'Marbella Restaurant',
#     'Marchis Restaurant',
#     'Marco Polo Ristorante',
#     'Margherita Pizza',
#     'Maria Pia',
#     'Maria Ristorante',
#     'Mariella Pizza',
#     'Maries Crisis Cafe',
#     'Marina Cafe',
#     'Marina Delray',
#     'Mariner Inn',
#     "Marino'S Pizza & Restaurant",
#     "Mario'S Pizza",
#     "Mario'S Restaurant",
#     'Marios Pizzeria',
#     'Mariott Marquis/Crossroads Bar',
#     'Market Cafe',
#     'Market Place Pizza',
#     'Market Restaurant (C-D Block)',
#     'Marquet Fine Pastry',
#     'Marquis Theater',
#     'Marriott Marquis - Main Kitchen',
#     'Marriott Marquis Pastry Shop',
#     'Marseille',
#     "Marty O'Brien'S",
#     'Marumi',
#     'Maruzzella',
#     "Mary Ann'S",
#     "Mary'S Fish Camp",
#     'Masawa',
#     'Master Wok',
#     'Mateus Restaurant',
#     "Matt'S Grill Restaurant",
#     'Maurya Restaurant',
#     'Max Soha',
#     'May May Kitchen',
#     'Maya',
#     'Mayer, Brown & Platt',
#     'Maz Mezcal',
#     "Mc Guinness'S",
#     "Mcaleer'S Pub",
#     "Mccabe'S Bar Car",
#     'Mccaffrey And Burke',
#     "Mccann'S Pub",
#     "Mccoy'S Pub",
#     'Mcdonald Avenue Diner',
#     "Mcdonald'S",
#     "Mcdonald'S (Macy'S 7Th Fl)",
#     'Mcdwyers Pub',
#     'Mcgees Pub',
#     'Mcgraw Hill Executive Dining',
#     'Mcloughlins Bar',
#     'Mcquaids Public House',
#     "Mcsorley'S Old Ale House",
#     'Me & My Eggroll',
#     'Mediterraneo',
#     'Mee Sum Coffee Shop',
#     'Mehak',
#     'Mejlander & Mulgannon',
#     'Melody Lanes',
#     'Members Dining Room @ The Met Museum',
#     'Memo Shish Kebab',
#     'Memories Lounge',
#     "Mendy'S",
#     'Mercer Kitchen',
#     'Mercury Bar',
#     'Mesivta Eitz Chaim',
#     'Meskerem',
#     'Metro Coffee Shop @ Jetro',
#     'Metro Diner',
#     'Metro Grill',
#     'Metropolitan',
#     'Metropolitan Club',
#     'Metropolitan Food Cafe Of Brooklyn College',
#     'Metropolitan Museum Employee Cafeteria',
#     'Metrostar Cafe',
#     'Mexican Radio',
#     'Mexico Lindo Restaurant',
#     "Mezcal'S Dos Restaurant",
#     "Mezcal'S Restaurant",
#     'Mezcals Restaurant',
#     'Mezzaluna',
#     'Mezzogiorno',
#     'Mi Pueblito Bakery/Comida Tipica Mexicana',
#     'Mi Sueno Restaurant',
#     "Michael Jordan'S Steak House - In Grand Central",
#     "Michael'S",
#     "Michael'S Pastry Shop",
#     "Michael'S Restaurant",
#     "Michelle'S Cocktail Lounge",
#     'Midway Cinemas',
#     "Mike'S Coffee Shop",
#     "Mike'S Donuts",
#     "Mike'S Pizza",
#     "Mike'S Place",
#     "Mike'S Pub",
#     'Mikes Pizza',
#     'Milan Sports Bar',
#     'Milanes Spanish Restaurant',
#     'Mill Basin Kosher Deli',
#     'Mill Korean Restaurant',
#     "Millie'S Deli",
#     'Million Deli',
#     'Mimis Restaurant & Bar',
#     'Minar Indian Restaurant',
#     'Mini Star Restaurant',
#     'Minitalia Pizzeria',
#     'Minskoff Theater',
#     'Miracali Bakery',
#     'Mirage Diner Restauraunt',
#     'Mishima Restaurant',
#     "Miss Lily'S 7A",
#     "Mitchell'S Restaurant",
#     'Miyagi Japanese Home Cooking',
#     'Modern Gourmet',
#     "Moe'S Southwestern Grill/Charley'S",
#     'Molly Wee Pub',
#     "Molly'S",
#     'Molyvos',
#     "Mom'S Fried Chicken",
#     'Moms Luncheonette',
#     "Mona'S",
#     'Mondial Bakery',
#     'Monster Sushi',
#     "Monte'S",
# ...
#     'Serendipity 3',
#     'Session 73',
#     'Sette Mezzo',
#     'Seuda Foods',
#     'Seven Bar & Grill',
#     'Seven Stars Bakery',
#     'Seville Restaurant',
#     'Shabu Tatsu',
#     'Shabu-Shabu 70 Restaurant',
#     'Shade',
#     'Shalon Restaurant',
#     'Shamrock Inn',
#     'Sharaku Japanese Restaurant',
#     'Sharmel Caterers',
#     "Shashemene Int'L Restaura",
#     'Sheas Emerald',
#     'Sheepshead Bay Yacht Club Bar',
#     'Shell Lanes',
#     'Shem Tov',
#     'Shemtov Manor',
#     "Shenanigan'S",
#     'Shenanigans Pub',
#     'Shimons Kosher Pizza',
#     'Shore Haven Diner',
#     'Short Stop Restaurant',
#     "Showman'S Cafe",
#     'Shubert Theater',
#     'Shun Lee',
#     'Shun Lee Palace Restaurant',
#     'Sideshows By The Seashore',
#     'Sidewalk Bar & Restaurant',
#     'Sido Falalel & More',
#     'Silver Moon Bakery',
#     'Silver Spurs/Molcajate Taqueria',
#     'Silver Star Restaurant',
#     'Simone Bar Cafe',
#     'Simpson Thacher And Bartlet Cafe',
#     'Sing Sing Karaoke',
#     'Singas Famous Pizza',
#     "Sissy Mcginty'S",
#     'Sisters Cuisine',
#     'Sistina Restaurant',
#     'Sizzler',
#     'Skadden Arps, Slate',
#     'Skylight Diner',
#     "Smiler'S",
#     "Smiler'S Deli",
#     'Smiling Pizza',
#     'Smith & Wollensky',
#     'Smoke',
#     'Snack',
#     'Snack Bar (Located Between A-B Between Fancy Food And Masters)',
#     'Snack Time Grill',
#     'Snacks-N-Wheels',
#     'Snafu',
#     "Sob'S",
#     'Soba Nippon Japanese Restaurant',
#     'Soba-Ya',
#     'Society Of Illustrators',
#     'Soda Bar',
#     'Sodexo',
#     'Soho Grand Hotel',
#     'Solas',
#     'Solera Restaurant',
#     'Sombrero Mexican Restaurant',
#     "Sonny'S Heros",
#     'Sony Music Employee Cafeteria',
#     "Sophie'S Restaurant",
#     'Sotto Voce Restaurant',
#     'Souen Restaurant',
#     'South Shore Swimming Club',
#     "South'S",
#     'Souvlaki House',
#     'Soy',
#     'Spain Restaurant & Bar',
#     'Sparks Steak House',
#     'Speedy Deli',
#     'Spirit Of New Jersey',
#     'Spirit Of New York',
#     'Spiros Restautrant',
#     "Spolini'S",
#     'Spoon Bread Catering',
#     'Sports Center At Chelsea Piers (Sushi Bar)',
#     'Sports Center Cafe',
#     'Sports Mania Bar & Grill',
#     "Spoto'S Restaurant",
#     'Spring St. Natural Restaurant',
#     'Springfield Diner',
#     'St Lucian Paradise',
#     "St. Dymphna'S",
#     'St. Marks Ale House',
#     'Stage Door Deli',
#     'Stage Restaurant',
#     'Stand # 210',
#     'Stand # 326',
#     'Star Lite Deli',
#     'Starbucks Coffee',
#     'Starbucks Coffee # 7463',
#     'Starbucks Coffee # 7540',
#     'Starbucks Coffee #7344',
#     'Starbucks Coffee #7358',
#     'Starbucks Coffee #7416',
#     'Starbucks Coffee #7682',
#     'Starbucks Coffee (Bank Of America Building)',
#     'Starbucks Coffee (Store #7216)',
#     'Starbucks Coffee (Store #7555)',
#     'Starbucks Coffee (Store #7577)',
#     'Starbucks Coffee (Store #7587)',
#     'Starbucks Coffee (Store #7696)',
#     'Starbucks Coffee (Store 7261)',
#     'Starting Gate',
#     'Steinway Billiard',
#     'Step In Restaurant & Lounge',
#     "Steve Chu'S Deli & Grocery",
#     "Steve'S Bakery",
#     "Steve'S Coffee Shop",
#     'Stir Cafe',
#     'Strauss Bakery',
#     'Strictly Vegetarian',
#     'Strokos Gourmet Deli',
#     'Strokos Pizza Deli',
#     'Stromboli Pizza',
#     'Studio 46',
#     'Studio Cafe 59',
#     'Stuyvesant Yacht Club',
#     'Subway',
#     'Subway / Twin Donut',
#     'Sugar Bar',
#     'Sugar Bun Bakery',
#     'Sugar City Bakery',
#     'Sugar Factory',
#     'Sugar Hill Restaurant, Supper Club And Disco',
#     'Sugiyama Restaurant',
#     'Sullivan & Cromwell',
#     "Sunberry'S",
#     'Sunflower Cafe',
#     'Sunrise Coffee Shop',
#     'Sunset Park Diner & Donuts',
#     'Sunset Pizzeria',
#     'Supernova-Novotel Hotel',
#     'Supper',
#     'Surf & Turf Restaurant',
#     'Surf Bar',
#     'Sushi Damo',
#     'Sushi Family',
#     'Sushi Of Gari',
#     'Sushi Samba #7',
#     'Sushi Zen',
#     'Sushiden',
#     'Sushiya Japanese Restaurant',
#     "Susie'S Pies",
#     'Sutton Cafe Restaurant',
#     'Sutton Pizza & Gyro',
#     'Sweet & Vicious',
#     'Sweet Chef Southern Styles Bakery',
#     'Sweet Life Cafe',
#     'Swift',
#     "Swifty'S",
#     'Swing 46 Jazz And Supper Club',
#     'Swiss International Airlines Lounge',
#     "Sybil'S Bakery",
#     "Sylvia'S Restaurant",
#     'Symposium Greek Restaurant',
#     'Szechuan Delight Restaurant',
#     'Szechuan Kitchen',
#     "T & G Whitney'S",
#     'T-Bar Steak & Lounge',
#     'T-Bone Diner',
#     "T.G.I. Friday'S",
#     'T.G.I. Fridays',
#     "T.J.'S Sports Bar",
#     'Taco Bell',
#     'Taco Bell Pizza Hut Express',
#     'Taco Bell, Au Bon Pain',
#     'Tacos Mexico',
#     "Tad'S Steaks",
#     'Tai Pan Bakery',
#     'Taj Cafe',
#     'Taj Donut Shop',
#     'Taj Mahal Indian Restaurant',
#     'Tajin Restaurant',
#     'Taka Hashi Restaurant',
#     'Tal Bagel',
#     'Tal Bagels Deli',
#     'Tamaqua',
#     'Tandoori Food & Bakery',
#     'Tanjia Hukka Bar',
#     'Tao Restaurant',
#     'Tap Room',
#     'Tap-A-Keg',
#     'Taqueria Restaurante Mi Bario',
#     'Tarallucci E Vino',
#     'Tartine',
#     'Taste Of India Ii Restaurant',
#     'Taste Restaurant',
#     'Taste The Tropics Ice Cream',
#     'Tastee Corner',
#     'Tasty Cafe Catering',
#     'Tasty Fast Food',
#     "Tasty'S",
#     'Tatiana Restaurant',
#     'Tavern Lounge',
#     'Tavern On Jane',
#     'Tea And Sympathy',
#     "Teddy'S Bar And Grill",
#     "Tee Dee'S Tavern",
#     'Ten Degrees',
#     'Ten Degrees Bistro',
#     "Ten Ren'S Tea Time",
#     'Ten-Tan Chinese Restaurant',
#     'Teodora',
#     'Tequila Sunrise',
#     'Tequilitas Mexican Restaurant',
#     'Tequilla Sunrise',
#     "Teresa'S Gourmet",
#     "Teresa'S Resturant",
#     'Terminal Cafe/Yankee Clipper',
#     'Terminal1 Employee Cafeteria',
#     'Terra Blues',
#     'Terrace Cafe',
#     'Terrace On The Park',
#     "Terranova'S Bake Ridge Bagel",
#     'Tevere 84',
#     'Texas Rotisserie',
#     'Thai Son',
#     'Thalia',
#     'The Abbey',
#     'The Abbey Pub',
#     'The Arch Diner',
#     'The Assembly Bar',
#     'The Astoria World Manor',
#     'The Aurora Pizza Caffe',
#     'The Bagel House',
#     'The Barbecue Pit',
#     'The Beekman',
#     'The Best Italian Pizza',
#     'The Bitter End',
#     'The Black Dog Grill',
#     'The Black Duck Restaurant',
#     'The Black Sheep',
#     'The Blue Zoo Lounge',
#     'The Bowery Ballroom',
#     'The Bras & Pail Bar',
#     'The Brazen Head',
#     'The Bread Factory Cafe',
#     'The Brook',
#     'The Bubble Lounge',
#     'The Burrito Bar Restaurant',
#     'The Cake Chef',
#     'The Campbell Apartment - In Grand Central',
#     'The Carnegie Cigar Club And Lounge',
#     'The Central Bar',
#     'The Century Association',
#     'The Clubhouse',
#     'The Cornell Center Of New York',
#     'The Corner House',
#     'The Country Cafe',
#     'The Courtyard Ale House',
#     'The Crooked Tree',
#     'The Cupping Room',
#     'The Dart Inn',
#     'The Dead Poet',
#     'The Dish Restaurant',
#     'The Eagle',
#     'The Edge Bar',
#     'The End Zone Bar',
#     'The Esplanade',
#     "The Famous Jimbo'S Hamburger Palace",
#     'The Fitz',
#     'The Food Hut',
#     'The Four Seasons',
#     'The Full Shilling',
#     'The Gate',
#     'The Gin Mill',
#     'The Ginger Man',
#     'The Grand Prospect Hall',
#     'The Great American Health Bar',
#     'The Great Burrito Mexican Kitchen',
#     'The Greek Corner',
#     'The Greek Kitchen  Clinton Bakery Cafe',
#     'The Green Table(Chelsea Market)',
#     'The Grocery',
#     'The Grotto',
#     'The Half King',
#     'The Hallmark Of Battery Park City- Dining Room',
#     'The Harrison',
#     'The Heights Bar & Grill',
#     'The Historic Old Bermuda Inn',
#     'The Hytes Bar',
#     "The Ice Box-Ralph'S Famous Italian Ices",
#     'The Irish Pub',
#     'The Islands',
#     'The Joyce Theater',
#     "The Lark'S Nest",
#     'The Liberty Cafe (S.I. Newhouse)',
#     'The Library',
#     'The Little Sweet Shoppe',
#     'The Lowell',
#     'The Magician',
#     'The Malt House',
#     'The Mansion Grand',
#     'The Mercury Lounge',
#     'The Movable Feast',
#     'The Muffins Shop',
#     'The Neptune Diner',
#     'The New Amity Restaurant',
#     'The New Starling Athletic Club Of The Bronx',
#     'The New Thompson Diner',
#     'The Nippon Club',
#     "The Old Time Vincent'S",
#     'The Original California Taqueria',
#     'The Original Pizza Iv',
#     'The Original Pizza Of 4Th Ave',
#     'The Original Pizza Of Avenue L',
#     "The Original Sal'S Pizzeria",
#     'The Otheroom',
#     'The Palace Theater',
#     'The Park',
#     'The Park Slope Chipshop',
#     'The Parlour',
#     'The Patio Grill',
#     'The Penn Club',
#     'The Pizza Place',
#     'The Place',
#     'The Players Club',
#     'The Princeton Club',
#     'The Punch Bowl',
#     'The Rail Line Diner',
#     'The Ranch Restaurant & Bar Of Guyana',
#     'The Red Cat',
#     'The Restaurant',
#     'The River Cafe',
#     'The River Club',
#     'The Riviera Cafe',
#     'The Room',
#     'The Scratcher Cafe',
#     'The Slaughtered Lamb',
#     'The Spring Lounge',
#     'The Stairs Bar And Lounge',
#     'The Stumble Inn',
#     'The Summit',
#     'The Tap Room',
#     'The Thirsty Scholar',
#     'The Tick Tavern',
#     'The Trash Bar',
#     'The Triad',
#     'The Triple Crown',
#     'The Union League Club',
#     'The University Club',
#     'The Upper Crust',
#     'The Usual Restaurant',
#     'The Village Lantern',
#     'The Village Tavern',
#     'The Water Club',
#     'The Webster Apartments',
#     'The Wheeltapper',
#     'The Whiskey Ward',
#     'The Williamsbridge Tavern',
#     'Think Sweet Cafe',
#     'Thomas Preti Caterers',
#     "Thomasina'S",
#     'Three Decker Restaurant',
#     "Three Guy'S Restaurant",
#     'Three Jolly Pigeons',
#     'Three Of Cups',
#     'Three Star Restaurant',
#     'Throgs Neck Clipper',
#     'Tibbett Diner',
#     'Tiberio Dimare',
#     'Tick Tock Diner',
#     'Tierras Columbianas',
#     'Tim Hortons',
#     'Time Cafeteria',
#     'Times Deli & Cafe',
#     "Timmy'S Deli",
#     "Tina'S Restaurant",
#     'Tio Pepe',
#     'Tip-Top Bar & Grill',
#     'Tir Na Nog',
#     'Tiramisu Restaurant',
#     "Tj Byrne'S Bar",
#     'Tjk Cafe & Restaurant',
#     'To Go Express',
#     'Toad Hall',
#     'Toast',
#     'Tobacco Road',
#     'Tokubei 86',
#     'Tokya',
#     'Toledo',
#     'Tom And Jerry Bar',
#     "Tom'S Delicious Pizza",
#     "Tom'S Restaurant",
#     'Tommaso Restaurant',
#     "Tommy'S Pizza",
#     'Tomoe Sushi',
#     'Tong Hai Tung Bakery',
#     "Tony'S Brick Oven",
#     "Tony'S Deli",
#     "Tony'S Pier Restaurant",
#     "Tony'S Pizza",
#     "Tony'S Pizza Ii",
#     "Tony'S Pizzeria",
#     "Tony'S Pizzeria & Restaurant",
#     'Topaz Thai Restaurant',
#     'Topaze Restaurant',
#     'Topaze Restaurant & Jerk Chicken',
#     'Torch Club',
#     'Tortilla Flats',
#     "Tota'S",
#     "Totonno'S Pizzeria",
#     'Tottenville Bagels',
#     "Touch Of Dee'S",
#     'Tournesol',
#     'Tous Les Jours',
#     'Tout Va Bien',
#     'Tov Kosher Kitchen',
#     'Towers Restaurant',
#     'Town Hall Theatre',
#     'Towne Cafe',
#     'Towne Deli & Pizza',
#     'Townhouse Diner',
#     'Townhouse Of Ny',
#     'Track Kitchen',
#     'Trackside',
#     'Trattoria Alba',
#     'Trattoria Della Arte',
#     'Trattoria I Malatesta',
#     "Trattoria L'Incontro",
#     'Trattoria Pesce Pasta',
#     'Trattoria Romana',
#     'Tre Giovani Pizza & Pasta',
#     'Trellis',
#     'Tres Coronas Bar',
#     'Trevi Deli',
#     'Triangolo Pizzeria',
#     'Tribeca Grand Hotel',
#     'Tribeca Grill',
#     'Tribeca Park Cafe',
#     'Tribeca Pizzeria',
#     'Tribeca Rooftop',
#     'Tribeca Tavern',
#     'Triestes Restaurant',
#     'Trinidad Golden Place',
#     'Trinity Pub',
#     'Triomphe',
#     'Triple Crown Diner',
#     'Tripoli Restaurant',
#     'Tropical House Baking Co.',
#     'Trufa Restaurant',
#     'Tsq Brasserie',
#     'Tsukushi Restaurant',
#     "Turkey'S Nest Tavern",
#     'Turkish Cuisine',
#     'Turkish Kitchen',
#     'Turkuaz Turkish Cuisine',
#     'Turtle Bay Grill And Lounge',
#     'Tuscany Grill',
#     'Twins Pub',
#     'Two Boots Grand Central',
#     'Two Boots To Go West',
#     'Two Boots To Go-Go',
#     "Ty'S",
#     'Ua Court Street #12',
#     'Ua Kaufman Astoria #14',
#     'Udon West',
#     'Uncle Nicks',
#     "Uncle Peter'S",
#     'Uncle Vanya',
#     'Underground Lounge',
#     'Unforgettable Lounge',
#     'Union Cafe Restaurant',
#     'Union Club Of City Of New York',
#     'Union Hall',
#     'Union Pool',
#     'Unique Lounge',
#     'United Cyprians Of America',
#     'United Grocery & Deli',
#     'Uno Cafe & Billiards',
#     'Uno Chicago Grill',
#     'Usa Diner',
#     'Usagi',
#     'Uskudar Restaurant',
#     'Usuluteco Restaurant',
#     'Utopia Restaurant',
#     'Utsav Festive India Restaurant',
#     'V & S Pizzeria Of Sheapshead Bay',
#     'V & T Restaurant',
#     'V & V Bakery',
#     'V-Bar And Cafe',
#     'Va Bene',
#     "Vaccaro'S Pizzeria & Trattoria",
#     "Valentino'S Pizza",
#     'Van Dam Diner',
#     'Varenichnaya - Pelmini Varenichky',
#     'Vatan',
#     "Vee'S Restaurant",
#     'Vegas Diner',
#     'Venice Pizza',
#     'Venice Restaurant',
#     'Verdi Restaurant',
#     'Verlaine',
#     'Verona Pizza',
#     'Veselka Restaurant',
#     'Vespa Cibobuono',
#     'Vesuvio Restaurant & Pizza',
#     'Veterans Of Foreign Wars Post #107 Canteen',
#     'Via Brazil',
#     'Via Italia Ristorante',
#     'Via Quadronno',
#     'Viand Cafe',
#     'Viand Coffee Shop',
#     "Vic'S",
#     'Vice Versa',
#     'Vico Ristorante',
#     "Victor'S Cafe",
#     'Victoria Pizza',
#     'Victory Sweet Shop',
#     'View Lounge',
#     'View Restaurant',
#     'Villa Barone',
#     'Villa Barone Manor',
#     'Villa Berulia',
#     'Villa Fiorita',
#     'Villa Monte Pizzeria',
#     'Villa Mosconi Restaurant',
#     'Villa Russo',
#     'Villa Rustica Ristorante',
#     'Village Den',
#     'Village Maria Pizza Ii',
#     'Village Natural',
#     'Village Pizza',
#     'Village Yogurt',
#     'Village Yokocho',
#     'Vin Et Fleurs',
#     "Vincent'S Pizzeria",
#     'Vincents Bagel',
#     "Vinnie'S Pizzeria/ Luncheonette",
#     "Vinny'S Famous Pizza",
#     "Vinny'S Of Carroll Garden Restaurant & Luncheonett",
#     "Vinny'S Pizza",
#     'Virage',
#     "Virgil'S Bbq",
#     'Vista Hermosa Deli Restaurant',
#     "Vito'S Bakery",
#     'Vittoria Bakery',
#     "Vivienne'S",
#     'Vixens',
#     'Vol De Nuit',
#     'Volare Restaurant',
#     'Von',
#     'W Times Square',
#     "W'S Bar & Restaurant",
#     "Wah Do Mr. Chan'S Restaurant",
#     'Wakamatsu Japanese Restaurant',
#     'Wakamba',
#     "Walker'S Restaurant",
#     'Wallse Restaruant',
#     'Walnut Bus Stop',
#     'Walter Reade Theater',
#     "Walter'S Bar",
#     'War Memorial Ice Skating Rink',
#     'Warren Hall Coffee Bar',
#     'Washington Square Diner',
#     'Water Front Ale House',
#     'Water Front Crab House',
#     "Water'S Edge Club",
#     'Wcou Radio / Tile Bar',
#     'Webster Cafe',
#     'Weiss Cafe Rockefeller University',
#     'Wembley Athletic Club',
#     "Wendy'S",
#     'West 53Rd Gourmet Deli',
#     'West 79Th Street Boat Basin Cafe',
#     'West Bank Cafe',
#     'West Cuisine-Enchantment By Maria',
#     'Western Bakery',
#     'Westside Restaurant',
#     'Westside Tavern',
#     'Westside Theatre',
#     'Westway Diner',
#     'Whaler Bar, Cafe Buon Giorno',
#     'Wharf Bar And Grill',
#     'Wheelers',
#     'Whiskey Park',
#     'White & Case',
#     'White Castle',
#     'White Horse Tavern',
#     'Whitestone Bagel Factory',
#     'Whitestone Lanes',
#     'Whitsons And Forbes',
#     'Wilbel Pizza',
#     'Wild Asia',
#     "Wilken'S Fine Food",
#     "Wimpy'S Restaurant",
#     'Winchesters Pub',
#     'Windfall',
#     'Windjammers Bar',
#     'Wine Bar',
#     "Winnie'S Bar",
#     'Winter Garden Theater',
#     'Wolf And Lamb',
#     'Womens Natl. Republican Club',
#     'Wondee Siam Ii',
#     'Woo Chon Restaurant',
#     'Wood Bine Caterers',
#     'Woodlawn Cafe',
#     'Woodrow Diner',
#     'World Cup Cafe',
#     'Wrap N Run Grill',
#     'Wu Liang Ye Restaurant',
#     'Xtra Cheese Pizzeria',
#     'Yakiniku West Restaurant',
#     'Yakitori Taisho',
#     'Yale Club',
#     "Yama Japanese Restaurant'",
#     'Yankee Clipper',
#     'Yankee Jz Pizza',
#     'Yankee Tavern',
#     'Yao Wah Kitchen',
#     'Yb Food Market',
#     'Yemen Cuisine',
#     'Yen Yen Restaurant',
#     "Yip'S",
#     'Yolanda Pizzeria Restaurant',
#     'Yonah Shimmels Knishes',
#     'Your Bakery',
#     'Yummy Kitchen',
#     'Yura & Company On Madison',
#     'Yvonne Yvonne Restaurant',
#     "Zafi'S Luncheonette",
#     "Zaro'S Bakery",
#     "Zaro'S Bread Basket",
#     'Zebu Grill',
#     "Zorba'S",
#     'Zum Schneider',
#     'Zum Stammtisch',
# ]

# %%
result = db.restaurants.distinct("cuisine")

pprint( list(result) )
# Out:
# [
#     'Afghan',
#     'African',
#     'American ',
#     'Armenian',
#     'Asian',
#     'Bagels/Pretzels',
#     'Bakery',
#     'Bangladeshi',
#     'Barbecue',
#     'Bottled beverages, including water, sodas, juices, etc.',
#     'Brazilian',
#     'CafÃ©/Coffee/Tea',
#     'Café/Coffee/Tea',
#     'Caribbean',
#     'Chicken',
#     'Chinese',
#     'Chinese/Cuban',
#     'Chinese/Japanese',
#     'Continental',
#     'Czech',
#     'Delicatessen',
#     'Donuts',
#     'Eastern European',
#     'Egyptian',
#     'English',
#     'Ethiopian',
#     'Filipino',
#     'French',
#     'German',
#     'Greek',
#     'Hamburgers',
#     'Hotdogs',
#     'Ice Cream, Gelato, Yogurt, Ices',
#     'Indian',
#     'Indonesian',
#     'Irish',
#     'Italian',
#     'Japanese',
#     'Jewish/Kosher',
#     'Juice, Smoothies, Fruit Salads',
#     'Korean',
#     'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#     'Mediterranean',
#     'Mexican',
#     'Middle Eastern',
#     'Moroccan',
#     'Not Listed/Not Applicable',
#     'Other',
#     'Pakistani',
#     'Pancakes/Waffles',
#     'Peruvian',
#     'Pizza',
#     'Pizza/Italian',
#     'Polish',
#     'Portuguese',
#     'Russian',
#     'Salads',
#     'Sandwiches',
#     'Sandwiches/Salads/Mixed Buffet',
#     'Seafood',
#     'Soul Food',
#     'Soups & Sandwiches',
#     'Spanish',
#     'Steak',
#     'Tapas',
#     'Tex-Mex',
#     'Thai',
#     'Turkish',
#     'Vegetarian',
#     'Vietnamese/Cambodian/Malaysia',
# ]

# %% [markdown]
# ### [Questão 2] Mostre o nome e o tipo de cozinha de 5 restaurantes quaisquer sem exibir o campo "_id"

# %%
result = db.restaurants.find(
    { "restaurant_id": { "$in":["40601531","40626388","40584813","40861252","40878590"] } },
    {
        "_id": 0,
        "name": 1,
        "cuisine": 1
    }
)

pprint( list(result) )
# Out:
# [
#     {'cuisine': 'Chinese', 'name': 'Hop Won Express'},
#     {'cuisine': 'American ', 'name': 'Puritan Restaurant'},
#     {'cuisine': 'American ', 'name': 'The Esplanade'},
#     {'cuisine': 'American ', 'name': 'Sweet & Vicious'},
#     {'cuisine': 'Japanese', 'name': 'Sapporo Restaurant'},
# ]

# %% [markdown]
# ### [Questão 3] Mostre 5 restaurantes no bairro "Bronx"

# %%
result = db.restaurants.find( {"borough": {"$in":["Bronx"] } } ).limit(5)

pprint( list(result) )
# Out:
# [
#     {
#         '_id': ObjectId('5f372bf75956cf602023fe9d'),
#         'address': {
#             'building': '2300',
#             'coord': [-73.8786113, 40.8502883],
#             'street': 'Southern Boulevard',
#             'zipcode': '10460',
#         },
#         'borough': 'Bronx',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 5, 28, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#             {
#                 'date': datetime.datetime(2013, 6, 19, 0, 0),
#                 'grade': 'A',
#                 'score': 4,
#             },
#             {
#                 'date': datetime.datetime(2012, 6, 15, 0, 0),
#                 'grade': 'A',
#                 'score': 3,
#             },
#         ],
#         'name': 'Wild Asia',
#         'restaurant_id': '40357217',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf602023fea6'),
#         'address': {
#             'building': '1007',
#             'coord': [-73.856077, 40.848447],
#             'street': 'Morris Park Ave',
#             'zipcode': '10462',
#         },
#         'borough': 'Bronx',
#         'cuisine': 'Bakery',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 3, 3, 0, 0),
#                 'grade': 'A',
#                 'score': 2,
#             },
#             {
#                 'date': datetime.datetime(2013, 9, 11, 0, 0),
#                 'grade': 'A',
#                 'score': 6,
#             },
#             {
#                 'date': datetime.datetime(2013, 1, 24, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2011, 11, 23, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2011, 3, 10, 0, 0),
#                 'grade': 'B',
#                 'score': 14,
#             },
#         ],
#         'name': 'Morris Park Bake Shop',
#         'restaurant_id': '30075445',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf602023febd'),
#         'address': {
#             'building': '277',
#             'coord': [-73.8941893, 40.8634684],
#             'street': 'East Kingsbridge Road',
#             'zipcode': '10458',
#         },
#         'borough': 'Bronx',
#         'cuisine': 'Chinese',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 3, 3, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2013, 9, 26, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2013, 3, 19, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2012, 8, 29, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#             {
#                 'date': datetime.datetime(2011, 8, 17, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#         ],
#         'name': 'Happy Garden',
#         'restaurant_id': '40364296',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf602023fec3'),
#         'address': {
#             'building': '658',
#             'coord': [-73.81363999999999, 40.82941100000001],
#             'street': 'Clarence Ave',
#             'zipcode': '10465',
#         },
#         'borough': 'Bronx',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 6, 21, 0, 0),
#                 'grade': 'A',
#                 'score': 5,
#             },
#             {
#                 'date': datetime.datetime(2012, 7, 11, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#         ],
#         'name': 'Manhem Club',
#         'restaurant_id': '40364363',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf602023fef3'),
#         'address': {
#             'building': '2222',
#             'coord': [-73.84971759999999, 40.8304811],
#             'street': 'Haviland Avenue',
#             'zipcode': '10462',
#         },
#         'borough': 'Bronx',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 12, 18, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#             {
#                 'date': datetime.datetime(2014, 5, 1, 0, 0),
#                 'grade': 'B',
#                 'score': 17,
#             },
#             {
#                 'date': datetime.datetime(2013, 3, 14, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2012, 9, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2012, 2, 8, 0, 0),
#                 'grade': 'B',
#                 'score': 19,
#             },
#         ],
#         'name': 'The New Starling Athletic Club Of The Bronx',
#         'restaurant_id': '40364956',
#     },
# ]

# %% [markdown]
# ### [Questão 4] Altere o tipo de cozinha do restaurante "Kosher Island" para "Sea food"

# %%
db.restaurants.update(
    { "name" : "Kosher Island" },
    { "$set": {"cuisine":"Sea food"} }
);

result = db.restaurants.find({"name":"Kosher Island"});

pprint( list(result) );
# Out:
# [
#     {
#         '_id': ObjectId('5f372bf75956cf602023fea5'),
#         'address': {
#             'building': '2206',
#             'coord': [-74.1377286, 40.6119572],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Sea food',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 10, 6, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2014, 5, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2013, 4, 4, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2012, 1, 24, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#         ],
#         'name': 'Kosher Island',
#         'restaurant_id': '40356442',
#     },
# ]

# %% [markdown]
# ### [Questão 5] Mostre e remova o(s) restaurante(s) com zipcode "10314"

# %%
result = db.restaurants.find({"address.zipcode":"10314"})

pprint(list(result))
# Out:
# [
#     {
#         '_id': ObjectId('5f372bf75956cf602023fea5'),
#         'address': {
#             'building': '2206',
#             'coord': [-74.1377286, 40.6119572],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Sea food',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 10, 6, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2014, 5, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2013, 4, 4, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2012, 1, 24, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#         ],
#         'name': 'Kosher Island',
#         'restaurant_id': '40356442',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf602023feaf'),
#         'address': {
#             'building': '2491',
#             'coord': [-74.1459332, 40.6103714],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Delicatessen',
#         'grades': [
#             {
#                 'date': datetime.datetime(2015, 1, 9, 0, 0),
#                 'grade': 'A',
#                 'score': 3,
#             },
#             {
#                 'date': datetime.datetime(2013, 12, 5, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2013, 6, 19, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2013, 1, 8, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#         ],
#         'name': 'Bagels N Buns',
#         'restaurant_id': '40363427',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf602023ff62'),
#         'address': {
#             'building': '1758',
#             'coord': [-74.1220973, 40.6129407],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Pizza/Italian',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 11, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 5,
#             },
#             {
#                 'date': datetime.datetime(2014, 1, 13, 0, 0),
#                 'grade': 'B',
#                 'score': 14,
#             },
#             {
#                 'date': datetime.datetime(2013, 4, 25, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2012, 10, 9, 0, 0),
#                 'grade': 'A',
#                 'score': 4,
#             },
#             {
#                 'date': datetime.datetime(2012, 5, 2, 0, 0),
#                 'grade': 'B',
#                 'score': 22,
#             },
#         ],
#         'name': "Joe & Pat'S Pizzeria",
#         'restaurant_id': '40365454',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf602023ffc3'),
#         'address': {
#             'building': '2055',
#             'coord': [-74.1321, 40.61266000000001],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 11, 6, 0, 0),
#                 'grade': 'B',
#                 'score': 25,
#             },
#             {
#                 'date': datetime.datetime(2014, 5, 6, 0, 0),
#                 'grade': 'B',
#                 'score': 20,
#             },
#             {
#                 'date': datetime.datetime(2013, 1, 26, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2011, 12, 17, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#         ],
#         'name': "Schaffer'S Tavern",
#         'restaurant_id': '40371771',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf602023ffd2'),
#         'address': {
#             'building': '275',
#             'coord': [-74.1235473, 40.6215341],
#             'street': 'Martling Ave',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 4, 9, 0, 0),
#                 'grade': 'A',
#                 'score': 5,
#             },
#             {
#                 'date': datetime.datetime(2013, 1, 16, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2012, 1, 6, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#         ],
#         'name': 'Exclusive Catering',
#         'restaurant_id': '40372016',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf6020240045'),
#         'address': {
#             'building': '0',
#             'coord': [-84.1899005, 39.7642657],
#             'street': 'Memorial Ice Skating',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 2, 14, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2012, 2, 18, 0, 0),
#                 'grade': 'A',
#                 'score': 8,
#             },
#         ],
#         'name': 'War Memorial Ice Skating Rink',
#         'restaurant_id': '40376583',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf60202400cb'),
#         'address': {
#             'building': '3115',
#             'coord': [-74.16303719999999, 40.60731],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Pizza',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 8, 7, 0, 0),
#                 'grade': 'B',
#                 'score': 21,
#             },
#             {
#                 'date': datetime.datetime(2014, 1, 7, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2012, 10, 9, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2011, 10, 18, 0, 0),
#                 'grade': 'A',
#                 'score': 4,
#             },
#         ],
#         'name': "Pizza D'Oro",
#         'restaurant_id': '40383945',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf60202400ea'),
#         'address': {
#             'building': '2210',
#             'coord': [-74.1369752, 40.6118922],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Pizza',
#         'grades': [
#             {
#                 'date': datetime.datetime(2015, 1, 7, 0, 0),
#                 'grade': 'A',
#                 'score': 8,
#             },
#             {
#                 'date': datetime.datetime(2013, 12, 5, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2013, 4, 25, 0, 0),
#                 'grade': 'B',
#                 'score': 17,
#             },
#         ],
#         'name': 'Dairy Palace',
#         'restaurant_id': '40385543',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf60202400f9'),
#         'address': {
#             'building': '921',
#             'coord': [-74.1485484, 40.6248044],
#             'street': 'Richmond Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2015, 1, 15, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2014, 5, 20, 0, 0),
#                 'grade': 'B',
#                 'score': 20,
#             },
#             {
#                 'date': datetime.datetime(2013, 9, 18, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#             {
#                 'date': datetime.datetime(2013, 4, 4, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2012, 6, 28, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#         ],
#         'name': 'Dakota Diner',
#         'restaurant_id': '40385974',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf602024014c'),
#         'address': {
#             'building': '280',
#             'coord': [-74.1386716, 40.6160213],
#             'street': 'Watchogue Road',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 7, 15, 0, 0),
#                 'grade': 'B',
#                 'score': 19,
#             },
#             {
#                 'date': datetime.datetime(2013, 12, 3, 0, 0),
#                 'grade': 'B',
#                 'score': 25,
#             },
#             {
#                 'date': datetime.datetime(2013, 5, 7, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2012, 6, 19, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2011, 12, 1, 0, 0),
#                 'grade': 'B',
#                 'score': 15,
#             },
#             {
#                 'date': datetime.datetime(2011, 7, 26, 0, 0),
#                 'grade': 'C',
#                 'score': 36,
#             },
#         ],
#         'name': 'Jimmy Max Restaurant',
#         'restaurant_id': '40387243',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf60202401b7'),
#         'address': {
#             'building': '151',
#             'coord': [-74.16906999999999, 40.60375],
#             'street': 'Signs Road',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 8, 28, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2013, 7, 29, 0, 0),
#                 'grade': 'C',
#                 'score': 2,
#             },
#             {
#                 'date': datetime.datetime(2012, 6, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 4,
#             },
#         ],
#         'name': 'Hillside Swimming Club',
#         'restaurant_id': '40391824',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf6020240206'),
#         'address': {
#             'building': '2655',
#             'coord': [-74.1660553, 40.5823983],
#             'street': 'Richmond Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Chinese',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 9, 24, 0, 0),
#                 'grade': 'Z',
#                 'score': 26,
#             },
#             {
#                 'date': datetime.datetime(2013, 9, 4, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#             {
#                 'date': datetime.datetime(2013, 3, 21, 0, 0),
#                 'grade': 'C',
#                 'score': 3,
#             },
#             {
#                 'date': datetime.datetime(2012, 1, 25, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#         ],
#         'name': 'Master Wok',
#         'restaurant_id': '40394394',
#     },
#     {
#         '_id': ObjectId('5f372bf75956cf602024026f'),
#         'address': {
#             'building': '1660',
#             'coord': [-74.162854, 40.60778699999999],
#             'street': 'Richmond Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Hamburgers',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 6, 3, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2013, 5, 23, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2012, 6, 5, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2011, 12, 27, 0, 0),
#                 'grade': 'C',
#                 'score': 52,
#             },
#         ],
#         'name': "Mcdonald'S",
#         'restaurant_id': '40395935',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf60202402f8'),
#         'address': {
#             'building': '2187',
#             'coord': [-74.16253999999999, 40.594092],
#             'street': 'Richmond Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2013, 12, 5, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2013, 3, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 8,
#             },
#             {
#                 'date': datetime.datetime(2012, 6, 16, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2011, 6, 16, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2011, 1, 14, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#         ],
#         'name': "Henny'S Restaurant",
#         'restaurant_id': '40398948',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf6020240352'),
#         'address': {
#             'building': '1975',
#             'coord': [-74.129932, 40.612816],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 11, 6, 0, 0),
#                 'grade': 'Z',
#                 'score': 38,
#             },
#             {
#                 'date': datetime.datetime(2013, 8, 17, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2012, 7, 17, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2012, 3, 10, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#         ],
#         'name': "Legend'S Pub",
#         'restaurant_id': '40400556',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf6020240360'),
#         'address': {
#             'building': '768',
#             'coord': [-74.12184789999999, 40.60862900000001],
#             'street': 'Manor Road',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Pizza',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 11, 6, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2014, 4, 9, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2013, 8, 6, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#             {
#                 'date': datetime.datetime(2012, 6, 5, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#             {
#                 'date': datetime.datetime(2011, 12, 3, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#         ],
#         'name': 'Village Maria Pizza Ii',
#         'restaurant_id': '40400898',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf6020240394'),
#         'address': {
#             'building': '770',
#             'coord': [-74.1219048, 40.6085365],
#             'street': 'Manor Road',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Chinese',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 7, 22, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2014, 1, 7, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2013, 12, 10, 0, 0),
#                 'grade': 'P',
#                 'score': 3,
#             },
#             {
#                 'date': datetime.datetime(2013, 4, 25, 0, 0),
#                 'grade': 'B',
#                 'score': 25,
#             },
#             {
#                 'date': datetime.datetime(2012, 8, 8, 0, 0),
#                 'grade': 'B',
#                 'score': 23,
#             },
#             {
#                 'date': datetime.datetime(2011, 12, 22, 0, 0),
#                 'grade': 'B',
#                 'score': 25,
#             },
#             {
#                 'date': datetime.datetime(2011, 8, 10, 0, 0),
#                 'grade': 'B',
#                 'score': 22,
#             },
#         ],
#         'name': 'Happy Fortune Ii',
#         'restaurant_id': '40401094',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf6020240408'),
#         'address': {
#             'building': '1899',
#             'coord': [-74.127349, 40.612969],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Bakery',
#         'grades': [
#             {
#                 'date': datetime.datetime(2013, 12, 4, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2012, 12, 11, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#         ],
#         'name': "Alfonso'S Pastry Shoppe",
#         'restaurant_id': '40423819',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf6020240415'),
#         'address': {
#             'building': '957',
#             'coord': [-74.1305762, 40.6129841],
#             'street': 'Jewett Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 9, 11, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2014, 3, 12, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2012, 12, 26, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2011, 12, 3, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#         ],
#         'name': 'The Cake Chef',
#         'restaurant_id': '40424709',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf6020240474'),
#         'address': {
#             'building': '2800',
#             'coord': [-74.15198199999999, 40.6009948],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 11, 18, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2013, 11, 6, 0, 0),
#                 'grade': 'A',
#                 'score': 3,
#             },
#             {
#                 'date': datetime.datetime(2012, 7, 6, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2012, 2, 22, 0, 0),
#                 'grade': 'A',
#                 'score': 4,
#             },
#         ],
#         'name': 'Campus Center Cafeteria',
#         'restaurant_id': '40516509',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf6020240478'),
#         'address': {
#             'building': '2800',
#             'coord': [-74.15198199999999, 40.6009948],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Café/Coffee/Tea',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 11, 18, 0, 0),
#                 'grade': 'A',
#                 'score': 5,
#             },
#             {
#                 'date': datetime.datetime(2013, 11, 21, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2012, 7, 31, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#             {
#                 'date': datetime.datetime(2012, 3, 21, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#         ],
#         'name': 'Food For Thought Library Cafe',
#         'restaurant_id': '40516511',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf6020240499'),
#         'address': {
#             'building': '950',
#             'coord': [-74.131142, 40.613148],
#             'street': 'Jewett Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Hamburgers',
#         'grades': [
#             {
#                 'date': datetime.datetime(2015, 1, 16, 0, 0),
#                 'grade': 'A',
#                 'score': 2,
#             },
#             {
#                 'date': datetime.datetime(2014, 8, 7, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2014, 2, 24, 0, 0),
#                 'grade': 'A',
#                 'score': 5,
#             },
#             {
#                 'date': datetime.datetime(2012, 12, 19, 0, 0),
#                 'grade': 'A',
#                 'score': 5,
#             },
#         ],
#         'name': 'Burger King',
#         'restaurant_id': '40513416',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf60202404fa'),
#         'address': {
#             'building': '2845',
#             'coord': [-74.1678299, 40.577238],
#             'street': 'Richmond Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Chinese',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 9, 8, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2014, 3, 4, 0, 0),
#                 'grade': 'A',
#                 'score': 6,
#             },
#             {
#                 'date': datetime.datetime(2013, 2, 25, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2012, 6, 12, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2011, 11, 1, 0, 0),
#                 'grade': 'B',
#                 'score': 15,
#             },
#         ],
#         'name': 'Jade Island Restaurant',
#         'restaurant_id': '40536227',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf6020240590'),
#         'address': {
#             'building': '3785',
#             'coord': [-74.18227569999999, 40.5975538],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 4, 22, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2013, 1, 30, 0, 0),
#                 'grade': 'A',
#                 'score': 5,
#             },
#             {
#                 'date': datetime.datetime(2012, 5, 24, 0, 0),
#                 'grade': 'A',
#                 'score': 8,
#             },
#             {
#                 'date': datetime.datetime(2011, 12, 22, 0, 0),
#                 'grade': 'A',
#                 'score': 2,
#             },
#         ],
#         'name': 'Mug Shots',
#         'restaurant_id': '40550262',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf60202405d2'),
#         'address': {
#             'building': '2795',
#             'coord': [-74.1674401, 40.5769947],
#             'street': 'Richmond Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Hamburgers',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 11, 18, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#             {
#                 'date': datetime.datetime(2013, 11, 6, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2013, 1, 16, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#         ],
#         'name': "Mcdonald'S",
#         'restaurant_id': '40571705',
#     },
#     {
#         '_id': ObjectId('5f372bf85956cf602024064a'),
#         'address': {
#             'building': '3785',
#             'coord': [-74.18227569999999, 40.5975538],
#             'street': 'Victory Boulevard',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Chicken',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 11, 8, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#             {
#                 'date': datetime.datetime(2014, 4, 24, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2013, 1, 17, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2012, 6, 9, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#         ],
#         'name': 'Chicken Holiday Express',
#         'restaurant_id': '40579745',
#     },
#     {
#         '_id': ObjectId('5f372bf95956cf6020240706'),
#         'address': {
#             'building': '2505',
#             'coord': [-74.1673983, 40.5865347],
#             'street': 'Richmond Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Café/Coffee/Tea',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 3, 26, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2013, 1, 31, 0, 0),
#                 'grade': 'A',
#                 'score': 2,
#             },
#             {
#                 'date': datetime.datetime(2011, 12, 12, 0, 0),
#                 'grade': 'A',
#                 'score': 2,
#             },
#         ],
#         'name': 'Starbucks Coffee',
#         'restaurant_id': '40602872',
#     },
#     {
#         '_id': ObjectId('5f372bf95956cf6020240743'),
#         'address': {
#             'building': '2557',
#             'coord': [-74.16819079999999, 40.5854225],
#             'street': 'Richmond Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Hamburgers',
#         'grades': [
#             {
#                 'date': datetime.datetime(2015, 1, 15, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#             {
#                 'date': datetime.datetime(2014, 5, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#             {
#                 'date': datetime.datetime(2013, 3, 1, 0, 0),
#                 'grade': 'A',
#                 'score': 3,
#             },
#             {
#                 'date': datetime.datetime(2012, 9, 11, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2012, 3, 27, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#         ],
#         'name': 'Burger King',
#         'restaurant_id': '40609680',
#     },
#     {
#         '_id': ObjectId('5f372bf95956cf6020240748'),
#         'address': {
#             'building': '446',
#             'coord': [-74.16489229999999, 40.5897778],
#             'street': 'Nome Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Pizza/Italian',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 11, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 5,
#             },
#             {
#                 'date': datetime.datetime(2014, 2, 26, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2013, 6, 4, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#             {
#                 'date': datetime.datetime(2012, 4, 16, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#         ],
#         'name': 'Barios Pizza & Restaurant',
#         'restaurant_id': '40609705',
#     },
#     {
#         '_id': ObjectId('5f372bf95956cf6020240768'),
#         'address': {
#             'building': '1451',
#             'coord': [-74.1586641, 40.612597],
#             'street': 'Richmond Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 4, 7, 0, 0),
#                 'grade': 'A',
#                 'score': 3,
#             },
#             {
#                 'date': datetime.datetime(2013, 1, 31, 0, 0),
#                 'grade': 'A',
#                 'score': 3,
#             },
#             {
#                 'date': datetime.datetime(2012, 1, 9, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#         ],
#         'name': "Applebee'S Neighborhood Grill & Bar",
#         'restaurant_id': '40620427',
#     },
#     {
#         '_id': ObjectId('5f372bf95956cf6020240832'),
#         'address': {
#             'building': '28030',
#             'coord': [-74.1629372, 40.5806591],
#             'street': 'Marsh Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 5, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2013, 4, 1, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#             {
#                 'date': datetime.datetime(2012, 4, 5, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#         ],
#         'name': 'Carvel Ice Cream',
#         'restaurant_id': '40639953',
#     },
#     {
#         '_id': ObjectId('5f372bf95956cf60202408fe'),
#         'address': {
#             'building': '1775',
#             'coord': [-74.1928099, 40.6000765],
#             'street': 'South Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Pizza',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 12, 16, 0, 0),
#                 'grade': 'B',
#                 'score': 16,
#             },
#             {
#                 'date': datetime.datetime(2014, 6, 25, 0, 0),
#                 'grade': 'C',
#                 'score': 32,
#             },
#             {
#                 'date': datetime.datetime(2013, 3, 12, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#         ],
#         'name': "Chuck E Cheese'S",
#         'restaurant_id': '40716299',
#     },
#     {
#         '_id': ObjectId('5f372bf95956cf6020240aaa'),
#         'address': {
#             'building': '26',
#             'coord': [-74.1668698, 40.588193],
#             'street': 'Richmond Hill Road',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Hamburgers',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 5, 19, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2013, 3, 12, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#             {
#                 'date': datetime.datetime(2011, 12, 12, 0, 0),
#                 'grade': 'A',
#                 'score': 3,
#             },
#         ],
#         'name': "Wendy'S",
#         'restaurant_id': '40782999',
#     },
#     {
#         '_id': ObjectId('5f372bf95956cf6020240ae9'),
#         'address': {
#             'building': '1445',
#             'coord': [-74.1574104, 40.6117346],
#             'street': 'Richmond Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Pizza',
#         'grades': [
#             {
#                 'date': datetime.datetime(2013, 12, 5, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2013, 4, 27, 0, 0),
#                 'grade': 'B',
#                 'score': 16,
#             },
#             {
#                 'date': datetime.datetime(2012, 5, 18, 0, 0),
#                 'grade': 'B',
#                 'score': 17,
#             },
#             {
#                 'date': datetime.datetime(2011, 12, 7, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2011, 7, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2011, 3, 3, 0, 0),
#                 'grade': 'C',
#                 'score': 39,
#             },
#         ],
#         'name': 'La Piazza Pizzeria & Restaurant',
#         'restaurant_id': '40791157',
#     },
#     {
#         '_id': ObjectId('5f372bf95956cf6020240b1e'),
#         'address': {
#             'building': '917',
#             'coord': [-74.12057349999999, 40.604379],
#             'street': 'Manor Road',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Italian',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 11, 19, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2014, 2, 18, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2013, 4, 30, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2012, 8, 18, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2012, 2, 28, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#         ],
#         'name': 'Manor House Restaurant',
#         'restaurant_id': '40803444',
#     },
#     {
#         '_id': ObjectId('5f372bf95956cf6020240b30'),
#         'address': {
#             'building': '2245',
#             'coord': [-74.16254529999999, 40.5922616],
#             'street': 'Richmond Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'Café/Coffee/Tea',
#         'grades': [
#             {
#                 'date': datetime.datetime(2015, 1, 6, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#             {
#                 'date': datetime.datetime(2013, 11, 21, 0, 0),
#                 'grade': 'A',
#                 'score': 8,
#             },
#             {
#                 'date': datetime.datetime(2012, 7, 26, 0, 0),
#                 'grade': 'A',
#                 'score': 13,
#             },
#             {
#                 'date': datetime.datetime(2012, 3, 14, 0, 0),
#                 'grade': 'A',
#                 'score': 5,
#             },
#         ],
#         'name': 'Barnes & Noble Cafe',
#         'restaurant_id': '40805108',
#     },
#     {
#         '_id': ObjectId('5f372bf95956cf6020240c66'),
#         'address': {
#             'building': '1100',
#             'coord': [-74.1771674, 40.6144973],
#             'street': 'South Avenue',
#             'zipcode': '10314',
#         },
#         'borough': 'Staten Island',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 10, 2, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2014, 4, 16, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2013, 7, 30, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2013, 4, 25, 0, 0),
#                 'grade': 'B',
#                 'score': 14,
#             },
#             {
#                 'date': datetime.datetime(2012, 7, 19, 0, 0),
#                 'grade': 'A',
#                 'score': 6,
#             },
#             {
#                 'date': datetime.datetime(2011, 12, 12, 0, 0),
#                 'grade': 'A',
#                 'score': 11,
#             },
#         ],
#         'name': 'Lorenzos Bar & Grill (Hilton Garden)',
#         'restaurant_id': '40854101',
#     },
# ]

# %%
db.restaurants.remove({"address.zipcode":"10314"})

result = db.restaurants.find({"address.zipcode":"10314"})

pprint(list(result))
# Out:
# []

# %% [markdown]
# ### [Questão 6] Adicione um campo status ao restaurante cujo nome é "Riviera Caterer". Status="demolido".

# %%
# NESTA ATIVIDADE MANTIVE O PADRAO DA COLLECTION EM TERMOS DE NOMENCLATURA DE CHAVE E VALOR
db.restaurants.update(
    {"name" : "Riviera Caterer"},
    {"$set": {"status" : "Demolido"} }
)

result = db.restaurants.find({"name":"Riviera Caterer"})

pprint( list(result) )
# Out:
# [
#     {
#         '_id': ObjectId('5f372bf75956cf602023fe99'),
#         'address': {
#             'building': '2780',
#             'coord': [-73.98241999999999, 40.579505],
#             'street': 'Stillwell Avenue',
#             'zipcode': '11224',
#         },
#         'borough': 'Brooklyn',
#         'cuisine': 'American ',
#         'grades': [
#             {
#                 'date': datetime.datetime(2014, 6, 10, 0, 0),
#                 'grade': 'A',
#                 'score': 5,
#             },
#             {
#                 'date': datetime.datetime(2013, 6, 5, 0, 0),
#                 'grade': 'A',
#                 'score': 7,
#             },
#             {
#                 'date': datetime.datetime(2012, 4, 13, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#             {
#                 'date': datetime.datetime(2011, 10, 12, 0, 0),
#                 'grade': 'A',
#                 'score': 12,
#             },
#         ],
#         'name': 'Riviera Caterer',
#         'restaurant_id': '40356018',
#         'status': 'Demolido',
#     },
# ]

# %% [markdown]
# ### [Questão Extra] Adicione um restaurante seguindo a estrutura de documentos da coleção

# %%
import datetime

db.restaurants.insert(
    {
      "address": {
         "building": "194",
         "coord": [ -14.7880958, -39.0432588 ],
         "street": "Av. Litorânea Norte",
         "zipcode": "45651610"
      },
      "borough": "Malhado",
      "cuisine": "Italian",
      "grades": [
         { "date": datetime.datetime(2020,1,15,0,0), "grade": "A", "score": 2 },
         { "date": datetime.datetime(2020,2,15,0,0,), "grade": "A", "score": 6 },
         { "date": datetime.datetime(2020,3,17,0,0), "grade": "A", "score": 10 },
         { "date": datetime.datetime(2020,4,20,0,0), "grade": "A", "score": 9 },
         { "date": datetime.datetime(2020,5,19,0,0), "grade": "B", "score": 14 }
      ],
      "name": "Pizzaria Litorânea",
      "restaurant_id": "99975999",
    }
)

result = db.restaurants.find({"restaurant_id":"99975999"})

pprint( list(result) )
# Out:
# [
#     {
#         '_id': ObjectId('5f372bff9399e75a30540eba'),
#         'address': {
#             'building': '194',
#             'coord': [-14.7880958, -39.0432588],
#             'street': 'Av. Litorânea Norte',
#             'zipcode': '45651610',
#         },
#         'borough': 'Malhado',
#         'cuisine': 'Italian',
#         'grades': [
#             {
#                 'date': datetime.datetime(2020, 1, 15, 0, 0),
#                 'grade': 'A',
#                 'score': 2,
#             },
#             {
#                 'date': datetime.datetime(2020, 2, 15, 0, 0),
#                 'grade': 'A',
#                 'score': 6,
#             },
#             {
#                 'date': datetime.datetime(2020, 3, 17, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2020, 4, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2020, 5, 19, 0, 0),
#                 'grade': 'B',
#                 'score': 14,
#             },
#         ],
#         'name': 'Pizzaria Litorânea',
#         'restaurant_id': '99975999',
#     },
# ]

# %% [markdown]
# ### [Questão Extra] Adicione um campo cidade do restaurante criado anteriormente para "Ilheus"

# %%
db.restaurants.update(
    {"name":"Pizzaria Litorânea"},
    {
        "$set": {
            "address": {
                "building": "194",
                "coord": [-14.7880958, -39.0432588],
                "street": "Av. Litorânea Norte",
                "zipcode": "45651610",
                "city": "Ilhéus"
            } 
        } 
    }
)

result = db.restaurants.find({"name":"Pizzaria Litorânea"})

pprint( list(result) )
# Out:
# [
#     {
#         '_id': ObjectId('5f372bff9399e75a30540eba'),
#         'address': {
#             'building': '194',
#             'city': 'Ilhéus',
#             'coord': [-14.7880958, -39.0432588],
#             'street': 'Av. Litorânea Norte',
#             'zipcode': '45651610',
#         },
#         'borough': 'Malhado',
#         'cuisine': 'Italian',
#         'grades': [
#             {
#                 'date': datetime.datetime(2020, 1, 15, 0, 0),
#                 'grade': 'A',
#                 'score': 2,
#             },
#             {
#                 'date': datetime.datetime(2020, 2, 15, 0, 0),
#                 'grade': 'A',
#                 'score': 6,
#             },
#             {
#                 'date': datetime.datetime(2020, 3, 17, 0, 0),
#                 'grade': 'A',
#                 'score': 10,
#             },
#             {
#                 'date': datetime.datetime(2020, 4, 20, 0, 0),
#                 'grade': 'A',
#                 'score': 9,
#             },
#             {
#                 'date': datetime.datetime(2020, 5, 19, 0, 0),
#                 'grade': 'B',
#                 'score': 14,
#             },
#         ],
#         'name': 'Pizzaria Litorânea',
#         'restaurant_id': '99975999',
#     },
# ]

# %% [markdown]
# ### [Questão Extra] Mostre o nome de todos os restaurantes que receberam pelo menos uma avaliação A

# %%
result = db.restaurants.find({"grades.grade":"A"}).distinct("name")

pprint(list(result))
# Out:
# [
#     '(Lewis Drug Store) Locanda Vini E Olii',
#     '1 East 66Th Street Kitchen',
#     '101 Deli',
#     '101 Restaurant And Bar',
#     '1020 Bar',
#     '104-01 Foster Avenue Coffee Shop(Ups)',
#     '10Th Avenue Pizza & Cafe',
#     '111 Restaurant',
#     '15 East Restaurant',
#     '200 Fifth Avenue Restaurant & Sports Bar',
#     '21 Club',
#     '2A',
#     '3 Deli & Grill',
#     '3 Guys',
#     '3 Guys Resturant',
#     '42Nd Street Pizza Diner',
#     "44 & X Hell'S Kitchen",
#     '44 Sw Ristorante & Bar',
#     '5 Burro Cafe',
#     '525 Lex Restaurant & Bar',
#     '7 Stars',
#     '71 Irving Place',
#     '7B Bar',
#     '7Th Avenue Donut Shop',
#     '810 Deli & Cafe',
#     '9024/Catering By Michael Schick Inc.',
#     '9Th Ave Saloon',
#     'A & B Deli & Catering',
#     'A & S Pizzeria',
#     'A Salt & Battery',
#     'A-1 Pizza Shop',
#     'A.J. Pizzeria',
#     "Abigael'S On Broadway",
#     'Abir Halal Restaurant',
#     "Abitino'S Pizza",
#     'Absolute Bagels',
#     'Academy Restauraunt',
#     'Acappella Restaurant',
#     'Acapulco Deli & Restaurant',
#     'Ace Bar',
#     'Acme Bar & Grill',
#     'Acqua',
#     'Acqua Santa',
#     'Acquista Trattoria',
#     'Adria Hotel',
#     "Adrian & Rocky'S Caterers",
#     'Afghan Kebab House',
#     'Afghan Kebab House #1',
#     'African Market (Baboon Cafe)',
#     'African Terrace',
#     'Africana Restaurant',
#     "Afternoone'S Restaurant",
#     'Agave',
#     'Agra Restaurant',
#     'Ah! Chihuahua',
#     'Air France Lounge',
#     'Air India Lounge',
#     'Airport Deli',
#     'Ajanta India',
#     'Ajisen Ramen',
#     'Akiyama Japanese Restaurant',
#     'Al Cholo Bakery',
#     'Al Di La',
#     'Al Forno',
#     'Al-Dente',
#     'Al-Mehran Restaurant',
#     'Aladdin',
#     'Alba Pizza',
#     "Alba'S Pizza",
#     'Albany Manor',
#     'Albella Ristorante & Bar',
#     "Aldo'S Ii Pizza And Restaurant",
#     "Alex'S Kitchen",
#     "Alfonso'S Bar",
#     "Alfonso'S Pastry Shoppe",
#     "Ali'S Roti Shop",
#     'Alibaba',
#     'Alibi Club',
#     "Alice'S Tea Cup",
#     'Alices',
#     'Aliotta Bake Shop',
#     'All American Coffee Shop',
#     'All American Deli',
#     "Allan'S Bakery",
#     'Alma',
#     'Almar',
#     'Alpha Donuts',
#     'Alta',
#     'Alyshia Aleem Coffee Shop',
#     'Am',
#     'Amaranth',
#     'Amazon Cafe',
#     'Ambassador Dining Room  At Saratoga Family Inn',
#     'Ambassador Theatre',
#     'Ambrosinos Pizzeria',
#     "Amelia'S Restaurant",
#     'Amerada Hess Express Cafe',
#     'American Airlines Employee Cafeteria',
#     'American Coffee Shop',
#     'American Express',
#     "American Hero & Sub'S",
#     'American Museum Of Natural History Food Court',
#     'Americas Burger And Wraps',
#     'Americas Restorante',
#     'Amf 34 Avenue Lanes',
#     'Amma',
#     'Amnon Kosher Pizza',
#     'Amore Pizzeria & Restaurant',
#     'Amsterdam Billiards',
#     'Amsterdam Restaurant & Tapas Lounge',
#     "Amy'S Bread",
#     'An Beal Bocht Cafe',
#     "Andre'S Hungarian",
#     "Andrew'S Coffee Shop",
#     "Andrew'S Diner",
#     'Andrews Coffee Shop',
#     "Andy'S Cafeteria",
#     'Anesis Cafe',
#     'Angel Flakes Patties',
#     'Angelica Kitchen',
#     "Angelica'S Bakery",
#     'Angelika Film Center',
#     'Angelo Of Mulberry St.',
#     "Angelo'S Pizzeria/Mimmo'S Restaurant",
#     'Anglers Club Of New York',
#     'Angry Wades',
#     'Anna Maria Pizza Pasta',
#     "Anna'S Cafe",
#     'Annam Braham Restaurant',
#     'Annelies Pastries',
#     "Annie Moore'S Restaurant",
#     "Annie'S Kitchen",
#     'Anopoli Family Restaurant',
#     'Anotheroom',
#     "Anthony'S Place",
#     'Antica Trattoria',
#     'Antojitos Mexicanos',
#     "Antonio'S Pizza",
#     "Antun'S",
#     'Anyway Cafe',
#     'Anyway Cafe Bar',
#     'Apollo Bakery',
#     'Appetito Restaurant',
#     "Applebaum'S",
#     "Applebee'S Neighborhood Grill & Bar",
#     'Aqua Grill',
#     'Aquamarina',
#     'Aqueduct North',
#     'Arabelle',
#     'Archer Sports Bar',
#     'Archives',
#     'Areo Restaurant',
#     "Aretsky'S Patroon",
#     'Arharn Thai Cuisine',
#     'Ariana Kebab House',
#     'Arirang Hibachi Steak House',
#     'Arirang Hibachi Steakhouse',
#     'Ariyoshi Japanese Restaurant',
#     'Arka Lounge',
#     "Arlene'S Grocery",
#     "Armando'S Pizza",
#     'Arno Ristorante',
#     'Arriba Arriba',
#     'Arte Cafe',
#     'Arte Restaurant',
#     "Arthur'S Tavern",
#     "Artie'S",
#     'Artisanal',
#     "Arturo'S",
#     "Arturo'S Pizza",
#     'Artuso Pastry Shop',
#     'Arzu Restaurant',
#     "Ashby'S Specialty",
#     'Astoria Bagel Shop',
#     'Astra',
#     'Astral Fitness & Wellness',
#     'Astro Restaurant',
#     'Astromundo Restaurant',
#     'Atlantic Grill',
#     'Atlantis Diner',
#     'Au Bon Pain',
#     'Auction House',
#     "Aunt Bella'S Rest Of Little Neck",
#     "Auntie Anne'S Pretzels",
#     'Austin House',
#     "Austin'S Steak & Ale House",
#     'Automatic Slims',
#     'Avellino Restaurant',
#     'Avra Estiatorio',
#     'Ayurveda Cafe',
#     'Azalea',
#     'Azuri Cafe',
#     'Azusa Of Japan',
#     'B & M Hot Bagel & Grocery',
#     'B. Smith Restaurant',
#     'B.B. Kings',
#     'B.Q.E. Cafe Billiards',
#     'B66 Club',
#     'Babbo Ristorante E Enoteca',
#     "Baby Bo'S Burritos",
#     'Back To Nature',
#     'Bad Boys Pizza',
#     'Bagel Bazaar',
#     "Bagel Bob'S",
#     'Bagel Cafe',
#     'Bagel Club',
#     'Bagel Corner',
#     'Bagel Deli / Village Green Deli',
#     'Bagel Depot',
#     'Bagel House',
#     'Bagel Land',
#     'Bagel Shoppe',
#     'Bagel Works',
#     'Bagelman Of Woodside',
#     'Bagels & Cream Deli',
#     'Bagels Deli',
#     'Bagels Etc',
#     'Bahari Estiatorio',
#     'Bahia Restaurant & Cafe',
#     'Bais Rochel',
#     'Bake And Things Restaurant',
#     'Baker Street Pub',
#     "Baker'S Dozen Bagel",
#     'Bali Nusa Indonesian Restaurant',
#     "Ballato'S Restaurant",
#     'Ballfields Cafe',
#     'Bally Total Fitness',
#     'Balthazar Bakery',
#     'Balthazar Restaurant',
#     'Bamboo Garden',
#     'Bamboo Garden Restaurant',
#     "Bamonte'S Restaurant",
#     'Bangal Curry',
#     'Bangkok Grand Palace',
#     'Bangkok Thai House',
#     'Bank Of New York',
#     'Bank Of New York Cafe',
#     'Banshee Pub',
#     'Bar 515',
#     'Bar Association Of The City Of Ny Kitchen',
#     'Bar Coastal',
#     'Bar None',
#     'Bar Six',
#     'Bar Tabac',
#     'Bar Toto',
#     'Bar Veloce',
#     'Bar Vetro',
#     'Baraonda',
#     'Barbaresco',
#     'Barbes',
#     'Barbetta Restaurant',
#     "Barclay'S Capital",
#     'Barfly',
#     'Bari Sandwich Shop',
#     'Barnes & Noble Booksellers',
#     'Barnes & Noble Cafe',
#     'Barney Greengrass',
#     'Barone Pizza',
#     'Barracuda Bar',
#     'Barrage',
#     'Barranquilla Bakery & Restaurant',
#     'Barre Cafe At Steps',
#     'Barries Restaurant',
#     "Barrow'S Pub",
#     'Bartow Pizza',
#     'Baskin Robbins',
#     'Bassett Caterers',
#     'Basta Pasta Restaurant',
#     'Bateaux New York',
#     'Bay Pizzeria Restaurant',
#     'Bay Ridge Manor Catering',
#     'Baybridge Szechuan Restaurant',
#     'Bayridge Pizza',
#     'Beauty Bar',
#     'Beaver Pond',
#     'Becco',
#     'Bedford Cafe & Restaurant',
#     "Behan'S Pub",
#     'Bel Paese Italian Deli',
#     'Bel-Aire Diner',
#     'Belaire Cafe',
#     'Belasco Theatre',
#     'Bella Blu',
#     'Bella Luna',
#     'Bella Napoli',
#     'Bello Giardino',
#     'Bello Restaurant',
#     'Bellrose Deli',
#     'Belmora Pizza & Restaurant',
#     'Belvedere Cafe',
#     'Ben Ash Delicatessen',
#     "Ben'S Deli",
#     "Ben'S Kosher Deli & Restaurant",
#     "Ben'S Pizza",
#     'Ben-Best Deli & Restaurant',
#     'Benjamin',
#     "Bennie'S Thai Cafe",
#     "Benny'S Burritos",
#     "Benny'S Famous Pizza",
#     'Bennys Burritos',
#     'Bergen Bagels',
#     'Bergen Beach Cafe',
#     'Berkely',
#     'Bermay Luncheonette',
#     'Bernard B Jacobs Theater',
#     'Best Deli Cafe',
#     'Beth Torah Kosher Caterers',
#     'Beyoglu',
#     'Biarritz Bakery',
#     'Bicheiros Bar',
#     "Big Al'S Chicago Pizza",
#     'Big Als Chicago Pizza',
#     'Big Bar',
#     "Big Daddy'S Diner",
#     'Big Jons Pizza & Restaurant',
#     'Big New York Fried Chicken',
#     "Bijan'S",
#     "Bill'S Restaurant",
#     'Billiard Company',
#     "Billy'S Sport Bar Restaurant & Lounge",
#     'Billymarks West',
#     'Birdland',
#     'Bistro Citron',
#     'Bistro Les Amis',
#     'Bistro Ten-18',
#     'Bits Bite & Baguettes',
#     'Black And White',
#     'Black Fat Pussy Cat',
#     'Black Rock Cafe',
#     'Black Whale',
#     'Blake & Todd',
#     'Blanches @ Dkny',
#     'Blarney Bar',
#     'Blarney Castle',
#     'Blarney Rock',
#     'Blarney Stone',
#     'Bleecker Street Bar',
#     'Blimpie',
#     'Bliss Bakery & Cafe',
#     'Bliss Street Station Restaurant',
#     "Blockhead'S Burritos",
#     "Blockhead'S Mexican Diner",
#     'Blockheads',
#     'Blockheads Burritos',
#     'Blondies',
#     'Blue & Gold Bar',
#     'Blue & Gray Inn',
#     'Blue Bay Diner',
#     'Blue Bay Restaurant',
#     'Blue Diner',
#     'Blue Fin',
#     'Blue Hill Restaurant',
#     'Blue Mountain Restaurant & Jerk Center',
#     'Blue Note Jazz',
#     'Blue Ribbon',
#     'Blue Ribbon Brasserie',
#     'Blue Ribbon Sushi',
#     'Blue Smoke',
#     'Blue Water Grill',
#     'Bluestockings Womens Bookstore Cafe',
#     "Bobby Van'S",
#     "Bobby'S Coffee Shop",
#     'Bocca',
#     'Bocca Di Bacco',
#     'Bocelli',
#     'Bombay Masala',
#     'Bond St',
#     'Bonelle Pastry Shop',
#     "Bonnie'S Grill",
#     "Bono'S Cafe",
#     'Book Chang Dong Sodndubu',
#     'Booth Theater',
#     'Boots & Saddle Bar',
#     'Boston Jerk-City Restaurant',
#     'Boston Market',
#     'Boston Pizza',
#     'Botanica Bar',
#     'Bottino',
#     'Boulevard Tavern',
#     'Bourbon Street',
#     'Bowery Eletric',
#     'Bowler Land',
#     'Bowlmor Chelsea Piers',
#     'Box Car Lounge',
#     "Brady'S Bar",
#     "Brandy'S Piano Bar",
#     'Brasserie Athenee',
#     'Brasserie Les Halles',
#     "Braulio'S & Family Restaurant",
#     'Bravo Cafe Concert',
#     'Bravo Pizza',
#     'Brazil Grill',
#     'Bread',
#     'Bread Market Cafe',
#     "Brendan'S",
#     'Brennan & Carr',
#     'Bricco Restaurant',
#     'Bridgeview Diner',
#     'Brioso Ristorante',
#     'Broadhurst Theater',
#     'Broadway Bagel',
#     'Broadway Dive',
#     'Broadway Lounge',
#     'Broadway Pizza & Pasta',
#     'Broadway Restaurant',
#     'Broadway Station',
#     'Broadway Theatre',
#     'Bronx Grill',
#     'Brooklyn Botanic Catering Hall',
#     'Brooklyn Diner',
#     'Brooklyn Ice Cream Factory',
#     'Brooklyn Moon Cafe',
#     'Brooklyn Pizza',
#     'Brooklyn Pizza Ii',
#     'Brooks Atkinson Theater',
#     'Broome Street Bar',
#     "Brother Jimmy'S Bbq",
#     'Brunos On The Boulevard',
#     "Bubby'S",
#     'Buccaneer Diner',
#     "Buddy'S Burrito & Taco Bar",
#     "Buddy'S Wonder Bar",
#     'Bull Head Tavern',
#     'Bull Mccabes',
#     'Bull Shots',
#     "Bully'S Deli",
#     'Bum Bum Bar',
#     'Bungalow Bar & Restaurant',
#     'Buona Notte Ristorante',
#     'Buono Bakery',
#     "Burek'S Pizza",
#     'Burger Barn Restaurant',
#     'Burger Heaven',
#     'Burger King',
#     'Burger King/Metro Mall',
#     'Burgers & Cupcakes',
#     "Burke'S Pub",
#     'Burrito Box',
#     'Burrito Loco',
#     'Bus Stop Cafe',
#     'Buzz',
#     'C & B Luncheonette',
#     'C & C Catering',
#     'C & C Catering Service',
#     'C.U.N.Y Cafe',
#     'Cabana',
#     "Caesar'S Palace",
#     'Cafe 101',
#     'Cafe 101 16Th Floor Cafeteria',
#     'Cafe 212/Columbia Catering Kitchen - Alfred Lerner Hall',
#     'Cafe 31',
#     'Cafe 75 Bar',
#     'Cafe Al Mercato',
#     "Cafe Amore'S Restaurant",
#     'Cafe Angelique',
#     'Cafe Angus',
#     'Cafe Asean',
#     'Cafe Atelier (Art Students League)',
#     'Cafe Bar',
#     'Cafe Bella Vita',
#     'Cafe Beyond',
#     'Cafe Bonjour',
#     'Cafe Borgia Ii',
#     'Cafe Bravo',
#     'Cafe Buon Gusto',
#     'Cafe Capri',
#     'Cafe Cardini',
#     'Cafe Cello Deli',
#     'Cafe Champignon',
#     'Cafe Duke',
#     'Cafe Edison',
#     'Cafe Eighty Two',
#     'Cafe Espanol',
#     'Cafe Express',
#     'Cafe Frida',
#     'Cafe Gitane',
#     'Cafe Joul',
#     'Cafe K',
#     'Cafe Lalo',
#     "Cafe Lou'S",
#     'Cafe Loup',
#     'Cafe Luka',
#     'Cafe Luluc',
#     'Cafe Luna',
#     'Cafe Luxembourg',
#     'Cafe Madison',
#     'Cafe Mae Mae',
#     'Cafe Metro',
#     'Cafe Mogador',
#     'Cafe Ole Usa',
#     'Cafe Orlin',
#     'Cafe Paris',
#     'Cafe Rakka',
#     'Cafe Renaissance',
#     'Cafe Riazor',
#     'Cafe Ronda',
#     'Cafe Rustico Ii',
#     'Cafe Sabarsky',
#     'Cafe Spice',
#     'Cafe Steinhof',
#     'Cafe Un Deux Trois',
#     'Cafe Volna',
#     'Cafe Zaiya',
#     'Cafeteria',
#     'Cafeteria- Lirr Employees',
#     'Caffe Buon Gusto',
#     'Caffe Dante',
#     'Caffe Egidio',
#     'Caffe Grazie',
#     'Caffe Linda',
#     'Caffe Napoli',
#     'Caffe Palermo',
#     'Caffe Reggio',
#     'Caffe Roma',
#     'Caffe Venezia',
#     'Caffe Vivaldi',
#     "Caffe' Romeo",
#     'Caffee Express',
#     'Caliente Cab Co',
#     'Cambridge Caterers',
#     'Camilles',
#     'Campagnola Restaurant',
#     'Campanile',
#     'Campeon',
#     'Campus Eatery',
#     'Canaletto Ristorante',
#     'Canard Inc',
#     'Candies Bar',
#     'Candle Bar',
#     'Candle Cafe',
#     "Canlon'S Restaurant",
#     'Canyon Road Grill',
#     'Capitol Restaurant',
#     'Cappuccino Cafe',
#     'Capri Bakery',
#     'Capri Ii Pizza',
#     'Capri Pizza Restaurant',
#     'Caprice',
#     "Captain'S Pizzeria And Restaurant",
#     'Cara Mia',
#     'Caravan Chicken',
#     'Caravan Of Dreams',
#     'Caribbean Sports',
#     'Caridad',
#     'Caridad Restaurant',
#     'Carleton Lounge - Mudd Building',
#     'Carlos Pizza',
#     'Carlow East',
#     "Carmine'S",
#     "Carmine'S Restaurant",
#     'Carnegie Delicatessen & Restaurant',
#     "Carol'S Cafe",
#     "Caroline'S On Broadway",
#     'Carom Cafe Billiards',
#     'Carry On Tea & Sympathy',
#     'Caruso Pizza #2',
#     'Caruso Pizzeria & Restaurant',
#     'Carvel',
#     'Carvel Ice Cream',
#     'Casa',
#     'Casa Bella',
#     'Casa Java',
#     'Casa Pepe',
#     'Casa Promesa',
#     'Casabianca Pizzeria',
#     'Casanova Restaurant',
#     "Cascarino'S",
#     "Cascarino'S Pizza",
#     "Cassidy'S Ale House",
#     'Cassis Bistro/Brasserie',
#     'Castlehill Diner',
#     "Catania'S Pizza Cafe",
#     "Caterina'S Pizza",
#     "Caterina'S Pizzeria",
#     "Cavallo'S Pizzeria",
#     'Cavatappo Grill',
#     'Cavo',
#     'Cbs Employee Cafeteria',
#     'Cea Lo Cafe',
#     'Cebu',
#     "Celeste'S Snack Bar",
#     'Central Cafe',
#     'Central Park Boathouse',
#     "Cha Cha'S Backyard Garden Bar & Cafe",
#     'Chadash Falafel & Pizza',
#     "Chadwick'S",
#     'Champ Gourmet',
#     "Champ'S Deli",
#     'Champion Bakery',
#     "Chan'S Kitchen",
#     'Chap A Nosh/Yun Kee',
#     "Charle'S Corner Restaurant & Deli",
#     'Charles Pizzeria',
#     "Charlie'S Mom Chinese Restaurant",
#     'Charlies Sports Bar',
#     'Charo Restaurant',
#     'Chase Edr',
#     'Che Bella Pizza',
#     'Checkers',
#     "Chef Ho'S",
#     'Cheito Duran Deli Grocery',
#     'Chelsea Square Restaurant',
#     'Chelsea Trattoria',
#     "Chen'S Chinese",
#     'Cherokee Deli',
#     'Cherry Tavern',
#     'Chez Jaqueline',
#     'Chez Josephine',
#     'Chez Napolean',
#     "Chic-Fil-A, Quiznos Subs, Jw'S, Tossed",
#     'Chick-N-Ribs',
#     'Chicken Delicious',
#     'Chicken Festival',
#     'Chickpea',
#     'China Chalet',
#     'China Fun',
#     'China Glatt',
#     'China Grill',
#     'China New Star',
#     'China Wok Ii',
#     'Chinantla',
#     'Chirping Chicken',
#     'Chiu Hong Bakery',
#     'Cho Dang Gol',
#     'Cho-Sen Garden',
#     "Chock Full O' Nuts",
#     "Chop'T",
#     'Chopstix Restaurant',
#     'Choy Le Chinese Restaurant',
#     "Christie'S",
#     "Christina'S Restaurant",
#     "Chuck E Cheese'S",
#     'Churrascaria Plataforma',
#     'Ciao Bella',
#     "Cibar - Lady Mendl'S Tea Salon",
#     'Cibo',
#     'Cilantro',
#     'Cindy Restaurant Luncheonette',
#     'Cinema Cafe & Bar',
#     'Cinema The Brasserie',
#     'Cinnabon World Famous Cinnamon Rolls',
#     'Cipriani Dolci',
#     'Cipriani Downtown Restaurant',
#     'Circa Tabac',
#     'Circle In The Square Theatre',
#     'Circle Pizzeria',
#     "Circle'S Grill",
#     'Circo Pastry Shop',
#     'Circo Restaurant',
#     'Ciro Pizza',
#     "Ciro'S Pizza Restaurant",
#     'Ciros Pastry Shop',
#     'Citibank Employee Cafeteria',
#     'Citibank Executive Conference Center',
#     'Citrus Bar & Grill',
#     'City Chow Cafe',
#     'City Chow Cafe V (Equinox)',
#     'City College Cafeteria',
#     'City Crab',
#     'City Hall Restaurant',
#     'City Island Deli',
#     'City Island Diner /Snug Bar',
#     'City Lobster & Steak',
#     'City Market Cafe',
#     'City Pie',
#     "Cj Sullivan'S",
#     'Claddagh Inn',
#     "Clark'S Restaurant",
#     'Classic Coffee Shop',
#     'Cleary Gottlieb',
#     "Cleopatra'S Needle",
#     'Clinton Restaurant',
#     'Clinton Street Baking Company',
#     'Cloister Cafe',
#     'Club 101',
#     'Club Macanudo (Cigar Bar)',
#     'Club Metropolitan',
#     'Cobblestone Pub',
#     'Cocktail Room (Nyac)',
#     "Cody'S Ale House Grill",
#     'Coffee Express',
#     'Coffee Shop',
#     'Coliseum Bar Restaurant',
#     'Collado Restaurant',
#     'Colonnade Diner',
#     'Colony Club',
#     'Columbo Yogurt/ Taco Bell/ Nathans/ Tim Horton/Pizza Hut',
#     'Columbus Citizens Foundation',
#     'Columbus Gourmet Food',
#     'Columbus House',
#     'Comic Strip',
#     'Community Food And Juice',
#     'Como Pizza',
#     'Concession # 110',
#     'Concession # 120/ The Bullpen',
#     'Concession Stand  330',
#     'Concourse Jamaican Bakery',
#     'Connecticut Muffin',
#     "Connie O'S",
#     "Connolly'S",
#     "Connolly'S Corner",
#     "Connolly'S Pub",
#     'Constantines Deli',
#     "Conti'S",
#     'Continental Luncheonette & Deli',
#     'Convivium Osteria',
#     "Coogan'S",
#     "Cookie'S Lounge",
#     'Cool Zone',
#     'Cooper Town Diner',
#     'Coopers Tavern',
#     'Copper Kettle',
#     "Coppola'S",
#     'Coral Diner',
#     'Corato I Pizza & Restaurant',
#     'Corato Pizza Ii',
#     'Cornelia Street Cafe',
#     'Corner Bistro',
#     'Corner Cafe And Bakery',
#     'Corner Gourmet Ii',
#     'Cort Theatre',
#     'Cositas Ricas',
#     'Cosmos Restaurant',
#     'Costco Wholesale',
#     'Country Donuts',
#     'Court Order',
#     'Court Square Diner',
#     'Courtyard By Marriott',
#     "Cousin John'S Cafe And Bakery",
#     'Cowgirl Hall Of Fame',
#     'Coyote Ugly',
#     'Cozy Soup & Burger',
#     'Crab Shanty',
#     'Craft',
#     "Cranberry'S",
#     'Cravath Cafe',
#     'Create & Go',
#     'Creative Cakes',
#     'Creative Edge Caterers',
#     'Credit Agricole',
#     'Credit Agricole-Cbi Executive Room',
#     'Crescent Corner',
#     "Crif Dogs / Please Don'T Tell",
#     'Criminal Court Bldg Cafeteria',
#     'Cronin & Phelan Pub & Restaurant',
#     'Crossbay Diner',
#     'Crossroads (Marriott Marquis)',
#     'Crosstown Diner',
#     'Crown Diner',
#     'Crown Fried Chicken',
#     'Crown Gourmet Deli',
#     'Crystal Curry House',
#     'Crystal Manor',
#     'Crystal Palace',
#     'Crystal Room',
#     'Cuccios Bakery',
#     'Cuchifrito',
#     'Cuchifritos',
#     'Cucina Di Pesce',
#     'Cucina Gourmet',
#     'Cucina Vivolo',
#     'Culinart Cafe',
#     "Cullen'S Tavern",
#     'Cup & Saucer',
#     'Curry In A Hurry',
#     "Curves Gentleman'S Club",
#     'D & P Restaurant & Cocktail',
#     "D'Angelo'S Pizzeria And Restaurant",
#     "D'Aquila Bakery",
#     'D.B.A.',
#     'Da Marino Restaurant',
#     'Da Mikelle Ii',
#     'Da Nico Restaurant',
#     'Da Rosina Restaurant',
#     'Da Silvano Restaurant',
#     'Da Tommasso',
#     'Da Umberto Restaurant',
#     'Da Vinci Pizza',
#     "Daddy'S",
#     'Dagan Pizza',
#     'Dagan Pizza & Dairy Restaurant',
#     'Dairy Luncheonette',
#     'Dallas Bbq',
#     'Dan Tempura',
#     'Dancing Crane Cafe (Bx Zoo)',
#     "Dangerfield'S Night Club",
#     'Dani Pizza And Restaurant',
#     'Daniel',
#     "Daniel'S Bagel",
#     "Daniello'S Pizzeria",
#     'Danny Blaine',
#     "Danny'S Deli",
#     "Danny'S Pizzeria & Cafe",
#     "Danny'S Pizzeria Ii",
#     "Dante'S Gourmet Food",
#     "Dave'S Tavern",
#     'Davis Polk Dining Room',
#     'Dazies Restaurant',
#     'Db Bistro Moderne',
#     'De Robertis Pastry Shop',
#     "Deacon Brodie'S",
#     'Death & Co',
#     "Deb'S",
#     'Debevoise & Plimpton',
#     "Defonte'S Sandwich Shop",
#     'Del Corso Pizzeria',
#     "Del Frisco'S",
#     'Deli Plus ( Inside Port Authority Station)',
#     'Delias Lounge Cafe',
#     'Delight Donut',
#     'Delmonico Gourmet',
#     "Delmonico'S Kitchen",
#     'Delmonicos',
#     'Delta Grill',
#     'Deluxe',
#     'Demarchelier Restaurant',
#     "Dempsey'S Pub",
#     "Denino'S Pizzeria Tavern",
#     "Dennis' Place",
#     "Denny'S Pub",
#     "Desmond'S Tavern",
#     'Desseo Night Club',
#     'Deux Amis',
#     'Devasthanam Canteen',
#     'Devon & Blakely',
#     "Di Luvio'S Deli",
#     'Diamante Poblano Restaurant',
#     "Digby'S",
#     'Dim Sum Go Go',
#     'Dinastia China',
#     'Diner',
#     'Dining Room',
#     "Dino'S Pizza & Pasta",
#     'Distilled',
#     'Dive 75',
#     'Dive Bar',
#     'Divers Cove',
#     'Diwan-E- Khaas',
#     'Diwan-E-Khaas',
#     "Dizzy'S Restaurant",
#     'Dj Reynolds Pub And Restaurant',
#     'Do Hwa',
#     'Doc Holidays',
#     'Doc Watsons',
#     'Doc Wine Bar',
#     'Dock Street Bar & Grill',
#     'Dojo Restaurant',
#     'Dolcino Trattoria Toscana',
#     "Dominick'S Bar & Restaurant",
#     "Domino'S Pizza",
#     'Don Alex Restaurant',
#     'Don Coqui',
#     'Don Filippo Restaurant',
#     'Don Giovanni Restaurant',
#     'Don Paco  Lopez Panderia',
#     'Don Pedro Restaurant',
#     'Don Pepi Pizza',
#     'Don Pepis Delicatessen',
#     'Don Peppe',
#     "Donato'S Pizzeria Restaurant",
#     "Donohue'S Steak House",
#     'Donut Pub',
#     'Donut Stop',
#     'Doral Donuts',
#     "Dorrian'S Red Hand Restaurant",
#     'Dosa Hutt',
#     'Double Dragon',
#     'Douglaston Club',
#     'Douglaston Golf Snacks',
#     'Down The Hatch',
#     'Down Town Association',
#     'Downtown Bakery Ii Mexican Food',
#     'Downtown Deli',
#     "Doyle'S Corner",
#     'Dragon City',
#     'Dragon Land Bakery',
#     'Dream Pizza',
#     'Dublin 6',
#     'Due',
#     "Duffy'S",
#     "Duke'S",
#     'Dunkin Donuts',
#     "Dunkin' Donuts",
#     "Dunkin' Donuts  Baskin Robbins",
#     "Dunkin' Donuts Baskin Robbins",
#     "Dunkin' Donuts, Baskin Robbins",
#     "Dunkin' Donuts/Baskin Robbins",
#     "Dunkin' Donuts/Baskin Robins",
#     "Dunkin' Donuts/Baskin' Robbins",
#     "Dunkin' Donuts/Subway",
#     'Dyckman Bar',
#     'Dyckman Express Restaurant',
#     'Dyker Beach Golf (Grill Room)',
#     'Dyker Park Bagels',
#     "Dylan'S Candybar",
#     'Dynasty',
#     'E & L Bakery & Coffee Shop',
#     'E-Dah Korean Bbq Lounge',
#     'E.A.T. Cafe',
#     'E.J Luncheonette',
#     'Ear Inn',
#     'East Dynasty',
#     'East Japanese Restaurant/ Bar',
#     'East Of Eighth',
#     'Eastwood Manor',
#     'Eat-A-Bagel (Andrew J. Barbery Ferry Boat)',
#     'Eatery Restaurant',
#     'Ebe Ye Yie African Restaurant',
#     "Edward'S",
#     "Egger'S Ice Cream Parlor",
#     'Egyptian Coffee Shop',
#     'El Aguila Bakery',
#     'El Anzuelo Fino Restaurant',
#     'El Azteca Mexican Restaurant',
#     'El Boqueron Tapas Bar & Restaurant',
#     'El Buen Ambiente',
#     'El Cantinero',
#     'El Caramelo Coffee Shop',
#     'El Caribe',
#     'El Castillo De Jagua Rest',
#     'El Castillo De Madison',
#     'El Centro',
#     'El Charro Bakery',
#     'El Charro Espanol',
#     "El Chivito D'Oro Iii",
#     'El Continental Restaurant',
#     'El Cuencanito',
#     'El Dorado Cafe',
#     'El Dorado Sports Lounge',
#     'El Familar Restaurant',
#     'El Gauchito Restaurant',
#     'El Greco Diner',
#     'El Hornero Bakery',
#     'El Lina Restaurant',
#     'El Loco Burrito',
#     'El Malecon Restaurant',
#     'El Mariachi Restaurant',
#     'El Molino Rojo Restaurant',
#     'El Nuevo Amanecer Restaurant',
#     'El Nuevo Ambiente Restaurant',
#     'El Nuevo Cafe Latino',
#     'El Nuevo Conquistador',
#     'El Olivo',
#     'El Paraiso Bar & Restaurant',
#     'El Pollo Peruano',
#     'El Pote Espanol',
#     'El Pulgarcito De America',
#     'El Ranchito De Daisy',
#     'El Rey De La Caridad',
#     'El Rey Mexican Restaurant',
#     'El Rinconcito Restaurant',
#     'El Rio Grande',
#     'El Rumbero Bar Restaurant',
#     'El Salvador Restaurant',
#     'El Sitio Restaurant',
#     'El Tina Fish Market & Seafood Restaurant',
#     'El Vaquero Barras',
#     'Elegante Pizza',
#     "Eleni'S New York",
#     'Elephant & Castle',
#     'Elia',
#     'Elias Corner For Fish',
#     "Elio'S",
#     "Ellen'S Stardust Diner",
#     'Elmhurst Famous Pizza',
#     'Elmo',
#     'Elora Restaurant',
#     'Emerald Pub',
#     "Emilia'S Restaurant",
#     'Emilio Iii Bar',
#     'Empire Szechuan Noodle House',
#     'Empire Szechuan Village',
#     'Empire Wok Kitchen',
#     'Emporium Brasil Restaurant',
#     "Enid'S",
#     'Ennju',
#     'Enzo Cafe',
#     'Erawan Thai Cuisine',
#     "Erin'S Isle",
#     'Erminia Restaurant',
#     'Ernst & Young Cafe',
#     "Errol'S Bakery",
#     'Esca',
#     'Escuelita Club',
#     'Esperanto',
#     'Ess-A-Bagel',
#     'Essex',
#     'Estancia 460',
#     'Estelle',
#     'Estiatorio Milos',
#     'Estihaya Asian Restaurant',
#     'Ethel Barrymore Theater',
#     'Ethos Greek Cuisine',
#     'Eurest Dining Service (American Express)',
#     'Euro Pizza',
#     'Europa Cafe',
#     'Europa Go-Go Dancing',
#     'Europa Night Club',
#     'Euzkadi',
#     'Everest Diner',
#     'Evergreen Restaurant',
#     "Evodio'S Place",
#     'Evolution',
#     'Excelsior Catering',
#     "Fabiane'S Cafe & Pastry",
#     'Faces & Names',
#     'Failte',
#     'Fame Diner',
#     'Family Corner',
#     'Family Pizza',
#     'Famous Bagel Buffet',
#     "Famous Ben'S Pizza Of Soho",
#     'Famous Famiglia Pizza',
#     'Famous Fish Market',
#     "Famous Joe'S Pizza",
#     'Famous Pizza',
#     'Faros Restaurant',
#     "Fascati'S Pizzeria",
#     'Fay Da Bakery',
#     'Feeding Tree Style West Indian Restaurant',
#     'Fei Teng Bakery',
#     'Felice 64 Wine Bar',
#     'Felidia Restaurant',
#     'Felix',
#     "Fella'S Bar",
#     "Ferdinando'S Restaurant",
#     "Ferrara'S",
#     'Ferris Booth Commons - Alfred Lerner Hall',
#     'Fifth Ave Cafe /Diner',
#     'Fifth Avenue Bingo',
#     'Fine & Shapiro',
#     'Finestra',
#     "Finnegan'S Wake",
#     'Fiorellos',
#     'Fiorentino Ristorante',
#     'Firehouse',
#     'Firenze',
#     'Fireside',
#     'Firozas Roti Bar',
#     'Fish',
#     'Fish Bar',
#     "Fisherman'S Cove",
#     'Fit Cafeteria (Building A)',
#     "Fitzgerald'S Pub",
#     'Flagship Diner',
#     'Flame Restaurant Coffee House',
#     'Flamingo',
#     "Flannery'S Bar",
#     'Flash Dancers',
#     'Flight 151',
#     'Flik International',
#     "Fluffy'S Cafe & Bakery",
#     'Flushing Meadows Pitch And Putt',
#     'Flute',
#     "Foley'S N.Y. Pub And Restaurant",
#     'Fontana Famous Pizza & Gyro',
#     'Food Fair Deli & Pizza',
#     'Food For Thought Catered Events',
#     'Food Mart Deli',
#     'Food Merchants',
#     'Footprints Cafe',
#     'Ford Foundation Cafeteria',
#     'Fordham Fried Chicken & Sea Food',
#     'Fordham Seafood And Chicken',
#     'Fordham University - Mcginley Center',
#     'Fordham University - Millenium Grill',
#     'Fordham University - Ram Cafeteria',
#     'Fordham University - Student Deli',
#     'Fordham University/Mcginley Center/Ramskeller Kitchen',
#     'Forest Hills Coffe Shop',
#     'Forest Hills Spa',
#     'Forest Park Golf Course',
#     'Forlinis Restaurant',
#     'Fortunato Bros Cafe & Bakery',
#     'Fountain Of Youth Health Spa Juice Bar & Dinner',
#     'Four Seasons Hotel',
#     'Fragole',
#     "Francesco'S Pizzeria Restaurant",
#     "Francisco'S Centro Vasco",
#     'Franco Bakery',
#     'Frank',
#     "Frank'S Pizza",
#     "Frank'S Pizza Restaurant",
#     "Frank'S Pizzeria",
#     "Frank'S Place",
#     "Frank'S Soup Bowl",
#     'Frankie & Johnnies Steakhouse',
#     'Fratelli Pizza',
#     "Fred'S",
#     "Fred'S At Barney'S",
#     "Freddie & Pepper'S Pizza",
#     'French Roast',
#     'Fresco',
#     'Fresco Bar Cafe Restaurant',
#     'Fresco On The Go',
#     "Fresh Meadow'S Pizza & Restaurant",
#     'Friars National Assoc.',
#     'Friend Of A Farmer',
#     "Friend'S Tavern",
#     'Friends Deli',
#     'Front Street Pizza',
#     'Frost Restaurant',
#     'Fuji Bakery',
#     'Full Moon Pizza',
#     'Funtopia Usa',
#     'G',
#     'G.P. Diner',
#     "Gabriel'S Bar & Grill",
#     "Gaby'S Pizza",
#     'Galicia Bar',
#     'Galicia Restaurant',
#     "Gallagher'S 2000",
#     'Gandhi',
#     'Gandhi Indian Cuisine',
#     'Garden Cafe Restaurant',
#     'Garden Grill',
#     'Garden Of Eat-In',
#     "Gargiulo'S Restaurant",
#     "Gary And Gino'S",
#     'Gaslight',
#     "Gaudio'S Pizzeria",
#     'Geido Restaurant',
#     'Gemini Diner',
#     "Gemini'S Lounge",
#     "Gene'S Coffee Shop",
#     "Gene'S Resturant",
#     'Genesis # 1 West Indian',
#     "Gennaro'S Catering Hall",
#     "Gennaro'S Rest & Pizzeria",
#     'Gente',
#     'George Keeley',
#     'Georges Restaurant',
#     'Georgia Diner',
#     'Georgios Country Grill',
#     'Gershwin Theatre',
#     'Ghandi Cafe',
#     'Giacomo Fine Foods',
#     'Gian & Pier Bakery',
#     'Giando',
#     'Giardino Ristorante',
#     "Gigi'S Pizzeria",
#     'Gigino At Wagner Park',
#     'Gigino Trattoria',
#     "Gina'S Pizza",
#     'Ginger',
#     "Ginger'S Bar",
#     "Gino'S Pastry Shop",
#     "Gino'S Pizza",
#     "Gino'S Pizzeria",
#     "Gino'S Pizzeria Restaurant",
#     'Gioiosa Caffe Expresso',
#     "Giorgio'S Of Gramercy",
#     'Giovanni 25',
#     "Giovanni'S Restaurant & Cafe",
#     'Giralda Bakery',
#     'Girasol Bakery',
#     "Glaser'S Bakery",
#     'Glatt Kosher Family Chinese Restaurant',
#     "Gleason'S Cafe",
#     "Glen Patrick'S Pub",
#     'Glen Roy Bar And Grill',
#     'Glen Terrace',
#     "Glenda'S Restaurant",
#     'Glendale Bakeshop & Cafe',
#     'Glendale Pizza',
#     'Glenlo Tavern',
#     "Gloria'S In And Out #3",
#     'Glorious Food',
#     'Glory Deli',
#     'Gnocco',
#     'Gold Bar B',
#     "Gold'S Gym",
#     'Golden Crown Bakery',
#     'Golden Dove Diner',
#     'Golden Horse Chinese Rest',
#     'Golden Krust Caribbean Bakery & Grill',
#     'Golden Pavillion',
#     'Golden Pizza',
#     'Golden Theatre',
#     'Good Enough To Eat (A.G. Bistro)',
#     'Good Restaurant',
#     'Good Shepherd Services',
#     "Goody'S Bbq",
#     "Goody'S Spanish Food",
#     'Gotham Bar & Grill',
#     'Gotham Cafe (Inside Holiday Inn)',
#     'Gottscheer Hall',
#     'Gourmet Grill',
#     'Gourmet On J',
#     'Gradisca Restaurant',
#     'Gramercy Cafe',
#     'Grand Avenue Pizza',
#     'Grand Canyon',
#     'Grand Havana Room',
#     'Grand Hyatt New York Hotel',
#     'Grand Morelos Diner & Bakery',
#     'Grand Plaza',
#     'Grand Street Deli & Mini Market',
#     'Grandstand Tavern',
#     'Grano Trattoria',
#     'Grassroot Tavern',
#     "Gray'S Papaya",
#     'Great Jones Cafe',
#     'Great Kills Yacht Club',
#     'Great N.Y. Noodletown',
#     'Great Wall Restaurant',
#     'Green House Cafe',
#     'Green Pavilion Restaurant & Sports Lounge',
#     'Green Trees',
#     'Greenhouse Cafe (557 Broaday) Scholastic Building',
#     'Greenpoint Tavern',
#     'Greenwood Bakery',
#     'Griffis Faculty Club',
#     "Grini'S Grill & Restaurant",
#     'Grotto Azzura Pizzeria',
#     'Ground Level Beer Pub',
#     "Guastavino'S",
#     'Guayoyo',
#     'Gun Post Lanes Snack Bar',
#     'Gurra Cafe',
#     "Gussy'S Bar",
#     'Gustosa Pizza',
#     'Guy & Gallard',
#     'Gyro King',
#     'H & H Midtown Bagels East',
#     'Haagen-Dazs',
#     'Hairos Night Club',
#     'Hale & Hearty Soups',
#     'Hallmark Deli',
#     'Hallo Berlin',
#     'Hamilton Deli',
#     'Hampton Chutney Company',
#     'Han Bat Restaurant',
#     'Han Gawi',
#     'Hana Sushi',
#     'Hangar Bar',
#     'Hanover Gourmet Deli',
#     'Hanson Gourmet Deli & Cafe',
#     'Hanson Restaurant And Pizzeria',
#     'Hapisgah Restaurant',
#     'Happy Fortune',
#     'Happy Garden',
#     'Happy Restaurant',
#     'Harbor Pizza',
#     'Harlem Bar-B-Q',
#     'Harmonie Club',
#     "Harriet'S Kitchen",
#     "Harry'O",
#     "Harry'S Burrito Junction",
#     'Haru',
#     'Haru Sake Bar',
#     'Harvard Club',
#     'Hasaki Restaurant',
#     'Hatsuhana Restaurant',
#     'Havana Alma De Cuba',
#     'Havana Ny',
#     'Haveli',
#     'Health King',
#     "Healy'S Pub",
#     'Heartland Brewery',
#     "Hector'S Cafe & Diner",
#     'Heidelberg Restaurant',
#     'Heights Cafe',
#     "Hell'S Kitchen",
#     'Hello Deli',
#     'Henrietta Hudson',
#     'Henry St. Ale House',
#     "Henry'S",
#     "Henry'S End",
#     'Hero Champ',
#     'Hi Fi',
#     'Hi Life Bar & Grill',
#     'Hidden Cottage',
#     'Highlands Cafe Restaurant',
#     'Highway Bagels',
#     'Highway Deli And Coffee Shop',
#     'Hill Tap Tavern',
#     'Hillel Bagels',
#     'Hillside Gourmet',
#     'Hillstone Manhattan',
#     "Hillstone'S",
#     'Ho Mei Restaurant',
#     'Hogs & Heifers',
#     'Holland Bar',
#     "Holtermann'S Bakery",
#     'Home Deli & Catering',
#     'Homestretch Bar',
#     'Hong Cheong',
#     'Hong Fung Bakery',
#     'Hong Kong Restaurant',
#     'Hooters',
#     'Hop Kee Restaurant',
#     'Hop Lee Kitchen',
#     'Hop Won Express',
#     'Hornado Ecuatoriano',
#     'Hot & Crusty Bagels Cafe',
#     'Hot & Crusty Bakery',
#     'Hot Bagels',
#     'Hot Bagels & Cafe',
#     'Hotel Carlyle',
#     'House Of Brews',
#     'Housing Works Food',
#     'Hsbc Bank',
#     'Hudson Bar And Books',
#     'Hudson Place',
#     "Hunan ''K'' Chinese Restaurant",
#     'Hunan Balcony',
#     'Hungarian Pastry Shop',
#     "Hunter'S Steak & Ale House",
#     "Hurley'S Saloon",
#     'Hyatt, Ny Central/Room Service',
#     'Hyo Dong Gak',
#     'I Trulli Restaurant',
#     'I.O. Cafe',
#     'Ibm Executive Dining Room',
#     'Ideal Donut',
#     "Ifh El Buffet Restaurant  Alberto'S Mofongo House",
#     "Iggy'S",
#     'Igloo Ice Cream Cafe',
#     'Iguana Restaurant',
#     'Iguanas',
#     'Ihawan',
#     'Ihop',
#     'Il Buco Restaurant',
#     'Il Cantinori Restauraunt',
#     'Il Cortile Restaurant',
#     'Il Fornetto Trattoria Cafe',
#     'Il Mulino',
#     'Il Palazzo',
#     'Il Postino',
#     'Il Posto',
#     'Il Posto Accanto',
#     'Il Riccio Restaurant',
#     'Il Toscano Ristorante',
#     'Il Vagabondo Restaurant',
#     'Il Violino',
#     "Ilda'S Place Ii",
#     'Imperial Biker Bar',
#     'Imperial Coffee House',
#     'Imperial Theatre',
#     'India Passage Restaurant',
#     'Indian Taj',
#     'Indigo Indian Cuisine',
#     'Indo Chine',
#     'Ing Forman Selz',
#     'Intermisson Cafe',
#     'International Restaurant',
#     'Internationalhouse',
#     "Iona'S Bar",
#     'Ipanema Bar',
#     'Ipanema Restaurant',
#     "Irene'S Place",
#     'Irish Brigade',
#     'Irish Cottage',
#     'Irish Eye Bar',
#     'Irish Punt',
#     'Iroha Japanese Restaurant',
#     'Iron Chef House',
#     "Isabela'S Mexican Cuisine",
#     'Ise Japanese Restaurant',
#     'Isla Restauraunt',
#     'Island',
#     'Island Burgers And Shakes',
#     'Island Chateau',
#     'Island Shores',
#     'Island Taste',
#     'Isle Of Capri Resturant',
#     'Istanbul Restaurant',
#     'Italian Village Restaurant Pizzeria',
#     'Italy Pizza & Restaurant',
#     'Izalco Restaurant',
#     'J & C Seafood',
#     'J & J Restaurant & Cuchifritos',
#     'J & M Bakery',
#     'J & R Pizza',
#     'J & S Pizza',
#     "J 'S Pizza",
#     'J And D Pizza',
#     'J And L Deli',
#     'J&V Famous Pizza',
#     'J.E. Bakery',
#     'J.J. Bubbles',
#     "J.R'S Cabaret",
#     "Jack'S Pizza & Pasta",
#     "Jack'S Restaurant & Bar",
#     "Jackie'S West Indian Bakery",
#     'Jacks Ale House',
#     'Jackson Hole',
#     'Jackson House Restaurant',
#     "Jacque'S Cafe",
#     'Jade Seneca Oriental Restaurant',
#     "Jahn'S Restaurant",
#     'Jaiya Thai Oriental Restaurant',
#     "Jake'S",
#     "Jake'S Dilemma",
#     "Jake'S Steakhouse",
#     'Jalapeno Deli',
#     'Jamaican Flavours',
#     'Jane',
#     'Japan Airlines Lounge',
#     'Jardin De China Rest',
#     'Java Girl',
#     'Java Restaurant',
#     'Jays Restaurant',
#     'Jean Danet French Pastry',
#     'Jean Georges',
#     "Jennifer'S Restaurant",
#     "Jentana'S Pizza",
#     'Jerk Hut',
#     "Jerry'S 637 Diner",
#     'Jerusalem Pizza',
#     'Jewel Bako',
#     'Jewish Theological Seminary',
#     'Jg Melon Restaurant',
#     'Jian On Chinese Restaurant',
#     "Jim Brady'S Restaurant",
#     "Jimbo'S Hamburger Place",
#     "Jimbo'S Hamburgers",
#     'Jimbos Hamburger Palace',
#     "Jimmy Ryan'S",
#     "Jimmy'S Corner",
#     'Jing Fong Restaurant',
#     'Jj Garden Restaurant',
#     'Jo Jo',
#     "Jody'S Club",
#     'Joe Allen Restaurant',
#     "Joe'S Of Ave U",
#     "Joe'S Pizza",
#     "Joe'S Place",
#     "Joe'S Pub",
#     "Joe'S Shanghai Restaurant",
#     "Joey'S Place",
#     'John & Joe Pizzeria & Restaurant',
#     'John & Tonys Pizza',
#     'John Hughes Knights Of Columbus Club',
#     "John Mulligan'S Fireside Pub",
#     "John'S Donut & Coffee Shop",
#     "John'S Pizza",
#     "John'S Pizzeria",
#     "John'S Restaurant",
#     "Johnny Mack'S Bar",
#     'Johnny Pumps',
#     "Johnny'S Bar",
#     "Johnny'S O'S",
#     "Johnny'S Reef Restaurant",
#     'Johns Cafe & Resturant',
#     "Jojo'S Pizza",
#     'Jolly Tinker',
#     'Jones Reavis & Pague Llp',
#     "Joseph'S Ristorante",
#     'Joshua Tree',
#     "Josie Wood'S Pub",
#     "Josie'S Restaurant",
#     'Joya',
#     "Joyce'S Tavern",
#     "Joyce'S West Indies Restaurant",
#     'Jp Morgan Chase Bank Cafeteria',
#     "Jp'S Bar",
#     "Jp'S Waterside Restaurant",
#     'Judge Roy Bean',
#     'Juice For Life',
#     'Juice Generation',
#     'Juicy Lucy',
#     "Juicy Lucy'S",
#     'Jules Bistro',
#     'Julius',
#     'Julliard & S.A.B. Cafeteria',
#     "Junior'S",
#     "Junior'S Cafe",
#     'Juniors',
#     "K'S Cafeteria",
#     'Kabab Cafe',
#     "Kabooz'S Bar & Grille",
#     'Kabul Kabab House',
#     'Kana Tapas Bar & Restaurant',
#     'Kanes Deli Diner',
#     'Kang Suh Korean Restaurant',
#     'Karavas Pizza N Pita',
#     'Karavas Place',
#     'Karma',
#     'Kasteli Ii',
#     "Katz'S Delicatessen",
#     'Keats Restaurant',
#     'Kebab House',
#     'Keenans',
#     'Keens Steakhouse',
#     'Kelley & Ping',
#     "Kelly'S Pub",
#     "Kelly'S Restaurant & Pizza",
#     "Kelly'S Tavern",
#     'Kennedy Fried Chicken',
#     'Kent Theatre',
#     'Kentucky Fried Chicken, Tim Hortons',
#     'Kentucky Fried Chicken/ Island Cuisine',
#     'Kenyon & Kenyon Cafeteria',
#     'Kerry Hills Pub',
#     'Kew Gardens Cinemas',
#     'Kfc/Taco Bell',
#     'Khyber Pass',
#     'Khyber Restaurant',
#     'Kiddie Cakes',
#     "Kids 'N' Action",
#     'Killarney Rose',
#     "Killarney'S Pub",
#     "Killmeyer'S Old Bavaria Inn.",
#     'Kimchee Korean Restaurant',
#     'King Yum Restaurant',
#     "King'S Arms Restaurant",
#     'Kings Carriage House',
#     'Kings County Cafeteria Bldg T',
#     'Kingston Tropical Bakery',
#     'Kinsale Tavern',
#     'Kismat Indian Cuisine',
#     'Kitchenette Uptown',
#     'Kitty Kiernans',
#     'Knapp St Pizza',
#     'Knapp St Pizza Ii',
#     'Knickerbocker Bar & Grill',
#     'Knickerbocker Club',
#     'Knights Of Baron Dekalb',
#     'Ko-Sushi Japanese Restaurant',
#     'Koliba Restaurant',
#     'Korean Lounge',
#     'Korner Pizzeria',
#     'Kosher Bagel Hole',
#     'Kosher Delight',
#     'Kosher Deluxe',
#     'Kosher Hut Of Brooklyn',
#     'Koyzina Kafe',
#     'Krispy Pizzeria',
#     "Kristy'S Restaurant",
#     'Krystal European Bakery',
#     'Krystal Pastry Shop',
#     'Kum Gang San',
#     'Kum Gang San Korean Restaurant',
#     'Kum Kau Kitchen',
#     'Kunjip Restaurant',
#     'Kurumazushi Restaurant',
#     'L & M Italian Deli & Catering',
#     "L'Express",
#     'L. A. Pizzeria',
#     'La Antioquena Bakery Ii',
#     'La Bagel Delight',
#     'La Baraka Restaurant',
#     'La Barca Restaurant',
#     'La Bella Pizza',
#     'La Bella Rosa Bakery',
#     'La Boina Roja Steak House',
#     'La Bonbonniere',
#     'La Bonne Soupe Bistro',
#     'La Bruschetta Restaurant',
#     'La Cabana',
#     'La Cabana Argentina',
#     'La Cabana Jarabacoa Restaurant',
#     'La Cabana Restaurant',
#     'La Cabana Salvadorena Restaurant',
#     'La Caridad 78',
#     'La Caridad Restaurant',
#     'La Carreta Restaurant',
#     'La Casa Bella',
#     'La Casa Del Pollo Restaurant',
#     'La Cucina',
#     'La Delice Pastry Shop',
#     'La Dinastia',
#     'La Dolce Italia Bakery',
#     'La Familia Restaurant',
#     'La Fe Restaurant',
#     'La Flor Bakery Cafe',
#     'La Fusta Restaurant',
#     'La Giara',
#     'La Gioconda',
#     'La Gourmet',
#     'La Grenouille',
#     'La Grotta Ristorante',
#     'La Isla',
#     'La Isla Cuchifritos',
#     'La Isla Restaurant',
#     'La Lechonera Criolla',
#     'La Lechonera Restaurant',
#     'La Linea Lounge',
#     'La Locanda Restaurant',
#     'La Luncheonette',
#     'La Mangeoire',
#     'La Mediterranee Restaurant',
#     'La Mela Restaurant',
#     'La Mirabelle Restaurant',
#     'La Nortena Express Restaurant',
#     'La Nueva Giralda Bakery',
#     'La Nueva Playitas',
#     'La Nueva Victoria Restaurant',
#     'La Palapa',
#     'La Palina Restaurant',
#     'La Parisienne Diner',
#     'La Perla Mexicana',
#     'La Piazzetta',
#     'La Picada Azuaya Restaurant',
#     'La Pizza Fresca',
#     'La Ripaille Restaurant',
#     'La Rivista Restaurant',
#     'La Sabrosura',
#     'La Sorrentina Pizzeria Restaurant',
#     'La Sorrentina Ristorante',
#     'La Strada Restaurant',
#     'La Taza De Oro Restaurant',
#     'La Verite Restaurant Bar',
#     'La Vienesa Spanish Bakery',
#     'La Villa De Pizza & Restaurant',
#     'La Villa Pizzeria',
#     'La Villita Restaurant',
#     'Labella Ferrara',
#     "Labetti'S Post # 2159",
#     'Lace',
#     'Laguardia Courtyard Hotel By Marriott',
#     'Lahore Delicatessen',
#     'Lamarca Pasta Restaurant',
#     'Landmark Coffee Shop',
#     'Lane Deli & Catering',
#     'Langans Bar & Restaurant',
#     "Lanza'S",
#     'Las Isla Restaurant',
#     'Last Stop Restaurant',
#     'Laterna Taverna',
#     'Latin American Restaurant',
#     'Latin Bakery',
#     'Latino Restaurant',
#     'Latourette Golf Course',
#     'Lattanzi',
#     "Lavelle'S Admiral'S Club",
#     'Lazard Freres',
#     'Lazzaras Pizza Cafe',
#     'Lb Spumoni Gardens',
#     'Le Bateau Ivre',
#     'Le Bernardin',
#     'Le Bon Cafe',
#     'Le Charlot',
#     'Le Colonial',
#     'Le Gigot',
#     'Le Glacier',
#     'Le Marais',
#     'Le Mirage Cafe',
#     'Le Monde',
#     'Le Pain Quotidien',
#     'Le Paris Bistrot Francais',
#     'Le Perigord',
#     'Le Petit Cafe',
#     'Le Rivage',
#     'Le Singe Vert',
#     'Le Train Bleu & B Cafe',
#     'Le Trapeze',
#     'Le Zie Trattoria',
#     "Lee'S Villa Chinese Restaurant",
#     'Lefkos Pygos Cafe',
#     'Legends Bar & Grill',
#     'Lena Restaurant',
#     'Lenfest Cafe - Jerome Green Hall',
#     "Lenihan'S Saloon",
#     "Lenny & John'S Pizza",
#     "Lenny'S Bagels",
#     "Lenny'S Clam Bar",
#     "Lenny'S Pizza",
#     'Lenox Hill Grill/Pizza',
#     'Leon Bakery',
#     'Leonidas',
#     'Les Halles',
#     'Levain Bakery',
#     'Lexicon',
#     'Lexington Bar And Books',
#     'Lexington Candy Shop',
#     'Lexler Deli',
#     "Li Greci'S Staaten Restaurant",
#     'Liberato Restaurant',
#     'Lichee Nut',
#     'Liffy Ii Bar',
#     'Lighthouse Cafe Restaurant',
#     "Lil Frankie'S Pizza",
#     "Lily'S Bar @ Roger Smith Hotel",
#     'Lin Home Chinese Restaura',
#     "Lin'S Garden",
#     'Lincoln Plaza Cinemas',
#     'Lindenwood Diner',
#     "Lindy'S",
#     'Ling Kee Beef Jerky',
#     'Lite Bites & Grill',
#     'Lite Delights',
#     'Little Brown Jug',
#     'Little Italy Pizza',
#     'Little Pie Company',
#     'Little Poland Restaurant',
#     "Little Sal'S Italiano",
#     "Little Vincent'S Pizza Restaurant",
#     'Live Bait Bar & Restaurant',
#     "Ljubo'S Pizzeria",
#     "Loduca'S Pizza",
#     "Loeser'S Hebrew National",
#     'Lok Sing Chinese Restaurant',
#     'Loki Bar & Benchmark Restaurant',
#     "Lolita'S Restaurant",
#     "Lombardi'S",
#     'Lomzymianka Restaurant',
#     'London Lennies',
#     'Longacre Theatre',
#     "Lopez'S Pizzeria And Coffee Shop",
#     'Lords Bakery',
#     "Lorenzo & Maria'S",
#     'Los Amigos Mexican Restaurant',
#     'Los Angeles Bakery',
#     'Los Arrieros Restaurant',
#     'Los Girasoles Restaurant',
#     'Los Papis Restaurant',
#     'Los Toldos Restaurant',
#     'Lotos Club Grill Room',
#     'Loui Seafood',
#     "Louie'Sdale Diner",
#     "Lovell'S Guiding Light",
#     "Lucho'S Place",
#     'Lucia Pizza',
#     'Lucien Restauraunt',
#     'Lucky Deli',
#     'Lucky House Chinese Kitchen',
#     'Lucky House Restaurant',
#     'Lucky Pizza',
#     'Lucky Star Cafe',
#     'Lucky Star Restaurant',
#     'Lucky Strike',
#     'Lucys',
#     "Luigi'S Catering",
#     "Luigi'S Pizza",
#     "Luigi'S Pizza & Restaurant",
#     "Luigi'S Pizzeria",
#     "Luigi'S Restaurant",
#     "Luke'S Bar & Grill",
#     "Lulu'S Bakery",
#     "Lulu'S Coffee Shop",
#     'Lunch Box',
#     'Lunella Restaurant',
#     'Lung Moon Bakery',
#     'Lunt Fontanne Theater',
#     'Lupa',
#     "Lupe'S East L.A. Kitchen",
#     "Lusardi'S Restaurant",
#     'Lyceum Theatre',
#     'M & M Bar & Grill',
#     'M. Restaurant',
#     'Macelleria Restaurant',
#     'Mad River Bar & Grille',
#     "Madame Tussaud'S",
#     'Madame X',
#     'Madiba',
#     'Madison Bistro',
#     'Madison Square',
#     "Madison'S",
#     'Madras Mahal',
#     'Maggie Mays',
#     'Maggies Place',
#     "Maguire'S Public House",
#     'Maharaja Quality Sweets',
#     'Majestic Pizza',
#     'Majestic Theater',
#     'Make My Cake',
#     "Malachy'S",
#     'Malaga Restaurant',
#     'Malecon Restaurant',
#     "Maloney'S Bar",
#     "Mama Carmela'S",
#     'Mama Lucia',
#     "Mama'S Fried Chicken",
#     'Mamoun Falafel',
#     'Mana',
#     'Manducatis',
#     "Manetta'S Ristorante",
#     'Mangez Avec Moi',
#     'Manhattan Courtyard',
#     'Manhattan Diner',
#     'Manhattan Espresso',
#     'Manhattan Monster',
#     'Manhem Club',
#     'Manna House',
#     'Manna House Bakery',
#     'Manna One Bakery',
#     'Manna Restaurant Ii',
#     "Manny'S Cafe Family Restaurant",
#     "Manny'S Grill",
#     'Manon Cafe / Leonidas',
#     'Mansions Cater',
#     'Marathon Food Shop',
#     'Marbella Restaurant',
#     'Marchis Restaurant',
#     'Marco Polo Ristorante',
#     'Margherita Pizza',
#     'Maria Pia',
#     'Maria Ristorante',
#     'Mariella Pizza',
#     'Maries Crisis Cafe',
#     'Marina Cafe',
#     'Marina Delray',
#     'Mariner Inn',
#     "Marino'S Pizza & Restaurant",
#     "Mario'S Pizza",
#     "Mario'S Restaurant",
#     'Marios Pizzeria',
#     'Mariott Marquis/Crossroads Bar',
#     'Market Cafe',
#     'Market Place Pizza',
#     'Market Restaurant (C-D Block)',
#     'Marquet Fine Pastry',
#     'Marquis Theater',
#     'Marriott Marquis - Main Kitchen',
#     'Marriott Marquis Pastry Shop',
#     'Marseille',
#     "Marty O'Brien'S",
#     'Marumi',
#     'Maruzzella',
#     "Mary Ann'S",
#     "Mary'S Fish Camp",
#     'Masawa',
#     'Master Wok',
#     'Mateus Restaurant',
#     "Matt'S Grill Restaurant",
#     'Maurya Restaurant',
#     'Max Soha',
#     'May May Kitchen',
#     'Maya',
#     'Mayer, Brown & Platt',
#     'Maz Mezcal',
#     "Mc Guinness'S",
#     "Mcaleer'S Pub",
#     "Mccabe'S Bar Car",
#     'Mccaffrey And Burke',
#     "Mccann'S Pub",
#     "Mccoy'S Pub",
#     'Mcdonald Avenue Diner',
#     "Mcdonald'S",
#     "Mcdonald'S (Macy'S 7Th Fl)",
#     'Mcdwyers Pub',
#     'Mcgees Pub',
#     'Mcgraw Hill Executive Dining',
#     'Mcloughlins Bar',
#     'Mcquaids Public House',
#     "Mcsorley'S Old Ale House",
#     'Me & My Eggroll',
#     'Mediterraneo',
#     'Mee Sum Coffee Shop',
#     'Mehak',
#     'Mejlander & Mulgannon',
#     'Melody Lanes',
#     'Members Dining Room @ The Met Museum',
#     'Memo Shish Kebab',
#     'Memories Lounge',
#     "Mendy'S",
#     'Mercer Kitchen',
#     'Mercury Bar',
#     'Mesivta Eitz Chaim',
#     'Meskerem',
#     'Metro Coffee Shop @ Jetro',
#     'Metro Diner',
#     'Metro Grill',
#     'Metropolitan',
#     'Metropolitan Club',
#     'Metropolitan Food Cafe Of Brooklyn College',
#     'Metropolitan Museum Employee Cafeteria',
#     'Metrostar Cafe',
#     'Mexican Radio',
#     'Mexico Lindo Restaurant',
#     "Mezcal'S Dos Restaurant",
#     "Mezcal'S Restaurant",
#     'Mezcals Restaurant',
#     'Mezzaluna',
#     'Mezzogiorno',
#     'Mi Pueblito Bakery/Comida Tipica Mexicana',
#     'Mi Sueno Restaurant',
#     "Michael Jordan'S Steak House - In Grand Central",
#     "Michael'S",
#     "Michael'S Pastry Shop",
#     "Michael'S Restaurant",
#     "Michelle'S Cocktail Lounge",
#     'Midway Cinemas',
#     "Mike'S Coffee Shop",
#     "Mike'S Donuts",
#     "Mike'S Pizza",
#     "Mike'S Place",
#     "Mike'S Pub",
#     'Mikes Pizza',
#     'Milan Sports Bar',
#     'Milanes Spanish Restaurant',
#     'Mill Basin Kosher Deli',
#     'Mill Korean Restaurant',
#     "Millie'S Deli",
#     'Million Deli',
#     'Mimis Restaurant & Bar',
#     'Minar Indian Restaurant',
#     'Mini Star Restaurant',
#     'Minitalia Pizzeria',
#     'Minskoff Theater',
#     'Miracali Bakery',
#     'Mirage Diner Restauraunt',
#     'Mishima Restaurant',
#     "Miss Lily'S 7A",
#     "Mitchell'S Restaurant",
#     'Miyagi Japanese Home Cooking',
#     "Moe'S Southwestern Grill/Charley'S",
#     'Molly Wee Pub',
#     "Molly'S",
#     'Molyvos',
#     "Mom'S Fried Chicken",
#     'Moms Luncheonette',
#     "Mona'S",
#     'Mondial Bakery',
#     'Monster Sushi',
#     "Monte'S",
#     'Montebello Restaurant',
#     'Montero Bar & Grill',
#     'Montezuma Restaurant',
#     "Monty Q'S",
#     'Moonstruck East',
#     "Moran'S Chelsea",
#     'Moretti Bakery',
#     'Morgan Stanley Cafeteria',
#     'Morningstar Restaurant',
#     'Morrell Wine Bar & Cafe',
#     'Morris Park Bake Shop',
#     'Morris Park Pizza',
#     "Morton'S Steakhouse",
#     "Mother'S Bake Shop",
#     "Moti'S",
#     'Motivo',
#     'Moto',
#     'Moustache',
#     'Moustache Restaurant',
#     'Mozzarella & Vino',
#     'Mr Broadway Kosher Restaurant',
#     'Mr Falafael Restaurant',
#     "Mr K'S Restaurant",
#     "Mr Mcgoo'S",
#     'Mr. Chow Restaurant',
#     "Mr. Phil'S Pizza",
#     'Mr. Wonton',
#     "Mrs Friggins' Kitchen",
# ...
#     'Sean Og',
#     'Seashore Restaurant',
#     'Section 5 Pizza Restaurant',
#     'Seguine Bagel Bakery',
#     'Seo Japanese Restaurant',
#     'Seoul Garden',
#     'Serafina Fabulous Pizza',
#     'Serendipity 3',
#     'Session 73',
#     'Sette Mezzo',
#     'Seuda Foods',
#     'Seven Bar & Grill',
#     'Seven Stars Bakery',
#     'Seville Restaurant',
#     'Shabu Tatsu',
#     'Shabu-Shabu 70 Restaurant',
#     'Shade',
#     'Shalon Restaurant',
#     'Shamrock Inn',
#     'Sharaku Japanese Restaurant',
#     'Sharmel Caterers',
#     "Shashemene Int'L Restaura",
#     'Sheas Emerald',
#     'Sheepshead Bay Yacht Club Bar',
#     'Shell Lanes',
#     'Shem Tov',
#     'Shemtov Manor',
#     "Shenanigan'S",
#     'Shenanigans Pub',
#     'Shimons Kosher Pizza',
#     'Shore Haven Diner',
#     'Short Stop Restaurant',
#     "Showman'S Cafe",
#     'Shubert Theater',
#     'Shun Lee',
#     'Shun Lee Palace Restaurant',
#     'Sideshows By The Seashore',
#     'Sidewalk Bar & Restaurant',
#     'Sido Falalel & More',
#     'Silver Moon Bakery',
#     'Silver Spurs/Molcajate Taqueria',
#     'Silver Star Restaurant',
#     'Simone Bar Cafe',
#     'Simpson Thacher And Bartlet Cafe',
#     'Sing Sing Karaoke',
#     'Singas Famous Pizza',
#     "Sissy Mcginty'S",
#     'Sisters Cuisine',
#     'Sistina Restaurant',
#     'Sizzler',
#     'Skadden Arps, Slate',
#     'Skylight Diner',
#     "Smiler'S",
#     "Smiler'S Deli",
#     'Smiling Pizza',
#     'Smith & Wollensky',
#     'Smoke',
#     'Snack',
#     'Snack Bar (Located Between A-B Between Fancy Food And Masters)',
#     'Snack Time Grill',
#     'Snacks-N-Wheels',
#     'Snafu',
#     "Sob'S",
#     'Soba Nippon Japanese Restaurant',
#     'Soba-Ya',
#     'Society Of Illustrators',
#     'Soda Bar',
#     'Sodexo',
#     'Soho Grand Hotel',
#     'Solas',
#     'Solera Restaurant',
#     'Sombrero Mexican Restaurant',
#     "Sonny'S Heros",
#     'Sony Music Employee Cafeteria',
#     "Sophie'S Restaurant",
#     'Sotto Voce Restaurant',
#     'Souen Restaurant',
#     'South Shore Swimming Club',
#     "South'S",
#     'Souvlaki House',
#     'Soy',
#     'Spain Restaurant & Bar',
#     'Sparks Steak House',
#     'Speedy Deli',
#     'Spirit Of New Jersey',
#     'Spirit Of New York',
#     'Spiros Restautrant',
#     "Spolini'S",
#     'Spoon Bread Catering',
#     'Sports Center At Chelsea Piers (Sushi Bar)',
#     'Sports Center Cafe',
#     'Sports Mania Bar & Grill',
#     "Spoto'S Restaurant",
#     'Spring St. Natural Restaurant',
#     'Springfield Diner',
#     'St Lucian Paradise',
#     "St. Dymphna'S",
#     'St. Marks Ale House',
#     'Stage Door Deli',
#     'Stage Restaurant',
#     'Stand # 210',
#     'Stand # 326',
#     'Star Lite Deli',
#     'Starbucks Coffee',
#     'Starbucks Coffee # 7463',
#     'Starbucks Coffee # 7540',
#     'Starbucks Coffee #7344',
#     'Starbucks Coffee #7358',
#     'Starbucks Coffee #7416',
#     'Starbucks Coffee #7682',
#     'Starbucks Coffee (Bank Of America Building)',
#     'Starbucks Coffee (Store #7216)',
#     'Starbucks Coffee (Store #7555)',
#     'Starbucks Coffee (Store #7577)',
#     'Starbucks Coffee (Store #7587)',
#     'Starbucks Coffee (Store #7696)',
#     'Starbucks Coffee (Store 7261)',
#     'Starting Gate',
#     'Steinway Billiard',
#     'Step In Restaurant & Lounge',
#     "Steve Chu'S Deli & Grocery",
#     "Steve'S Bakery",
#     "Steve'S Coffee Shop",
#     'Stir Cafe',
#     'Strauss Bakery',
#     'Strictly Vegetarian',
#     'Strokos Gourmet Deli',
#     'Strokos Pizza Deli',
#     'Stromboli Pizza',
#     'Studio 46',
#     'Studio Cafe 59',
#     'Stuyvesant Yacht Club',
#     'Subway',
#     'Subway / Twin Donut',
#     'Sugar Bar',
#     'Sugar Bun Bakery',
#     'Sugar City Bakery',
#     'Sugar Factory',
#     'Sugar Hill Restaurant, Supper Club And Disco',
#     'Sugiyama Restaurant',
#     'Sullivan & Cromwell',
#     "Sunberry'S",
#     'Sunflower Cafe',
#     'Sunrise Coffee Shop',
#     'Sunset Park Diner & Donuts',
#     'Sunset Pizzeria',
#     'Supernova-Novotel Hotel',
#     'Supper',
#     'Surf & Turf Restaurant',
#     'Surf Bar',
#     'Sushi Damo',
#     'Sushi Family',
#     'Sushi Of Gari',
#     'Sushi Samba #7',
#     'Sushi Zen',
#     'Sushiden',
#     'Sushiya Japanese Restaurant',
#     "Susie'S Pies",
#     'Sutton Cafe Restaurant',
#     'Sutton Pizza & Gyro',
#     'Sweet & Vicious',
#     'Sweet Chef Southern Styles Bakery',
#     'Sweet Life Cafe',
#     'Swift',
#     "Swifty'S",
#     'Swing 46 Jazz And Supper Club',
#     'Swiss International Airlines Lounge',
#     "Sybil'S Bakery",
#     "Sylvia'S Restaurant",
#     'Symposium Greek Restaurant',
#     'Szechuan Delight Restaurant',
#     'Szechuan Kitchen',
#     "T & G Whitney'S",
#     'T-Bar Steak & Lounge',
#     'T-Bone Diner',
#     "T.G.I. Friday'S",
#     'T.G.I. Fridays',
#     "T.J.'S Sports Bar",
#     'Taco Bell',
#     'Taco Bell Pizza Hut Express',
#     'Taco Bell, Au Bon Pain',
#     'Tacos Mexico',
#     "Tad'S Steaks",
#     'Tai Pan Bakery',
#     'Taj Cafe',
#     'Taj Donut Shop',
#     'Taj Mahal Indian Restaurant',
#     'Tajin Restaurant',
#     'Taka Hashi Restaurant',
#     'Tal Bagel',
#     'Tal Bagels Deli',
#     'Tamaqua',
#     'Tandoori Food & Bakery',
#     'Tanjia Hukka Bar',
#     'Tao Restaurant',
#     'Tap Room',
#     'Tap-A-Keg',
#     'Taqueria Restaurante Mi Bario',
#     'Tarallucci E Vino',
#     'Tartine',
#     'Taste Of India Ii Restaurant',
#     'Taste Restaurant',
#     'Taste The Tropics Ice Cream',
#     'Tastee Corner',
#     'Tasty Cafe Catering',
#     'Tasty Fast Food',
#     "Tasty'S",
#     'Tatiana Restaurant',
#     'Tavern Lounge',
#     'Tavern On Jane',
#     'Tea And Sympathy',
#     "Teddy'S Bar And Grill",
#     "Tee Dee'S Tavern",
#     'Ten Degrees',
#     'Ten Degrees Bistro',
#     "Ten Ren'S Tea Time",
#     'Ten-Tan Chinese Restaurant',
#     'Teodora',
#     'Tequila Sunrise',
#     'Tequilitas Mexican Restaurant',
#     'Tequilla Sunrise',
#     "Teresa'S Gourmet",
#     "Teresa'S Resturant",
#     'Terminal Cafe/Yankee Clipper',
#     'Terminal1 Employee Cafeteria',
#     'Terra Blues',
#     'Terrace Cafe',
#     'Terrace On The Park',
#     "Terranova'S Bake Ridge Bagel",
#     'Tevere 84',
#     'Texas Rotisserie',
#     'Thai Son',
#     'Thalia',
#     'The Abbey',
#     'The Abbey Pub',
#     'The Arch Diner',
#     'The Assembly Bar',
#     'The Astoria World Manor',
#     'The Aurora Pizza Caffe',
#     'The Bagel House',
#     'The Barbecue Pit',
#     'The Beekman',
#     'The Best Italian Pizza',
#     'The Bitter End',
#     'The Black Dog Grill',
#     'The Black Duck Restaurant',
#     'The Black Sheep',
#     'The Blue Zoo Lounge',
#     'The Bowery Ballroom',
#     'The Bras & Pail Bar',
#     'The Brazen Head',
#     'The Bread Factory Cafe',
#     'The Brook',
#     'The Bubble Lounge',
#     'The Burrito Bar Restaurant',
#     'The Campbell Apartment - In Grand Central',
#     'The Carnegie Cigar Club And Lounge',
#     'The Central Bar',
#     'The Century Association',
#     'The Clubhouse',
#     'The Cornell Center Of New York',
#     'The Corner House',
#     'The Country Cafe',
#     'The Courtyard Ale House',
#     'The Crooked Tree',
#     'The Cupping Room',
#     'The Dart Inn',
#     'The Dead Poet',
#     'The Dish Restaurant',
#     'The Eagle',
#     'The Edge Bar',
#     'The End Zone Bar',
#     'The Esplanade',
#     "The Famous Jimbo'S Hamburger Palace",
#     'The Fitz',
#     'The Food Hut',
#     'The Four Seasons',
#     'The Full Shilling',
#     'The Gate',
#     'The Gin Mill',
#     'The Ginger Man',
#     'The Grand Prospect Hall',
#     'The Great American Health Bar',
#     'The Great Burrito Mexican Kitchen',
#     'The Greek Corner',
#     'The Greek Kitchen  Clinton Bakery Cafe',
#     'The Green Table(Chelsea Market)',
#     'The Grocery',
#     'The Grotto',
#     'The Half King',
#     'The Hallmark Of Battery Park City- Dining Room',
#     'The Harrison',
#     'The Heights Bar & Grill',
#     'The Historic Old Bermuda Inn',
#     'The Hytes Bar',
#     "The Ice Box-Ralph'S Famous Italian Ices",
#     'The Irish Pub',
#     'The Islands',
#     'The Joyce Theater',
#     "The Lark'S Nest",
#     'The Liberty Cafe (S.I. Newhouse)',
#     'The Library',
#     'The Little Sweet Shoppe',
#     'The Lowell',
#     'The Magician',
#     'The Malt House',
#     'The Mansion Grand',
#     'The Mercury Lounge',
#     'The Movable Feast',
#     'The Muffins Shop',
#     'The Neptune Diner',
#     'The New Amity Restaurant',
#     'The New Starling Athletic Club Of The Bronx',
#     'The New Thompson Diner',
#     'The Nippon Club',
#     "The Old Time Vincent'S",
#     'The Original California Taqueria',
#     'The Original Pizza Iv',
#     'The Original Pizza Of 4Th Ave',
#     'The Original Pizza Of Avenue L',
#     "The Original Sal'S Pizzeria",
#     'The Otheroom',
#     'The Palace Theater',
#     'The Park',
#     'The Park Slope Chipshop',
#     'The Parlour',
#     'The Patio Grill',
#     'The Penn Club',
#     'The Pizza Place',
#     'The Place',
#     'The Players Club',
#     'The Princeton Club',
#     'The Punch Bowl',
#     'The Rail Line Diner',
#     'The Ranch Restaurant & Bar Of Guyana',
#     'The Red Cat',
#     'The Restaurant',
#     'The River Cafe',
#     'The River Club',
#     'The Riviera Cafe',
#     'The Room',
#     'The Scratcher Cafe',
#     'The Slaughtered Lamb',
#     'The Spring Lounge',
#     'The Stairs Bar And Lounge',
#     'The Stumble Inn',
#     'The Summit',
#     'The Tap Room',
#     'The Thirsty Scholar',
#     'The Tick Tavern',
#     'The Trash Bar',
#     'The Triad',
#     'The Triple Crown',
#     'The Union League Club',
#     'The University Club',
#     'The Upper Crust',
#     'The Usual Restaurant',
#     'The Village Lantern',
#     'The Village Tavern',
#     'The Water Club',
#     'The Webster Apartments',
#     'The Wheeltapper',
#     'The Whiskey Ward',
#     'The Williamsbridge Tavern',
#     'Think Sweet Cafe',
#     'Thomas Preti Caterers',
#     "Thomasina'S",
#     'Three Decker Restaurant',
#     "Three Guy'S Restaurant",
#     'Three Jolly Pigeons',
#     'Three Of Cups',
#     'Three Star Restaurant',
#     'Throgs Neck Clipper',
#     'Tibbett Diner',
#     'Tiberio Dimare',
#     'Tick Tock Diner',
#     'Tierras Columbianas',
#     'Tim Hortons',
#     'Time Cafeteria',
#     'Times Deli & Cafe',
#     "Timmy'S Deli",
#     "Tina'S Restaurant",
#     'Tio Pepe',
#     'Tip-Top Bar & Grill',
#     'Tir Na Nog',
#     'Tiramisu Restaurant',
#     "Tj Byrne'S Bar",
#     'Tjk Cafe & Restaurant',
#     'To Go Express',
#     'Toad Hall',
#     'Toast',
#     'Tokubei 86',
#     'Tokya',
#     'Toledo',
#     'Tom And Jerry Bar',
#     "Tom'S Delicious Pizza",
#     "Tom'S Restaurant",
#     'Tommaso Restaurant',
#     "Tommy'S Pizza",
#     'Tong Hai Tung Bakery',
#     "Tony'S Brick Oven",
#     "Tony'S Deli",
#     "Tony'S Pier Restaurant",
#     "Tony'S Pizza",
#     "Tony'S Pizza Ii",
#     "Tony'S Pizzeria",
#     "Tony'S Pizzeria & Restaurant",
#     'Topaz Thai Restaurant',
#     'Topaze Restaurant',
#     'Topaze Restaurant & Jerk Chicken',
#     'Torch Club',
#     'Tortilla Flats',
#     "Tota'S",
#     "Totonno'S Pizzeria",
#     'Tottenville Bagels',
#     "Touch Of Dee'S",
#     'Tournesol',
#     'Tous Les Jours',
#     'Tout Va Bien',
#     'Tov Kosher Kitchen',
#     'Towers Restaurant',
#     'Town Hall Theatre',
#     'Towne Cafe',
#     'Towne Deli & Pizza',
#     'Townhouse Diner',
#     'Townhouse Of Ny',
#     'Track Kitchen',
#     'Trackside',
#     'Trattoria Alba',
#     'Trattoria Della Arte',
#     'Trattoria I Malatesta',
#     "Trattoria L'Incontro",
#     'Trattoria Pesce Pasta',
#     'Trattoria Romana',
#     'Tre Giovani Pizza & Pasta',
#     'Trellis',
#     'Tres Coronas Bar',
#     'Trevi Deli',
#     'Triangolo Pizzeria',
#     'Tribeca Grand Hotel',
#     'Tribeca Grill',
#     'Tribeca Park Cafe',
#     'Tribeca Pizzeria',
#     'Tribeca Rooftop',
#     'Tribeca Tavern',
#     'Triestes Restaurant',
#     'Trinity Pub',
#     'Triomphe',
#     'Triple Crown Diner',
#     'Tripoli Restaurant',
#     'Tropical House Baking Co.',
#     'Trufa Restaurant',
#     'Tsq Brasserie',
#     'Tsukushi Restaurant',
#     "Turkey'S Nest Tavern",
#     'Turkish Cuisine',
#     'Turkish Kitchen',
#     'Turkuaz Turkish Cuisine',
#     'Turtle Bay Grill And Lounge',
#     'Tuscany Grill',
#     'Twins Pub',
#     'Two Boots Grand Central',
#     'Two Boots To Go West',
#     'Two Boots To Go-Go',
#     "Ty'S",
#     'Ua Court Street #12',
#     'Ua Kaufman Astoria #14',
#     'Udon West',
#     'Uncle Nicks',
#     "Uncle Peter'S",
#     'Uncle Vanya',
#     'Underground Lounge',
#     'Unforgettable Lounge',
#     'Union Cafe Restaurant',
#     'Union Club Of City Of New York',
#     'Union Hall',
#     'Union Pool',
#     'Unique Lounge',
#     'United Cyprians Of America',
#     'United Grocery & Deli',
#     'Uno Cafe & Billiards',
#     'Uno Chicago Grill',
#     'Usagi',
#     'Uskudar Restaurant',
#     'Usuluteco Restaurant',
#     'Utopia Restaurant',
#     'Utsav Festive India Restaurant',
#     'V & S Pizzeria Of Sheapshead Bay',
#     'V & T Restaurant',
#     'V & V Bakery',
#     'V-Bar And Cafe',
#     'Va Bene',
#     "Vaccaro'S Pizzeria & Trattoria",
#     "Valentino'S Pizza",
#     'Van Dam Diner',
#     'Varenichnaya - Pelmini Varenichky',
#     'Vatan',
#     "Vee'S Restaurant",
#     'Vegas Diner',
#     'Venice Pizza',
#     'Venice Restaurant',
#     'Verdi Restaurant',
#     'Verlaine',
#     'Verona Pizza',
#     'Veselka Restaurant',
#     'Vespa Cibobuono',
#     'Vesuvio Restaurant & Pizza',
#     'Veterans Of Foreign Wars Post #107 Canteen',
#     'Via Brazil',
#     'Via Italia Ristorante',
#     'Via Quadronno',
#     'Viand Cafe',
#     'Viand Coffee Shop',
#     "Vic'S",
#     'Vice Versa',
#     'Vico Ristorante',
#     "Victor'S Cafe",
#     'Victoria Pizza',
#     'Victory Sweet Shop',
#     'View Lounge',
#     'View Restaurant',
#     'Villa Barone',
#     'Villa Barone Manor',
#     'Villa Berulia',
#     'Villa Fiorita',
#     'Villa Monte Pizzeria',
#     'Villa Mosconi Restaurant',
#     'Villa Russo',
#     'Villa Rustica Ristorante',
#     'Village Den',
#     'Village Natural',
#     'Village Pizza',
#     'Village Yogurt',
#     'Village Yokocho',
#     'Vin Et Fleurs',
#     "Vincent'S Pizzeria",
#     'Vincents Bagel',
#     "Vinnie'S Pizzeria/ Luncheonette",
#     "Vinny'S Famous Pizza",
#     "Vinny'S Of Carroll Garden Restaurant & Luncheonett",
#     "Vinny'S Pizza",
#     'Virage',
#     "Virgil'S Bbq",
#     'Vista Hermosa Deli Restaurant',
#     "Vito'S Bakery",
#     'Vittoria Bakery',
#     "Vivienne'S",
#     'Vixens',
#     'Vol De Nuit',
#     'Volare Restaurant',
#     'Von',
#     'W Times Square',
#     "W'S Bar & Restaurant",
#     "Wah Do Mr. Chan'S Restaurant",
#     'Wakamatsu Japanese Restaurant',
#     'Wakamba',
#     "Walker'S Restaurant",
#     'Wallse Restaruant',
#     'Walnut Bus Stop',
#     'Walter Reade Theater',
#     "Walter'S Bar",
#     'Warren Hall Coffee Bar',
#     'Washington Square Diner',
#     'Water Front Ale House',
#     'Water Front Crab House',
#     "Water'S Edge Club",
#     'Wcou Radio / Tile Bar',
#     'Webster Cafe',
#     'Weiss Cafe Rockefeller University',
#     'Wembley Athletic Club',
#     "Wendy'S",
#     'West 53Rd Gourmet Deli',
#     'West 79Th Street Boat Basin Cafe',
#     'West Bank Cafe',
#     'West Cuisine-Enchantment By Maria',
#     'Western Bakery',
#     'Westside Restaurant',
#     'Westside Tavern',
#     'Westside Theatre',
#     'Westway Diner',
#     'Whaler Bar, Cafe Buon Giorno',
#     'Wharf Bar And Grill',
#     'Wheelers',
#     'Whiskey Park',
#     'White & Case',
#     'White Castle',
#     'White Horse Tavern',
#     'Whitestone Bagel Factory',
#     'Whitestone Lanes',
#     'Whitsons And Forbes',
#     'Wilbel Pizza',
#     'Wild Asia',
#     "Wilken'S Fine Food",
#     "Wimpy'S Restaurant",
#     'Winchesters Pub',
#     'Windfall',
#     'Windjammers Bar',
#     'Wine Bar',
#     'Winter Garden Theater',
#     'Wolf And Lamb',
#     'Womens Natl. Republican Club',
#     'Wondee Siam Ii',
#     'Woo Chon Restaurant',
#     'Wood Bine Caterers',
#     'Woodlawn Cafe',
#     'Woodrow Diner',
#     'World Cup Cafe',
#     'Wrap N Run Grill',
#     'Wu Liang Ye Restaurant',
#     'Xtra Cheese Pizzeria',
#     'Yakiniku West Restaurant',
#     'Yakitori Taisho',
#     'Yale Club',
#     "Yama Japanese Restaurant'",
#     'Yankee Clipper',
#     'Yankee Jz Pizza',
#     'Yankee Tavern',
#     'Yao Wah Kitchen',
#     'Yb Food Market',
#     'Yemen Cuisine',
#     'Yen Yen Restaurant',
#     "Yip'S",
#     'Yolanda Pizzeria Restaurant',
#     'Yonah Shimmels Knishes',
#     'Your Bakery',
#     'Yummy Kitchen',
#     'Yura & Company On Madison',
#     'Yvonne Yvonne Restaurant',
#     "Zafi'S Luncheonette",
#     "Zaro'S Bakery",
#     "Zaro'S Bread Basket",
#     'Zebu Grill',
#     "Zorba'S",
#     'Zum Schneider',
#     'Zum Stammtisch',
# ]
